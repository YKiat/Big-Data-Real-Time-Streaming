# %%
from pymongo import MongoClient
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, split, element_at, when
import pygeohash as pgh 
import pandas as pd 
import json 
from datetime import datetime

# %%
topic = 'PartB'
client = MongoClient()
mydb = client.fit3182_assignment_db
streaming_climate_collection = mydb['streaming_climate_collection']
streaming_hotspot_collection = mydb['streaming_hotspot_collection']
streaming_hotspot_collection.drop()
streaming_climate_collection.drop()

# %% [markdown]
# Initialize our spark session with `#threads = #logicalCPU` and the given application name.

# %%
spark = (
    SparkSession.builder
    .master('local[*]')
    .appName('[Demo] Spark Streaming from Kafka into MongoDB')
    .getOrCreate()
)

# %% [markdown]
# Create a streaming dataframe with options providing the bootstrap server(s) and topic name.

# %%
topic_stream_df = (
    spark.readStream.format('kafka')
    .option('kafka.bootstrap.servers', 'localhost:9092')
    .option('subscribe', topic)
    .load()
)

# %%
topic_stream_df.printSchema()
# Out:
# root
#  |-- key: binary (nullable = true)
#  |-- value: binary (nullable = true)
#  |-- topic: string (nullable = true)
#  |-- partition: integer (nullable = true)
#  |-- offset: long (nullable = true)
#  |-- timestamp: timestamp (nullable = true)
#  |-- timestampType: integer (nullable = true)

# %%
output_stream_df = (
    topic_stream_df
    .select(                                     
            topic_stream_df.value.cast('string')
    .alias('data'))
)

# %%
output_stream_df.printSchema()
# Out:
# root
#  |-- data: string (nullable = true)

# %%
class DbWriter:
    # called at the start of processing each partition in each output micro-batch
    def open(self, partition_id, epoch_id):
        self.mongo_client = MongoClient(
            host='localhost',
            port=27017
        )
        self.db = self.mongo_client['fit3182_db']
        return True
    
    # called once per row of the result dataframe
    # the current code DOES NOT handle duplicate processing
    #   e.g., query fails and restarts just before current micro-batch was fully inserted
    def process(self, row):
        self.db[topic_name].insert_one(row.asDict())
    
    # called once all rows have been processed (possibly with error)
    def close(self, err):
        self.mongo_client.close()

# %%
def process_batch(batch_df,batch_id):
    #raw_data = batch_df.collect()
    # raw _data = [Row(),Row()]
    # process data into [{},{},...]
    data = [row.asDict(row) for row in batch_df.collect()]
    lst = [] 
    climate_lst = []
    hotspot_lst = [] 
    for i in range(len(data)): 
        temp = data[i]['data']
        temp = eval(temp) 
        if temp['Producer_id'] == 'Producer_01': 
            climate_lst.append(temp)

        else: 
            hotspot_lst.append(temp)    
    
    # 1. check if there is climate data in this array 
    # no climate, return
    
    if len(climate_lst) == 0: 
        return 
    
    for i in climate_lst:
        date = i['Created_Day'][0:10]

#     if len(climate_lst) == 0: 
#         return 
    # create datetime str and datetime datetime format for further purpose to group in visualization
    for i in range(len(hotspot_lst)): 
        hotspot_lst[i]['Date'] = date 
        x = hotspot_lst[i]['Created_Date']
        Create_datetime = date + " " + x 
        Create_datetime_str = Create_datetime
        hotspot_lst[i]['Create_datetime_str'] = Create_datetime_str
        Create_datetime = datetime.strptime(Create_datetime,"%Y-%m-%d %H:%M:%S")
        hotspot_lst[i]['Created_Date'] = Create_datetime
    
   
    

    # 2. compute geohash for climate, hotspot(TERRA & AQUA) (done in producer)
    if len(climate_lst) > 0:
        for i in range(len(climate_lst)): 
            climate_lst[i]["Geohash3"] = pgh.encode(climate_lst[i]['latitude'],climate_lst[i]['longitude'],precision=3)
    
    for i in range(len(hotspot_lst)): 
        hotspot_lst[i]["Geohash3"] = pgh.encode(hotspot_lst[i]['latitude'],hotspot_lst[i]['longitude'],precision=3)
        hotspot_lst[i]["Geohash5"] = pgh.encode(hotspot_lst[i]['latitude'],hotspot_lst[i]['longitude'],precision=5)
     
    # 3. within same batch, group the climate and hotspot in a lst (==geohash_3)
    same_geohash_3 = [] 
    #same_location.append(climate_lst)
    for i in hotspot_lst: 
        if climate_lst[0].get("Geohash3") == i.get('Geohash3'): 
            same_geohash_3.append(i)
    
    
    # 4. if no matching, just insert climate data into mongodb and return 
    if len(same_geohash_3) == 0:
        for i in climate_lst:
            b = {
            'station': 948703, 
            'date': i.get('Created_Day'),
            'air_temperature_celcius': i.get('air_temperature_celcius'),
            'relative_humidity': i.get('relative_humidity'),
            'windspeed_knots':i.get('windspeed_knots'),
            'max_wind_speed': i.get('max_wind_speed'),
            'precitipation': i.get('precitipation '), 
            'GHI_w/m2': i.get('GHI_w/m2'),
            'geohash3': i.get('Geohash3')
            
            }
            streaming_climate_collection.insert_one(b)
        return 

    
    # 5. if matching, groupby the same location(geohash5) and agg the avg
    hotspot_fire_lst = []
    unique_geohash5 = []
    surface_temp_sum = 0 
    confidence_sum = 0
    count = 1 
    for i in range(len(same_geohash_3)): 
        # check whether we agg on this geohash code
        if same_geohash_3[i]['Geohash5'] not in unique_geohash5:
            surface_temp_sum += same_geohash_3[i]['surface_temperature_celcius'] 
            confidence_sum += same_geohash_3[i]['confidence'] 
            for j in range(len(same_geohash_3)): 
                # skip checking itself
                if i != j :
                    if same_geohash_3[i]['Geohash5'] == same_geohash_3[j]["Geohash5"]: 
                        # count as in how many matches geohash5
                        count += 1 
                        surface_temp_sum += same_geohash_3[j]['surface_temperature_celcius'] 
                        confidence_sum += same_geohash_3[j]['confidence']
                        unique_geohash5.append(same_geohash_3[j]['Geohash5'])
        surface_temp_avg = surface_temp_sum/count 
        confidence_avg = confidence_sum/count 
        surface_temp_sum = 0 
        confidence_sum = 0 
        # only insert if > 0.0 to avoid some duplicate inserting
        if confidence_avg > 0.0:
            y = {'longitude':same_geohash_3[i]['longitude'],
                 'latitude': same_geohash_3[i]['latitude'], 
                  'confidence': confidence_avg, 
                  'surface_temperature':surface_temp_avg, 
                  'Date': same_geohash_3[i]['Created_Date'], 
                  'Date_str': same_geohash_3[i]['Date']
                 } 
            hotspot_fire_lst.append(y)   
        # reset count 
        count = 1
    
    
    # 6. insert data into mongodb 
    
    for i in climate_lst:
        a = {
            'station': 948703, 
            'date': i.get('Created_Day'),
            'air_temperature_celcius': i.get('air_temperature_celcius'),
            'relative_humidity': i.get('relative_humidity'),
            'windspeed_knots':i.get('windspeed_knots'),
            'max_wind_speed': i.get('max_wind_speed'),
            'precitipation': i.get('precipitation '), 
            'GHI_w/m2': i.get('GHI_w/m2'), 
            'geohash3': i.get('Geohash3')
        }
        climate_lst[0] = a 
        
    if len(hotspot_fire_lst) > 0 : 
        for i in climate_lst: 
            if i.get('air_temperature_celcius') > 20 and i.get('GHI_w/m2') > 180: 
                i['Fire_Cause'] = 'natural'
            else: 
                i['Fire_Cause'] = 'other'     
    
    # insert data into mongodb 
    
    for i in climate_lst:
        streaming_climate_collection.insert_one(i)
    
    for i in hotspot_fire_lst: 
        streaming_hotspot_collection.insert_one(i)
        
    
    
         

    print("Climate_lst: ",climate_lst) 
    print("Hotspot_lst: ",hotspot_lst)
    print("Same: ", same_geohash_3)
    print('Same Geohash:' , hotspot_fire_lst)

# %%
db_writer = (
    output_stream_df
    .writeStream
    .outputMode('append')
    .trigger(processingTime='10 seconds')
    .foreachBatch(process_batch)
)

# %%
db_writer.start()
# Out:
# Climate_lst:  [{'station': 948703, 'date': '2022-01-11', 'air_temperature_celcius': 14, 'relative_humidity': 48.2, 'windspeed_knots': 12.5, 'max_wind_speed': 19.0, 'precitipation': None, 'GHI_w/m2': 122, 'geohash3': 'r1m', 'Fire_Cause': 'other', '_id': ObjectId('628a70c025967c93f524f0ed')}]
# Hotspot_lst:  [{'latitude': -37.7619, 'longitude': 142.8294, 'confidence': 71, 'surface_temperature_celcius': 46, 'Producer_id': 'TERRA_Producer_03', 'Created_Date': datetime.datetime(2022, 1, 11, 19, 12), 'Date': '2022-01-11', 'Create_datetime_str': '2022-01-11 19:12:00', 'Geohash3': 'r1m', 'Geohash5': 'r1m94'}, {'latitude': -37.562, 'longitude': 148.05, 'confidence': 61, 'surface_temperature_celcius': 72, 'Producer_id': 'AQUA_Producer_02', 'Created_Date': datetime.datetime(2022, 1, 11, 0, 0), 'Date': '2022-01-11', 'Create_datetime_str': '2022-01-11 00:00:00', 'Geohash3': 'r33', 'Geohash5': 'r3362'}, {'latitude': -35.541, 'longitude': 143.311, 'confidence': 82, 'surface_temperature_celcius': 63, 'Producer_id': 'TERRA_Producer_03', 'Created_Date': datetime.datetime(2022, 1, 11, 0, 0), 'Date': '2022-01-11', 'Create_datetime_str': '2022-01-11 00:00:00', 'Geohash3': 'r1t', 'Geohash5': 'r1tvv'}, {'latitude': -36.762, 'longitude': 147.12, 'confidence': 92, 'surface_temperature_celcius': 43, 'Producer_id': 'AQUA_Producer_02', 'Created_Date': datetime.datetime(2022, 1, 11, 4, 48), 'Date': '2022-01-11', 'Create_datetime_str': '2022-01-11 04:48:00', 'Geohash3': 'r32', 'Geohash5': 'r32wg'}, {'latitude': -36.152, 'longitude': 143.578, 'confidence': 69, 'surface_temperature_celcius': 44, 'Producer_id': 'TERRA_Producer_03', 'Created_Date': datetime.datetime(2022, 1, 11, 4, 48), 'Date': '2022-01-11', 'Create_datetime_str': '2022-01-11 04:48:00', 'Geohash3': 'r1w', 'Geohash5': 'r1w47'}, {'latitude': -36.7889, 'longitude': 146.6495, 'confidence': 59, 'surface_temperature_celcius': 49, 'Producer_id': 'AQUA_Producer_02', 'Created_Date': datetime.datetime(2022, 1, 11, 9, 36), 'Date': '2022-01-11', 'Create_datetime_str': '2022-01-11 09:36:00', 'Geohash3': 'r32', 'Geohash5': 'r32q9'}, {'latitude': -36.939, 'longitude': 143.28, 'confidence': 100, 'surface_temperature_celcius': 59, 'Producer_id': 'TERRA_Producer_03', 'Created_Date': datetime.datetime(2022, 1, 11, 9, 36), 'Date': '2022-01-11', 'Create_datetime_str': '2022-01-11 09:36:00', 'Geohash3': 'r1m', 'Geohash5': 'r1mvu'}, {'latitude': -36.8202, 'longitude': 141.80200000000002, 'confidence': 80, 'surface_temperature_celcius': 54, 'Producer_id': 'AQUA_Producer_02', 'Created_Date': datetime.datetime(2022, 1, 11, 14, 24), 'Date': '2022-01-11', 'Create_datetime_str': '2022-01-11 14:24:00', 'Geohash3': 'r1k', 'Geohash5': 'r1kyd'}, {'latitude': -34.385999999999996, 'longitude': 142.0503, 'confidence': 81, 'surface_temperature_celcius': 54, 'Producer_id': 'TERRA_Producer_03', 'Created_Date': datetime.datetime(2022, 1, 11, 14, 24), 'Date': '2022-01-11', 'Create_datetime_str': '2022-01-11 14:24:00', 'Geohash3': 'r1v', 'Geohash5': 'r1vh2'}]
# Same:  [{'latitude': -37.7619, 'longitude': 142.8294, 'confidence': 71, 'surface_temperature_celcius': 46, 'Producer_id': 'TERRA_Producer_03', 'Created_Date': datetime.datetime(2022, 1, 11, 19, 12), 'Date': '2022-01-11', 'Create_datetime_str': '2022-01-11 19:12:00', 'Geohash3': 'r1m', 'Geohash5': 'r1m94'}, {'latitude': -36.939, 'longitude': 143.28, 'confidence': 100, 'surface_temperature_celcius': 59, 'Producer_id': 'TERRA_Producer_03', 'Created_Date': datetime.datetime(2022, 1, 11, 9, 36), 'Date': '2022-01-11', 'Create_datetime_str': '2022-01-11 09:36:00', 'Geohash3': 'r1m', 'Geohash5': 'r1mvu'}]
# Same Geohash: [{'longitude': 142.8294, 'latitude': -37.7619, 'confidence': 71.0, 'surface_temperature': 46.0, 'Date': datetime.datetime(2022, 1, 11, 19, 12), 'Date_str': '2022-01-11', '_id': ObjectId('628a70c025967c93f524f0ee')}, {'longitude': 143.28, 'latitude': -36.939, 'confidence': 100.0, 'surface_temperature': 59.0, 'Date': datetime.datetime(2022, 1, 11, 9, 36), 'Date_str': '2022-01-11', '_id': ObjectId('628a70c025967c93f524f0ef')}]
# Climate_lst:  [{'station': 948703, 'date': '2022-01-12', 'air_temperature_celcius': 8, 'relative_humidity': 41.6, 'windspeed_knots': 8.3, 'max_wind_speed': 15.9, 'precitipation': None, 'GHI_w/m2': 73, 'geohash3': 'r1k', 'Fire_Cause': 'other', '_id': ObjectId('628a70ca25967c93f524f0f0')}]
# Hotspot_lst:  [{'latitude': -36.7257, 'longitude': 140.9956, 'confidence': 78, 'surface_temperature_celcius': 51, 'Producer_id': 'AQUA_Producer_02', 'Created_Date': datetime.datetime(2022, 1, 12, 19, 12), 'Date': '2022-01-12', 'Create_datetime_str': '2022-01-12 19:12:00', 'Geohash3': 'r1k', 'Geohash5': 'r1kr0'}, {'latitude': -36.6952, 'longitude': 144.7228, 'confidence': 84, 'surface_temperature_celcius': 57, 'Producer_id': 'TERRA_Producer_03', 'Created_Date': datetime.datetime(2022, 1, 12, 19, 12), 'Date': '2022-01-12', 'Create_datetime_str': '2022-01-12 19:12:00', 'Geohash3': 'r1q', 'Geohash5': 'r1qzj'}, {'latitude': -36.759, 'longitude': 144.158, 'confidence': 86, 'surface_temperature_celcius': 60, 'Producer_id': 'AQUA_Producer_02', 'Created_Date': datetime.datetime(2022, 1, 12, 0, 0), 'Date': '2022-01-12', 'Create_datetime_str': '2022-01-12 00:00:00', 'Geohash3': 'r1q', 'Geohash5': 'r1qwb'}, {'latitude': -35.7523, 'longitude': 143.8866, 'confidence': 85, 'surface_temperature_celcius': 59, 'Producer_id': 'TERRA_Producer_03', 'Created_Date': datetime.datetime(2022, 1, 12, 0, 0), 'Date': '2022-01-12', 'Create_datetime_str': '2022-01-12 00:00:00', 'Geohash3': 'r1w', 'Geohash5': 'r1wkd'}, {'latitude': -34.328, 'longitude': 141.5402, 'confidence': 78, 'surface_temperature_celcius': 58, 'Producer_id': 'AQUA_Producer_02', 'Created_Date': datetime.datetime(2022, 1, 12, 4, 48), 'Date': '2022-01-12', 'Create_datetime_str': '2022-01-12 04:48:00', 'Geohash3': 'r1u', 'Geohash5': 'r1uss'}, {'latitude': -36.9172, 'longitude': 142.0472, 'confidence': 71, 'surface_temperature_celcius': 45, 'Producer_id': 'TERRA_Producer_03', 'Created_Date': datetime.datetime(2022, 1, 12, 4, 48), 'Date': '2022-01-12', 'Create_datetime_str': '2022-01-12 04:48:00', 'Geohash3': 'r1m', 'Geohash5': 'r1mjb'}, {'latitude': -36.2825, 'longitude': 145.7491, 'confidence': 73, 'surface_temperature_celcius': 47, 'Producer_id': 'AQUA_Producer_02', 'Created_Date': datetime.datetime(2022, 1, 12, 9, 36), 'Date': '2022-01-12', 'Create_datetime_str': '2022-01-12 09:36:00', 'Geohash3': 'r1x', 'Geohash5': 'r1x9s'}, {'latitude': -34.8919, 'longitude': 142.0529, 'confidence': 75, 'surface_temperature_celcius': 49, 'Producer_id': 'TERRA_Producer_03', 'Created_Date': datetime.datetime(2022, 1, 12, 9, 36), 'Date': '2022-01-12', 'Create_datetime_str': '2022-01-12 09:36:00', 'Geohash3': 'r1v', 'Geohash5': 'r1v18'}, {'latitude': -36.272, 'longitude': 145.5501, 'confidence': 74, 'surface_temperature_celcius': 48, 'Producer_id': 'AQUA_Producer_02', 'Created_Date': datetime.datetime(2022, 1, 12, 14, 24), 'Date': '2022-01-12', 'Create_datetime_str': '2022-01-12 14:24:00', 'Geohash3': 'r1x', 'Geohash5': 'r1x98'}, {'latitude': -37.6198, 'longitude': 143.0357, 'confidence': 52, 'surface_temperature_celcius': 38, 'Producer_id': 'TERRA_Producer_03', 'Created_Date': datetime.datetime(2022, 1, 12, 14, 24), 'Date': '2022-01-12', 'Create_datetime_str': '2022-01-12 14:24:00', 'Geohash3': 'r1m', 'Geohash5': 'r1m9y'}]
# Same:  [{'latitude': -36.7257, 'longitude': 140.9956, 'confidence': 78, 'surface_temperature_celcius': 51, 'Producer_id': 'AQUA_Producer_02', 'Created_Date': datetime.datetime(2022, 1, 12, 19, 12), 'Date': '2022-01-12', 'Create_datetime_str': '2022-01-12 19:12:00', 'Geohash3': 'r1k', 'Geohash5': 'r1kr0'}]
# Same Geohash: [{'longitude': 140.9956, 'latitude': -36.7257, 'confidence': 78.0, 'surface_temperature': 51.0, 'Date': datetime.datetime(2022, 1, 12, 19, 12), 'Date_str': '2022-01-12', '_id': ObjectId('628a70ca25967c93f524f0f1')}]
# Climate_lst:  [{'station': 948703, 'date': '2022-01-14', 'air_temperature_celcius': 17, 'relative_humidity': 48.7, 'windspeed_knots': 10.5, 'max_wind_speed': 15.0, 'precitipation': None, 'GHI_w/m2': 147, 'geohash3': 'r33', 'Fire_Cause': 'other', '_id': ObjectId('628a70de25967c93f524f0f3')}]
# Hotspot_lst:  [{'latitude': -36.73, 'longitude': 143.935, 'confidence': 89, 'surface_temperature_celcius': 65, 'Producer_id': 'TERRA_Producer_03', 'Created_Date': datetime.datetime(2022, 1, 14, 14, 24), 'Date': '2022-01-14', 'Create_datetime_str': '2022-01-14 14:24:00', 'Geohash3': 'r1q', 'Geohash5': 'r1qr5'}, {'latitude': -37.1521, 'longitude': 148.9446, 'confidence': 66, 'surface_temperature_celcius': 46, 'Producer_id': 'AQUA_Producer_02', 'Created_Date': datetime.datetime(2022, 1, 14, 19, 12), 'Date': '2022-01-14', 'Create_datetime_str': '2022-01-14 19:12:00', 'Geohash3': 'r33', 'Geohash5': 'r33ut'}, {'latitude': -38.0605, 'longitude': 143.6358, 'confidence': 75, 'surface_temperature_celcius': 49, 'Producer_id': 'TERRA_Producer_03', 'Created_Date': datetime.datetime(2022, 1, 14, 19, 12), 'Date': '2022-01-14', 'Create_datetime_str': '2022-01-14 19:12:00', 'Geohash3': 'r1n', 'Geohash5': 'r1npk'}, {'latitude': -35.9225, 'longitude': 143.5451, 'confidence': 66, 'surface_temperature_celcius': 43, 'Producer_id': 'AQUA_Producer_02', 'Created_Date': datetime.datetime(2022, 1, 14, 0, 0), 'Date': '2022-01-14', 'Create_datetime_str': '2022-01-14 00:00:00', 'Geohash3': 'r1w', 'Geohash5': 'r1w5d'}, {'latitude': -37.4023, 'longitude': 147.0394, 'confidence': 59, 'surface_temperature_celcius': 56, 'Producer_id': 'TERRA_Producer_03', 'Created_Date': datetime.datetime(2022, 1, 14, 0, 0), 'Date': '2022-01-14', 'Create_datetime_str': '2022-01-14 00:00:00', 'Geohash3': 'r32', 'Geohash5': 'r32e1'}, {'latitude': -37.094, 'longitude': 141.8857, 'confidence': 83, 'surface_temperature_celcius': 57, 'Producer_id': 'AQUA_Producer_02', 'Created_Date': datetime.datetime(2022, 1, 14, 4, 48), 'Date': '2022-01-14', 'Create_datetime_str': '2022-01-14 04:48:00', 'Geohash3': 'r1k', 'Geohash5': 'r1kuu'}, {'latitude': -37.9373, 'longitude': 146.0744, 'confidence': 56, 'surface_temperature_celcius': 39, 'Producer_id': 'TERRA_Producer_03', 'Created_Date': datetime.datetime(2022, 1, 14, 4, 48), 'Date': '2022-01-14', 'Create_datetime_str': '2022-01-14 04:48:00', 'Geohash3': 'r1r', 'Geohash5': 'r1rbh'}, {'latitude': -37.665, 'longitude': 142.1339, 'confidence': 74, 'surface_temperature_celcius': 48, 'Producer_id': 'AQUA_Producer_02', 'Created_Date': datetime.datetime(2022, 1, 14, 9, 36), 'Date': '2022-01-14', 'Create_datetime_str': '2022-01-14 09:36:00', 'Geohash3': 'r1m', 'Geohash5': 'r1m1d'}, {'latitude': -37.4024, 'longitude': 145.5918, 'confidence': 79, 'surface_temperature_celcius': 52, 'Producer_id': 'TERRA_Producer_03', 'Created_Date': datetime.datetime(2022, 1, 14, 9, 36), 'Date': '2022-01-14', 'Create_datetime_str': '2022-01-14 09:36:00', 'Geohash3': 'r1r', 'Geohash5': 'r1re1'}, {'latitude': -37.9775, 'longitude': 143.5868, 'confidence': 61, 'surface_temperature_celcius': 41, 'Producer_id': 'AQUA_Producer_02', 'Created_Date': datetime.datetime(2022, 1, 14, 14, 24), 'Date': '2022-01-14', 'Create_datetime_str': '2022-01-14 14:24:00', 'Geohash3': 'r1n', 'Geohash5': 'r1npg'}]
# Same:  [{'latitude': -37.1521, 'longitude': 148.9446, 'confidence': 66, 'surface_temperature_celcius': 46, 'Producer_id': 'AQUA_Producer_02', 'Created_Date': datetime.datetime(2022, 1, 14, 19, 12), 'Date': '2022-01-14', 'Create_datetime_str': '2022-01-14 19:12:00', 'Geohash3': 'r33', 'Geohash5': 'r33ut'}]
# Same Geohash: [{'longitude': 148.9446, 'latitude': -37.1521, 'confidence': 66.0, 'surface_temperature': 46.0, 'Date': datetime.datetime(2022, 1, 14, 19, 12), 'Date_str': '2022-01-14', '_id': ObjectId('628a70de25967c93f524f0f4')}]
# Climate_lst:  [{'station': 948703, 'date': '2022-01-16', 'air_temperature_celcius': 15, 'relative_humidity': 48.1, 'windspeed_knots': 7.9, 'max_wind_speed': 12.0, 'precitipation': None, 'GHI_w/m2': 131, 'geohash3': 'r1s', 'Fire_Cause': 'other', '_id': ObjectId('628a70f225967c93f524f0f6')}]
# Hotspot_lst:  [{'latitude': -36.4489, 'longitude': 144.7685, 'confidence': 93, 'surface_temperature_celcius': 73, 'Producer_id': 'TERRA_Producer_03', 'Created_Date': datetime.datetime(2022, 1, 16, 14, 24), 'Date': '2022-01-16', 'Create_datetime_str': '2022-01-16 14:24:00', 'Geohash3': 'r1w', 'Geohash5': 'r1wbw'}, {'latitude': -36.7034, 'longitude': 141.6168, 'confidence': 71, 'surface_temperature_celcius': 46, 'Producer_id': 'AQUA_Producer_02', 'Created_Date': datetime.datetime(2022, 1, 16, 19, 12), 'Date': '2022-01-16', 'Create_datetime_str': '2022-01-16 19:12:00', 'Geohash3': 'r1k', 'Geohash5': 'r1kxn'}, {'latitude': -38.141, 'longitude': 143.183, 'confidence': 68, 'surface_temperature_celcius': 46, 'Producer_id': 'TERRA_Producer_03', 'Created_Date': datetime.datetime(2022, 1, 16, 19, 12), 'Date': '2022-01-16', 'Create_datetime_str': '2022-01-16 19:12:00', 'Geohash3': 'r1j', 'Geohash5': 'r1jz4'}, {'latitude': -36.2127, 'longitude': 141.4938, 'confidence': 78, 'surface_temperature_celcius': 51, 'Producer_id': 'AQUA_Producer_02', 'Created_Date': datetime.datetime(2022, 1, 16, 0, 0), 'Date': '2022-01-16', 'Create_datetime_str': '2022-01-16 00:00:00', 'Geohash3': 'r1s', 'Geohash5': 'r1s9g'}, {'latitude': -35.8055, 'longitude': 142.7428, 'confidence': 73, 'surface_temperature_celcius': 47, 'Producer_id': 'TERRA_Producer_03', 'Created_Date': datetime.datetime(2022, 1, 16, 0, 0), 'Date': '2022-01-16', 'Create_datetime_str': '2022-01-16 00:00:00', 'Geohash3': 'r1t', 'Geohash5': 'r1ts2'}, {'latitude': -36.4312, 'longitude': 143.9942, 'confidence': 71, 'surface_temperature_celcius': 46, 'Producer_id': 'AQUA_Producer_02', 'Created_Date': datetime.datetime(2022, 1, 16, 4, 48), 'Date': '2022-01-16', 'Create_datetime_str': '2022-01-16 04:48:00', 'Geohash3': 'r1w', 'Geohash5': 'r1w2s'}, {'latitude': -36.2936, 'longitude': 145.1053, 'confidence': 73, 'surface_temperature_celcius': 47, 'Producer_id': 'TERRA_Producer_03', 'Created_Date': datetime.datetime(2022, 1, 16, 4, 48), 'Date': '2022-01-16', 'Create_datetime_str': '2022-01-16 04:48:00', 'Geohash3': 'r1x', 'Geohash5': 'r1x1t'}, {'latitude': -37.594, 'longitude': 142.6933, 'confidence': 100, 'surface_temperature_celcius': 106, 'Producer_id': 'AQUA_Producer_02', 'Created_Date': datetime.datetime(2022, 1, 16, 9, 36), 'Date': '2022-01-16', 'Create_datetime_str': '2022-01-16 09:36:00', 'Geohash3': 'r1m', 'Geohash5': 'r1m6p'}, {'latitude': -37.7037, 'longitude': 142.3299, 'confidence': 62, 'surface_temperature_celcius': 41, 'Producer_id': 'TERRA_Producer_03', 'Created_Date': datetime.datetime(2022, 1, 16, 9, 36), 'Date': '2022-01-16', 'Create_datetime_str': '2022-01-16 09:36:00', 'Geohash3': 'r1m', 'Geohash5': 'r1m1w'}, {'latitude': -37.7129, 'longitude': 143.0307, 'confidence': 57, 'surface_temperature_celcius': 39, 'Producer_id': 'AQUA_Producer_02', 'Created_Date': datetime.datetime(2022, 1, 16, 14, 24), 'Date': '2022-01-16', 'Create_datetime_str': '2022-01-16 14:24:00', 'Geohash3': 'r1m', 'Geohash5': 'r1m9q'}]
# Same:  [{'latitude': -36.2127, 'longitude': 141.4938, 'confidence': 78, 'surface_temperature_celcius': 51, 'Producer_id': 'AQUA_Producer_02', 'Created_Date': datetime.datetime(2022, 1, 16, 0, 0), 'Date': '2022-01-16', 'Create_datetime_str': '2022-01-16 00:00:00', 'Geohash3': 'r1s', 'Geohash5': 'r1s9g'}]
# Same Geohash: [{'longitude': 141.4938, 'latitude': -36.2127, 'confidence': 78.0, 'surface_temperature': 51.0, 'Date': datetime.datetime(2022, 1, 16, 0, 0), 'Date_str': '2022-01-16', '_id': ObjectId('628a70f225967c93f524f0f7')}]
# Climate_lst:  [{'station': 948703, 'date': '2022-01-20', 'air_temperature_celcius': 14, 'relative_humidity': 49.9, 'windspeed_knots': 6.8, 'max_wind_speed': 15.9, 'precitipation': None, 'GHI_w/m2': 120, 'geohash3': 'r1w', 'Fire_Cause': 'other', '_id': ObjectId('628a711a25967c93f524f0fb')}]
# Hotspot_lst:  [{'latitude': -35.8768, 'longitude': 145.4627, 'confidence': 100, 'surface_temperature_celcius': 86, 'Producer_id': 'TERRA_Producer_03', 'Created_Date': datetime.datetime(2022, 1, 20, 14, 24), 'Date': '2022-01-20', 'Create_datetime_str': '2022-01-20 14:24:00', 'Geohash3': 'r1x', 'Geohash5': 'r1x7y'}, {'latitude': -37.3735, 'longitude': 145.8384, 'confidence': 100, 'surface_temperature_celcius': 95, 'Producer_id': 'AQUA_Producer_02', 'Created_Date': datetime.datetime(2022, 1, 20, 19, 12), 'Date': '2022-01-20', 'Create_datetime_str': '2022-01-20 19:12:00', 'Geohash3': 'r1r', 'Geohash5': 'r1req'}, {'latitude': -36.7652, 'longitude': 147.1289, 'confidence': 78, 'surface_temperature_celcius': 39, 'Producer_id': 'TERRA_Producer_03', 'Created_Date': datetime.datetime(2022, 1, 20, 19, 12), 'Date': '2022-01-20', 'Create_datetime_str': '2022-01-20 19:12:00', 'Geohash3': 'r32', 'Geohash5': 'r32wg'}, {'latitude': -36.6851, 'longitude': 141.6125, 'confidence': 71, 'surface_temperature_celcius': 46, 'Producer_id': 'AQUA_Producer_02', 'Created_Date': datetime.datetime(2022, 1, 20, 0, 0), 'Date': '2022-01-20', 'Create_datetime_str': '2022-01-20 00:00:00', 'Geohash3': 'r1k', 'Geohash5': 'r1kxq'}, {'latitude': -35.9124, 'longitude': 141.8639, 'confidence': 86, 'surface_temperature_celcius': 61, 'Producer_id': 'TERRA_Producer_03', 'Created_Date': datetime.datetime(2022, 1, 20, 0, 0), 'Date': '2022-01-20', 'Create_datetime_str': '2022-01-20 00:00:00', 'Geohash3': 'r1s', 'Geohash5': 'r1sgs'}, {'latitude': -36.7038, 'longitude': 141.8813, 'confidence': 70, 'surface_temperature_celcius': 45, 'Producer_id': 'AQUA_Producer_02', 'Created_Date': datetime.datetime(2022, 1, 20, 4, 48), 'Date': '2022-01-20', 'Create_datetime_str': '2022-01-20 04:48:00', 'Geohash3': 'r1k', 'Geohash5': 'r1kzh'}, {'latitude': -36.5741, 'longitude': 143.8891, 'confidence': 74, 'surface_temperature_celcius': 48, 'Producer_id': 'TERRA_Producer_03', 'Created_Date': datetime.datetime(2022, 1, 20, 4, 48), 'Date': '2022-01-20', 'Create_datetime_str': '2022-01-20 04:48:00', 'Geohash3': 'r1q', 'Geohash5': 'r1qrf'}, {'latitude': -37.7931, 'longitude': 148.385, 'confidence': 64, 'surface_temperature_celcius': 58, 'Producer_id': 'AQUA_Producer_02', 'Created_Date': datetime.datetime(2022, 1, 20, 9, 36), 'Date': '2022-01-20', 'Create_datetime_str': '2022-01-20 09:36:00', 'Geohash3': 'r33', 'Geohash5': 'r338b'}, {'latitude': -37.4508, 'longitude': 142.8859, 'confidence': 72, 'surface_temperature_celcius': 46, 'Producer_id': 'TERRA_Producer_03', 'Created_Date': datetime.datetime(2022, 1, 20, 9, 36), 'Date': '2022-01-20', 'Create_datetime_str': '2022-01-20 09:36:00', 'Geohash3': 'r1m', 'Geohash5': 'r1mdg'}, {'latitude': -36.3979, 'longitude': 144.749, 'confidence': 74, 'surface_temperature_celcius': 48, 'Producer_id': 'AQUA_Producer_02', 'Created_Date': datetime.datetime(2022, 1, 20, 14, 24), 'Date': '2022-01-20', 'Create_datetime_str': '2022-01-20 14:24:00', 'Geohash3': 'r1w', 'Geohash5': 'r1wbv'}]
# Same:  [{'latitude': -36.3979, 'longitude': 144.749, 'confidence': 74, 'surface_temperature_celcius': 48, 'Producer_id': 'AQUA_Producer_02', 'Created_Date': datetime.datetime(2022, 1, 20, 14, 24), 'Date': '2022-01-20', 'Create_datetime_str': '2022-01-20 14:24:00', 'Geohash3': 'r1w', 'Geohash5': 'r1wbv'}]
# Same Geohash: [{'longitude': 144.749, 'latitude': -36.3979, 'confidence': 74.0, 'surface_temperature': 48.0, 'Date': datetime.datetime(2022, 1, 20, 14, 24), 'Date_str': '2022-01-20', '_id': ObjectId('628a711a25967c93f524f0fc')}]
# Climate_lst:  [{'station': 948703, 'date': '2022-01-22', 'air_temperature_celcius': 28, 'relative_humidity': 58.4, 'windspeed_knots': 11.9, 'max_wind_speed': 18.1, 'precitipation': None, 'GHI_w/m2': 223, 'geohash3': 'r1q', 'Fire_Cause': 'natural', '_id': ObjectId('628a712e25967c93f524f0fe')}]
# Hotspot_lst:  [{'latitude': -35.0616, 'longitude': 141.4417, 'confidence': 93, 'surface_temperature_celcius': 73, 'Producer_id': 'TERRA_Producer_03', 'Created_Date': datetime.datetime(2022, 1, 22, 14, 24), 'Date': '2022-01-22', 'Create_datetime_str': '2022-01-22 14:24:00', 'Geohash3': 'r1u', 'Geohash5': 'r1u8d'}, {'latitude': -37.564, 'longitude': 147.99200000000002, 'confidence': 74, 'surface_temperature_celcius': 44, 'Producer_id': 'AQUA_Producer_02', 'Created_Date': datetime.datetime(2022, 1, 22, 19, 12), 'Date': '2022-01-22', 'Create_datetime_str': '2022-01-22 19:12:00', 'Geohash3': 'r33', 'Geohash5': 'r334r'}, {'latitude': -37.0745, 'longitude': 141.0692, 'confidence': 100, 'surface_temperature_celcius': 120, 'Producer_id': 'TERRA_Producer_03', 'Created_Date': datetime.datetime(2022, 1, 22, 19, 12), 'Date': '2022-01-22', 'Create_datetime_str': '2022-01-22 19:12:00', 'Geohash3': 'r1k', 'Geohash5': 'r1km4'}, {'latitude': -37.4984, 'longitude': 142.0686, 'confidence': 54, 'surface_temperature_celcius': 40, 'Producer_id': 'AQUA_Producer_02', 'Created_Date': datetime.datetime(2022, 1, 22, 0, 0), 'Date': '2022-01-22', 'Create_datetime_str': '2022-01-22 00:00:00', 'Geohash3': 'r1m', 'Geohash5': 'r1m48'}, {'latitude': -37.8011, 'longitude': 144.7343, 'confidence': 67, 'surface_temperature_celcius': 44, 'Producer_id': 'TERRA_Producer_03', 'Created_Date': datetime.datetime(2022, 1, 22, 0, 0), 'Date': '2022-01-22', 'Create_datetime_str': '2022-01-22 00:00:00', 'Geohash3': 'r1q', 'Geohash5': 'r1qbv'}, {'latitude': -37.3046, 'longitude': 143.5448, 'confidence': 93, 'surface_temperature_celcius': 72, 'Producer_id': 'AQUA_Producer_02', 'Created_Date': datetime.datetime(2022, 1, 22, 4, 48), 'Date': '2022-01-22', 'Create_datetime_str': '2022-01-22 04:48:00', 'Geohash3': 'r1q', 'Geohash5': 'r1q5f'}, {'latitude': -38.5484, 'longitude': 143.4804, 'confidence': 88, 'surface_temperature_celcius': 64, 'Producer_id': 'TERRA_Producer_03', 'Created_Date': datetime.datetime(2022, 1, 22, 4, 48), 'Date': '2022-01-22', 'Create_datetime_str': '2022-01-22 04:48:00', 'Geohash3': 'r1n', 'Geohash5': 'r1nh8'}, {'latitude': -35.4407, 'longitude': 142.3644, 'confidence': 57, 'surface_temperature_celcius': 35, 'Producer_id': 'AQUA_Producer_02', 'Created_Date': datetime.datetime(2022, 1, 22, 9, 36), 'Date': '2022-01-22', 'Create_datetime_str': '2022-01-22 09:36:00', 'Geohash3': 'r1t', 'Geohash5': 'r1tnr'}, {'latitude': -36.6535, 'longitude': 142.8771, 'confidence': 74, 'surface_temperature_celcius': 48, 'Producer_id': 'TERRA_Producer_03', 'Created_Date': datetime.datetime(2022, 1, 22, 9, 36), 'Date': '2022-01-22', 'Create_datetime_str': '2022-01-22 09:36:00', 'Geohash3': 'r1m', 'Geohash5': 'r1mx7'}, {'latitude': -37.3785, 'longitude': 145.6226, 'confidence': 77, 'surface_temperature_celcius': 50, 'Producer_id': 'AQUA_Producer_02', 'Created_Date': datetime.datetime(2022, 1, 22, 14, 24), 'Date': '2022-01-22', 'Create_datetime_str': '2022-01-22 14:24:00', 'Geohash3': 'r1r', 'Geohash5': 'r1re3'}]
# Same:  [{'latitude': -37.8011, 'longitude': 144.7343, 'confidence': 67, 'surface_temperature_celcius': 44, 'Producer_id': 'TERRA_Producer_03', 'Created_Date': datetime.datetime(2022, 1, 22, 0, 0), 'Date': '2022-01-22', 'Create_datetime_str': '2022-01-22 00:00:00', 'Geohash3': 'r1q', 'Geohash5': 'r1qbv'}, {'latitude': -37.3046, 'longitude': 143.5448, 'confidence': 93, 'surface_temperature_celcius': 72, 'Producer_id': 'AQUA_Producer_02', 'Created_Date': datetime.datetime(2022, 1, 22, 4, 48), 'Date': '2022-01-22', 'Create_datetime_str': '2022-01-22 04:48:00', 'Geohash3': 'r1q', 'Geohash5': 'r1q5f'}]
# Same Geohash: [{'longitude': 144.7343, 'latitude': -37.8011, 'confidence': 67.0, 'surface_temperature': 44.0, 'Date': datetime.datetime(2022, 1, 22, 0, 0), 'Date_str': '2022-01-22', '_id': ObjectId('628a712e25967c93f524f0ff')}, {'longitude': 143.5448, 'latitude': -37.3046, 'confidence': 93.0, 'surface_temperature': 72.0, 'Date': datetime.datetime(2022, 1, 22, 4, 48), 'Date_str': '2022-01-22', '_id': ObjectId('628a712e25967c93f524f100')}]
# Climate_lst:  [{'station': 948703, 'date': '2022-01-23', 'air_temperature_celcius': 23, 'relative_humidity': 60.6, 'windspeed_knots': 10.1, 'max_wind_speed': 26.0, 'precitipation': None, 'GHI_w/m2': 180, 'geohash3': 'r1m', 'Fire_Cause': 'other', '_id': ObjectId('628a713825967c93f524f101')}]
# Hotspot_lst:  [{'latitude': -37.6857, 'longitude': 142.8532, 'confidence': 59, 'surface_temperature_celcius': 40, 'Producer_id': 'TERRA_Producer_03', 'Created_Date': datetime.datetime(2022, 1, 23, 14, 24), 'Date': '2022-01-23', 'Create_datetime_str': '2022-01-23 14:24:00', 'Geohash3': 'r1m', 'Geohash5': 'r1m9d'}, {'latitude': -36.1247, 'longitude': 145.1437, 'confidence': 71, 'surface_temperature_celcius': 46, 'Producer_id': 'AQUA_Producer_02', 'Created_Date': datetime.datetime(2022, 1, 23, 19, 12), 'Date': '2022-01-23', 'Create_datetime_str': '2022-01-23 19:12:00', 'Geohash3': 'r1x', 'Geohash5': 'r1x4q'}, {'latitude': -37.45, 'longitude': 148.097, 'confidence': 70, 'surface_temperature_celcius': 37, 'Producer_id': 'TERRA_Producer_03', 'Created_Date': datetime.datetime(2022, 1, 23, 19, 12), 'Date': '2022-01-23', 'Create_datetime_str': '2022-01-23 19:12:00', 'Geohash3': 'r33', 'Geohash5': 'r336f'}, {'latitude': -37.4169, 'longitude': 145.5926, 'confidence': 89, 'surface_temperature_celcius': 64, 'Producer_id': 'AQUA_Producer_02', 'Created_Date': datetime.datetime(2022, 1, 23, 0, 0), 'Date': '2022-01-23', 'Create_datetime_str': '2022-01-23 00:00:00', 'Geohash3': 'r1r', 'Geohash5': 'r1re1'}, {'latitude': -38.0866, 'longitude': 143.9534, 'confidence': 96, 'surface_temperature_celcius': 78, 'Producer_id': 'TERRA_Producer_03', 'Created_Date': datetime.datetime(2022, 1, 23, 0, 0), 'Date': '2022-01-23', 'Create_datetime_str': '2022-01-23 00:00:00', 'Geohash3': 'r1n', 'Geohash5': 'r1nr7'}, {'latitude': -38.0674, 'longitude': 142.965, 'confidence': 91, 'surface_temperature_celcius': 68, 'Producer_id': 'AQUA_Producer_02', 'Created_Date': datetime.datetime(2022, 1, 23, 4, 48), 'Date': '2022-01-23', 'Create_datetime_str': '2022-01-23 04:48:00', 'Geohash3': 'r1j', 'Geohash5': 'r1jxm'}, {'latitude': -37.8167, 'longitude': 142.1718, 'confidence': 86, 'surface_temperature_celcius': 61, 'Producer_id': 'TERRA_Producer_03', 'Created_Date': datetime.datetime(2022, 1, 23, 4, 48), 'Date': '2022-01-23', 'Create_datetime_str': '2022-01-23 04:48:00', 'Geohash3': 'r1m', 'Geohash5': 'r1m0g'}, {'latitude': -37.7972, 'longitude': 143.1153, 'confidence': 64, 'surface_temperature_celcius': 42, 'Producer_id': 'AQUA_Producer_02', 'Created_Date': datetime.datetime(2022, 1, 23, 9, 36), 'Date': '2022-01-23', 'Create_datetime_str': '2022-01-23 09:36:00', 'Geohash3': 'r1m', 'Geohash5': 'r1mbb'}, {'latitude': -36.543, 'longitude': 141.138, 'confidence': 72, 'surface_temperature_celcius': 48, 'Producer_id': 'TERRA_Producer_03', 'Created_Date': datetime.datetime(2022, 1, 23, 9, 36), 'Date': '2022-01-23', 'Create_datetime_str': '2022-01-23 09:36:00', 'Geohash3': 'r1s', 'Geohash5': 'r1s25'}, {'latitude': -36.6732, 'longitude': 142.5162, 'confidence': 79, 'surface_temperature_celcius': 52, 'Producer_id': 'AQUA_Producer_02', 'Created_Date': datetime.datetime(2022, 1, 23, 14, 24), 'Date': '2022-01-23', 'Create_datetime_str': '2022-01-23 14:24:00', 'Geohash3': 'r1m', 'Geohash5': 'r1mr7'}]
# Same:  [{'latitude': -37.6857, 'longitude': 142.8532, 'confidence': 59, 'surface_temperature_celcius': 40, 'Producer_id': 'TERRA_Producer_03', 'Created_Date': datetime.datetime(2022, 1, 23, 14, 24), 'Date': '2022-01-23', 'Create_datetime_str': '2022-01-23 14:24:00', 'Geohash3': 'r1m', 'Geohash5': 'r1m9d'}, {'latitude': -37.8167, 'longitude': 142.1718, 'confidence': 86, 'surface_temperature_celcius': 61, 'Producer_id': 'TERRA_Producer_03', 'Created_Date': datetime.datetime(2022, 1, 23, 4, 48), 'Date': '2022-01-23', 'Create_datetime_str': '2022-01-23 04:48:00', 'Geohash3': 'r1m', 'Geohash5': 'r1m0g'}, {'latitude': -37.7972, 'longitude': 143.1153, 'confidence': 64, 'surface_temperature_celcius': 42, 'Producer_id': 'AQUA_Producer_02', 'Created_Date': datetime.datetime(2022, 1, 23, 9, 36), 'Date': '2022-01-23', 'Create_datetime_str': '2022-01-23 09:36:00', 'Geohash3': 'r1m', 'Geohash5': 'r1mbb'}, {'latitude': -36.6732, 'longitude': 142.5162, 'confidence': 79, 'surface_temperature_celcius': 52, 'Producer_id': 'AQUA_Producer_02', 'Created_Date': datetime.datetime(2022, 1, 23, 14, 24), 'Date': '2022-01-23', 'Create_datetime_str': '2022-01-23 14:24:00', 'Geohash3': 'r1m', 'Geohash5': 'r1mr7'}]
# Same Geohash: [{'longitude': 142.8532, 'latitude': -37.6857, 'confidence': 59.0, 'surface_temperature': 40.0, 'Date': datetime.datetime(2022, 1, 23, 14, 24), 'Date_str': '2022-01-23', '_id': ObjectId('628a713825967c93f524f102')}, {'longitude': 142.1718, 'latitude': -37.8167, 'confidence': 86.0, 'surface_temperature': 61.0, 'Date': datetime.datetime(2022, 1, 23, 4, 48), 'Date_str': '2022-01-23', '_id': ObjectId('628a713825967c93f524f103')}, {'longitude': 143.1153, 'latitude': -37.7972, 'confidence': 64.0, 'surface_temperature': 42.0, 'Date': datetime.datetime(2022, 1, 23, 9, 36), 'Date_str': '2022-01-23', '_id': ObjectId('628a713825967c93f524f104')}, {'longitude': 142.5162, 'latitude': -36.6732, 'confidence': 79.0, 'surface_temperature': 52.0, 'Date': datetime.datetime(2022, 1, 23, 14, 24), 'Date_str': '2022-01-23', '_id': ObjectId('628a713825967c93f524f105')}]
# Climate_lst:  [{'station': 948703, 'date': '2022-01-24', 'air_temperature_celcius': 11, 'relative_humidity': 40.5, 'windspeed_knots': 13.4, 'max_wind_speed': 26.0, 'precitipation': None, 'GHI_w/m2': 102, 'geohash3': 'r33', 'Fire_Cause': 'other', '_id': ObjectId('628a714225967c93f524f106')}]
# Hotspot_lst:  [{'latitude': -37.475, 'longitude': 148.134, 'confidence': 59, 'surface_temperature_celcius': 40, 'Producer_id': 'TERRA_Producer_03', 'Created_Date': datetime.datetime(2022, 1, 24, 14, 24), 'Date': '2022-01-24', 'Create_datetime_str': '2022-01-24 14:24:00', 'Geohash3': 'r33', 'Geohash5': 'r336f'}, {'latitude': -36.018, 'longitude': 143.2048, 'confidence': 85, 'surface_temperature_celcius': 60, 'Producer_id': 'AQUA_Producer_02', 'Created_Date': datetime.datetime(2022, 1, 24, 19, 12), 'Date': '2022-01-24', 'Create_datetime_str': '2022-01-24 19:12:00', 'Geohash3': 'r1t', 'Geohash5': 'r1tg4'}, {'latitude': -36.0885, 'longitude': 145.0359, 'confidence': 95, 'surface_temperature_celcius': 76, 'Producer_id': 'TERRA_Producer_03', 'Created_Date': datetime.datetime(2022, 1, 24, 19, 12), 'Date': '2022-01-24', 'Create_datetime_str': '2022-01-24 19:12:00', 'Geohash3': 'r1x', 'Geohash5': 'r1x4s'}, {'latitude': -36.4399, 'longitude': 141.0914, 'confidence': 59, 'surface_temperature_celcius': 40, 'Producer_id': 'AQUA_Producer_02', 'Created_Date': datetime.datetime(2022, 1, 24, 0, 0), 'Date': '2022-01-24', 'Create_datetime_str': '2022-01-24 00:00:00', 'Geohash3': 'r1s', 'Geohash5': 'r1s2d'}, {'latitude': -36.2375, 'longitude': 143.4093, 'confidence': 82, 'surface_temperature_celcius': 55, 'Producer_id': 'TERRA_Producer_03', 'Created_Date': datetime.datetime(2022, 1, 24, 0, 0), 'Date': '2022-01-24', 'Create_datetime_str': '2022-01-24 00:00:00', 'Geohash3': 'r1t', 'Geohash5': 'r1tcz'}, {'latitude': -36.2257, 'longitude': 144.2904, 'confidence': 72, 'surface_temperature_celcius': 46, 'Producer_id': 'AQUA_Producer_02', 'Created_Date': datetime.datetime(2022, 1, 24, 4, 48), 'Date': '2022-01-24', 'Create_datetime_str': '2022-01-24 04:48:00', 'Geohash3': 'r1w', 'Geohash5': 'r1w9g'}, {'latitude': -36.5234, 'longitude': 145.4642, 'confidence': 79, 'surface_temperature_celcius': 52, 'Producer_id': 'TERRA_Producer_03', 'Created_Date': datetime.datetime(2022, 1, 24, 4, 48), 'Date': '2022-01-24', 'Create_datetime_str': '2022-01-24 04:48:00', 'Geohash3': 'r1x', 'Geohash5': 'r1x2n'}, {'latitude': -36.3661, 'longitude': 145.8545, 'confidence': 83, 'surface_temperature_celcius': 56, 'Producer_id': 'AQUA_Producer_02', 'Created_Date': datetime.datetime(2022, 1, 24, 9, 36), 'Date': '2022-01-24', 'Create_datetime_str': '2022-01-24 09:36:00', 'Geohash3': 'r1x', 'Geohash5': 'r1x9p'}, {'latitude': -37.4429, 'longitude': 142.8928, 'confidence': 86, 'surface_temperature_celcius': 60, 'Producer_id': 'TERRA_Producer_03', 'Created_Date': datetime.datetime(2022, 1, 24, 9, 36), 'Date': '2022-01-24', 'Create_datetime_str': '2022-01-24 09:36:00', 'Geohash3': 'r1m', 'Geohash5': 'r1mdg'}, {'latitude': -37.6953, 'longitude': 143.0704, 'confidence': 59, 'surface_temperature_celcius': 40, 'Producer_id': 'AQUA_Producer_02', 'Created_Date': datetime.datetime(2022, 1, 24, 14, 24), 'Date': '2022-01-24', 'Create_datetime_str': '2022-01-24 14:24:00', 'Geohash3': 'r1m', 'Geohash5': 'r1m9x'}]
# Same:  [{'latitude': -37.475, 'longitude': 148.134, 'confidence': 59, 'surface_temperature_celcius': 40, 'Producer_id': 'TERRA_Producer_03', 'Created_Date': datetime.datetime(2022, 1, 24, 14, 24), 'Date': '2022-01-24', 'Create_datetime_str': '2022-01-24 14:24:00', 'Geohash3': 'r33', 'Geohash5': 'r336f'}]
# Same Geohash: [{'longitude': 148.134, 'latitude': -37.475, 'confidence': 59.0, 'surface_temperature': 40.0, 'Date': datetime.datetime(2022, 1, 24, 14, 24), 'Date_str': '2022-01-24', '_id': ObjectId('628a714225967c93f524f107')}]
# Climate_lst:  [{'station': 948703, 'date': '2022-01-27', 'air_temperature_celcius': 15, 'relative_humidity': 56.1, 'windspeed_knots': 5.1, 'max_wind_speed': 9.9, 'precitipation': None, 'GHI_w/m2': 122, 'geohash3': 'r1w', 'Fire_Cause': 'other', '_id': ObjectId('628a716025967c93f524f10a')}]
# Hotspot_lst:  [{'latitude': -37.5052, 'longitude': 142.8636, 'confidence': 62, 'surface_temperature_celcius': 54, 'Producer_id': 'TERRA_Producer_03', 'Created_Date': datetime.datetime(2022, 1, 27, 14, 24), 'Date': '2022-01-27', 'Create_datetime_str': '2022-01-27 14:24:00', 'Geohash3': 'r1m', 'Geohash5': 'r1mdd'}, {'latitude': -36.5399, 'longitude': 144.678, 'confidence': 90, 'surface_temperature_celcius': 66, 'Producer_id': 'AQUA_Producer_02', 'Created_Date': datetime.datetime(2022, 1, 27, 19, 12), 'Date': '2022-01-27', 'Create_datetime_str': '2022-01-27 19:12:00', 'Geohash3': 'r1w', 'Geohash5': 'r1wbh'}, {'latitude': -37.9004, 'longitude': 141.0921, 'confidence': 68, 'surface_temperature_celcius': 44, 'Producer_id': 'TERRA_Producer_03', 'Created_Date': datetime.datetime(2022, 1, 27, 19, 12), 'Date': '2022-01-27', 'Create_datetime_str': '2022-01-27 19:12:00', 'Geohash3': 'r1k', 'Geohash5': 'r1k26'}, {'latitude': -36.9348, 'longitude': 143.09799999999998, 'confidence': 87, 'surface_temperature_celcius': 117, 'Producer_id': 'AQUA_Producer_02', 'Created_Date': datetime.datetime(2022, 1, 27, 0, 0), 'Date': '2022-01-27', 'Create_datetime_str': '2022-01-27 00:00:00', 'Geohash3': 'r1m', 'Geohash5': 'r1mvb'}, {'latitude': -36.6962, 'longitude': 145.2642, 'confidence': 84, 'surface_temperature_celcius': 58, 'Producer_id': 'TERRA_Producer_03', 'Created_Date': datetime.datetime(2022, 1, 27, 0, 0), 'Date': '2022-01-27', 'Create_datetime_str': '2022-01-27 00:00:00', 'Geohash3': 'r1r', 'Geohash5': 'r1rr1'}, {'latitude': -36.5607, 'longitude': 144.1913, 'confidence': 80, 'surface_temperature_celcius': 53, 'Producer_id': 'AQUA_Producer_02', 'Created_Date': datetime.datetime(2022, 1, 27, 4, 48), 'Date': '2022-01-27', 'Create_datetime_str': '2022-01-27 04:48:00', 'Geohash3': 'r1w', 'Geohash5': 'r1w81'}, {'latitude': -37.7893, 'longitude': 142.7953, 'confidence': 58, 'surface_temperature_celcius': 40, 'Producer_id': 'TERRA_Producer_03', 'Created_Date': datetime.datetime(2022, 1, 27, 4, 48), 'Date': '2022-01-27', 'Create_datetime_str': '2022-01-27 04:48:00', 'Geohash3': 'r1m', 'Geohash5': 'r1m91'}, {'latitude': -36.7422, 'longitude': 141.8511, 'confidence': 66, 'surface_temperature_celcius': 48, 'Producer_id': 'AQUA_Producer_02', 'Created_Date': datetime.datetime(2022, 1, 27, 9, 36), 'Date': '2022-01-27', 'Create_datetime_str': '2022-01-27 09:36:00', 'Geohash3': 'r1k', 'Geohash5': 'r1kyg'}, {'latitude': -36.8867, 'longitude': 142.1873, 'confidence': 90, 'surface_temperature_celcius': 66, 'Producer_id': 'TERRA_Producer_03', 'Created_Date': datetime.datetime(2022, 1, 27, 9, 36), 'Date': '2022-01-27', 'Create_datetime_str': '2022-01-27 09:36:00', 'Geohash3': 'r1m', 'Geohash5': 'r1mn5'}, {'latitude': -37.583, 'longitude': 149.316, 'confidence': 100, 'surface_temperature_celcius': 49, 'Producer_id': 'AQUA_Producer_02', 'Created_Date': datetime.datetime(2022, 1, 27, 14, 24), 'Date': '2022-01-27', 'Create_datetime_str': '2022-01-27 14:24:00', 'Geohash3': 'r36', 'Geohash5': 'r364j'}]
# Same:  [{'latitude': -36.5399, 'longitude': 144.678, 'confidence': 90, 'surface_temperature_celcius': 66, 'Producer_id': 'AQUA_Producer_02', 'Created_Date': datetime.datetime(2022, 1, 27, 19, 12), 'Date': '2022-01-27', 'Create_datetime_str': '2022-01-27 19:12:00', 'Geohash3': 'r1w', 'Geohash5': 'r1wbh'}, {'latitude': -36.5607, 'longitude': 144.1913, 'confidence': 80, 'surface_temperature_celcius': 53, 'Producer_id': 'AQUA_Producer_02', 'Created_Date': datetime.datetime(2022, 1, 27, 4, 48), 'Date': '2022-01-27', 'Create_datetime_str': '2022-01-27 04:48:00', 'Geohash3': 'r1w', 'Geohash5': 'r1w81'}]
# Same Geohash: [{'longitude': 144.678, 'latitude': -36.5399, 'confidence': 90.0, 'surface_temperature': 66.0, 'Date': datetime.datetime(2022, 1, 27, 19, 12), 'Date_str': '2022-01-27', '_id': ObjectId('628a716025967c93f524f10b')}, {'longitude': 144.1913, 'latitude': -36.5607, 'confidence': 80.0, 'surface_temperature': 53.0, 'Date': datetime.datetime(2022, 1, 27, 4, 48), 'Date_str': '2022-01-27', '_id': ObjectId('628a716025967c93f524f10c')}]
# Climate_lst:  [{'station': 948703, 'date': '2022-01-28', 'air_temperature_celcius': 10, 'relative_humidity': 43.6, 'windspeed_knots': 9.7, 'max_wind_speed': 14.0, 'precitipation': None, 'GHI_w/m2': 90, 'geohash3': 'r1x', 'Fire_Cause': 'other', '_id': ObjectId('628a716a25967c93f524f10d')}]
# Hotspot_lst:  [{'latitude': -37.4551, 'longitude': 143.7902, 'confidence': 76, 'surface_temperature_celcius': 49, 'Producer_id': 'TERRA_Producer_03', 'Created_Date': datetime.datetime(2022, 1, 28, 14, 24), 'Date': '2022-01-28', 'Create_datetime_str': '2022-01-28 14:24:00', 'Geohash3': 'r1q', 'Geohash5': 'r1q6b'}, {'latitude': -37.597, 'longitude': 143.0741, 'confidence': 52, 'surface_temperature_celcius': 38, 'Producer_id': 'AQUA_Producer_02', 'Created_Date': datetime.datetime(2022, 1, 28, 19, 12), 'Date': '2022-01-28', 'Create_datetime_str': '2022-01-28 19:12:00', 'Geohash3': 'r1m', 'Geohash5': 'r1mdp'}, {'latitude': -36.2306, 'longitude': 143.6408, 'confidence': 93, 'surface_temperature_celcius': 72, 'Producer_id': 'TERRA_Producer_03', 'Created_Date': datetime.datetime(2022, 1, 28, 19, 12), 'Date': '2022-01-28', 'Create_datetime_str': '2022-01-28 19:12:00', 'Geohash3': 'r1w', 'Geohash5': 'r1w1u'}, {'latitude': -36.2538, 'longitude': 145.5929, 'confidence': 63, 'surface_temperature_celcius': 42, 'Producer_id': 'AQUA_Producer_02', 'Created_Date': datetime.datetime(2022, 1, 28, 0, 0), 'Date': '2022-01-28', 'Create_datetime_str': '2022-01-28 00:00:00', 'Geohash3': 'r1x', 'Geohash5': 'r1x9c'}, {'latitude': -35.6453, 'longitude': 142.387, 'confidence': 91, 'surface_temperature_celcius': 69, 'Producer_id': 'TERRA_Producer_03', 'Created_Date': datetime.datetime(2022, 1, 28, 0, 0), 'Date': '2022-01-28', 'Create_datetime_str': '2022-01-28 00:00:00', 'Geohash3': 'r1t', 'Geohash5': 'r1tm0'}, {'latitude': -36.748000000000005, 'longitude': 144.168, 'confidence': 62, 'surface_temperature_celcius': 44, 'Producer_id': 'AQUA_Producer_02', 'Created_Date': datetime.datetime(2022, 1, 28, 4, 48), 'Date': '2022-01-28', 'Create_datetime_str': '2022-01-28 04:48:00', 'Geohash3': 'r1q', 'Geohash5': 'r1qwb'}, {'latitude': -37.2627, 'longitude': 141.8114, 'confidence': 70, 'surface_temperature_celcius': 45, 'Producer_id': 'TERRA_Producer_03', 'Created_Date': datetime.datetime(2022, 1, 28, 4, 48), 'Date': '2022-01-28', 'Create_datetime_str': '2022-01-28 04:48:00', 'Geohash3': 'r1k', 'Geohash5': 'r1ku4'}, {'latitude': -35.7937, 'longitude': 143.195, 'confidence': 68, 'surface_temperature_celcius': 44, 'Producer_id': 'AQUA_Producer_02', 'Created_Date': datetime.datetime(2022, 1, 28, 9, 36), 'Date': '2022-01-28', 'Create_datetime_str': '2022-01-28 09:36:00', 'Geohash3': 'r1t', 'Geohash5': 'r1tu6'}, {'latitude': -36.3477, 'longitude': 144.533, 'confidence': 86, 'surface_temperature_celcius': 41, 'Producer_id': 'TERRA_Producer_03', 'Created_Date': datetime.datetime(2022, 1, 28, 9, 36), 'Date': '2022-01-28', 'Create_datetime_str': '2022-01-28 09:36:00', 'Geohash3': 'r1w', 'Geohash5': 'r1wc0'}, {'latitude': -37.2142, 'longitude': 148.822, 'confidence': 55, 'surface_temperature_celcius': 39, 'Producer_id': 'AQUA_Producer_02', 'Created_Date': datetime.datetime(2022, 1, 28, 14, 24), 'Date': '2022-01-28', 'Create_datetime_str': '2022-01-28 14:24:00', 'Geohash3': 'r33', 'Geohash5': 'r33u6'}]
# Same:  [{'latitude': -36.2538, 'longitude': 145.5929, 'confidence': 63, 'surface_temperature_celcius': 42, 'Producer_id': 'AQUA_Producer_02', 'Created_Date': datetime.datetime(2022, 1, 28, 0, 0), 'Date': '2022-01-28', 'Create_datetime_str': '2022-01-28 00:00:00', 'Geohash3': 'r1x', 'Geohash5': 'r1x9c'}]
# Same Geohash: [{'longitude': 145.5929, 'latitude': -36.2538, 'confidence': 63.0, 'surface_temperature': 42.0, 'Date': datetime.datetime(2022, 1, 28, 0, 0), 'Date_str': '2022-01-28', '_id': ObjectId('628a716a25967c93f524f10e')}]
# Climate_lst:  [{'station': 948703, 'date': '2022-02-01', 'air_temperature_celcius': 12, 'relative_humidity': 44.2, 'windspeed_knots': 6.2, 'max_wind_speed': 15.0, 'precitipation': None, 'GHI_w/m2': 108, 'geohash3': 'r1m', 'Fire_Cause': 'other', '_id': ObjectId('628a719225967c93f524f112')}]
# Hotspot_lst:  [{'latitude': -37.522, 'longitude': 143.3874, 'confidence': 71, 'surface_temperature_celcius': 73, 'Producer_id': 'TERRA_Producer_03', 'Created_Date': datetime.datetime(2022, 2, 1, 14, 24), 'Date': '2022-02-01', 'Create_datetime_str': '2022-02-01 14:24:00', 'Geohash3': 'r1m', 'Geohash5': 'r1mfw'}, {'latitude': -37.4988, 'longitude': 143.1458, 'confidence': 85, 'surface_temperature_celcius': 59, 'Producer_id': 'AQUA_Producer_02', 'Created_Date': datetime.datetime(2022, 2, 1, 19, 12), 'Date': '2022-02-01', 'Create_datetime_str': '2022-02-01 19:12:00', 'Geohash3': 'r1m', 'Geohash5': 'r1mf9'}, {'latitude': -36.0856, 'longitude': 144.233, 'confidence': 73, 'surface_temperature_celcius': 47, 'Producer_id': 'TERRA_Producer_03', 'Created_Date': datetime.datetime(2022, 2, 1, 19, 12), 'Date': '2022-02-01', 'Create_datetime_str': '2022-02-01 19:12:00', 'Geohash3': 'r1w', 'Geohash5': 'r1wdd'}, {'latitude': -36.3326, 'longitude': 142.8706, 'confidence': 74, 'surface_temperature_celcius': 47, 'Producer_id': 'AQUA_Producer_02', 'Created_Date': datetime.datetime(2022, 2, 1, 0, 0), 'Date': '2022-02-01', 'Create_datetime_str': '2022-02-01 00:00:00', 'Geohash3': 'r1t', 'Geohash5': 'r1t97'}, {'latitude': -36.7721, 'longitude': 142.4219, 'confidence': 62, 'surface_temperature_celcius': 46, 'Producer_id': 'TERRA_Producer_03', 'Created_Date': datetime.datetime(2022, 2, 1, 0, 0), 'Date': '2022-02-01', 'Create_datetime_str': '2022-02-01 00:00:00', 'Geohash3': 'r1m', 'Geohash5': 'r1mqb'}, {'latitude': -38.5123, 'longitude': 146.4007, 'confidence': 100, 'surface_temperature_celcius': 89, 'Producer_id': 'AQUA_Producer_02', 'Created_Date': datetime.datetime(2022, 2, 1, 4, 48), 'Date': '2022-02-01', 'Create_datetime_str': '2022-02-01 04:48:00', 'Geohash3': 'r30', 'Geohash5': 'r30hg'}, {'latitude': -37.8323, 'longitude': 147.2232, 'confidence': 84, 'surface_temperature_celcius': 68, 'Producer_id': 'TERRA_Producer_03', 'Created_Date': datetime.datetime(2022, 2, 1, 4, 48), 'Date': '2022-02-01', 'Create_datetime_str': '2022-02-01 04:48:00', 'Geohash3': 'r32', 'Geohash5': 'r328y'}, {'latitude': -37.7836, 'longitude': 143.9688, 'confidence': 58, 'surface_temperature_celcius': 40, 'Producer_id': 'AQUA_Producer_02', 'Created_Date': datetime.datetime(2022, 2, 1, 9, 36), 'Date': '2022-02-01', 'Create_datetime_str': '2022-02-01 09:36:00', 'Geohash3': 'r1q', 'Geohash5': 'r1q3h'}, {'latitude': -36.4061, 'longitude': 143.0987, 'confidence': 64, 'surface_temperature_celcius': 42, 'Producer_id': 'TERRA_Producer_03', 'Created_Date': datetime.datetime(2022, 2, 1, 9, 36), 'Date': '2022-02-01', 'Create_datetime_str': '2022-02-01 09:36:00', 'Geohash3': 'r1t', 'Geohash5': 'r1tbb'}, {'latitude': -37.253, 'longitude': 144.3681, 'confidence': 96, 'surface_temperature_celcius': 78, 'Producer_id': 'AQUA_Producer_02', 'Created_Date': datetime.datetime(2022, 2, 1, 14, 24), 'Date': '2022-02-01', 'Create_datetime_str': '2022-02-01 14:24:00', 'Geohash3': 'r1q', 'Geohash5': 'r1qsj'}]
# Same:  [{'latitude': -37.522, 'longitude': 143.3874, 'confidence': 71, 'surface_temperature_celcius': 73, 'Producer_id': 'TERRA_Producer_03', 'Created_Date': datetime.datetime(2022, 2, 1, 14, 24), 'Date': '2022-02-01', 'Create_datetime_str': '2022-02-01 14:24:00', 'Geohash3': 'r1m', 'Geohash5': 'r1mfw'}, {'latitude': -37.4988, 'longitude': 143.1458, 'confidence': 85, 'surface_temperature_celcius': 59, 'Producer_id': 'AQUA_Producer_02', 'Created_Date': datetime.datetime(2022, 2, 1, 19, 12), 'Date': '2022-02-01', 'Create_datetime_str': '2022-02-01 19:12:00', 'Geohash3': 'r1m', 'Geohash5': 'r1mf9'}, {'latitude': -36.7721, 'longitude': 142.4219, 'confidence': 62, 'surface_temperature_celcius': 46, 'Producer_id': 'TERRA_Producer_03', 'Created_Date': datetime.datetime(2022, 2, 1, 0, 0), 'Date': '2022-02-01', 'Create_datetime_str': '2022-02-01 00:00:00', 'Geohash3': 'r1m', 'Geohash5': 'r1mqb'}]
# Same Geohash: [{'longitude': 143.3874, 'latitude': -37.522, 'confidence': 71.0, 'surface_temperature': 73.0, 'Date': datetime.datetime(2022, 2, 1, 14, 24), 'Date_str': '2022-02-01', '_id': ObjectId('628a719225967c93f524f113')}, {'longitude': 143.1458, 'latitude': -37.4988, 'confidence': 85.0, 'surface_temperature': 59.0, 'Date': datetime.datetime(2022, 2, 1, 19, 12), 'Date_str': '2022-02-01', '_id': ObjectId('628a719225967c93f524f114')}, {'longitude': 142.4219, 'latitude': -36.7721, 'confidence': 62.0, 'surface_temperature': 46.0, 'Date': datetime.datetime(2022, 2, 1, 0, 0), 'Date_str': '2022-02-01', '_id': ObjectId('628a719225967c93f524f115')}]
# Climate_lst:  [{'station': 948703, 'date': '2022-02-02', 'air_temperature_celcius': 14, 'relative_humidity': 52.8, 'windspeed_knots': 9.3, 'max_wind_speed': 18.1, 'precitipation': None, 'GHI_w/m2': 117, 'geohash3': 'r1k', 'Fire_Cause': 'other', '_id': ObjectId('628a719c25967c93f524f116')}]
# ...
# Same:  [{'latitude': -36.931999999999995, 'longitude': 141.9456, 'confidence': 79, 'surface_temperature_celcius': 53, 'Producer_id': 'AQUA_Producer_02', 'Created_Date': datetime.datetime(2022, 3, 6, 0, 0), 'Date': '2022-03-06', 'Create_datetime_str': '2022-03-06 00:00:00', 'Geohash3': 'r1k', 'Geohash5': 'r1kvy'}, {'latitude': -36.7806, 'longitude': 141.5597, 'confidence': 94, 'surface_temperature_celcius': 74, 'Producer_id': 'AQUA_Producer_02', 'Created_Date': datetime.datetime(2022, 3, 6, 9, 36), 'Date': '2022-03-06', 'Create_datetime_str': '2022-03-06 09:36:00', 'Geohash3': 'r1k', 'Geohash5': 'r1kwv'}, {'latitude': -36.7791, 'longitude': 141.5711, 'confidence': 72, 'surface_temperature_celcius': 46, 'Producer_id': 'AQUA_Producer_02', 'Created_Date': datetime.datetime(2022, 3, 6, 14, 24), 'Date': '2022-03-06', 'Create_datetime_str': '2022-03-06 14:24:00', 'Geohash3': 'r1k', 'Geohash5': 'r1kwv'}]
# Same Geohash: [{'longitude': 141.9456, 'latitude': -36.931999999999995, 'confidence': 79.0, 'surface_temperature': 53.0, 'Date': datetime.datetime(2022, 3, 6, 0, 0), 'Date_str': '2022-03-06', '_id': ObjectId('628a72dc25967c93f524f151')}, {'longitude': 141.5597, 'latitude': -36.7806, 'confidence': 83.0, 'surface_temperature': 60.0, 'Date': datetime.datetime(2022, 3, 6, 9, 36), 'Date_str': '2022-03-06', '_id': ObjectId('628a72dc25967c93f524f152')}]
# Climate_lst:  [{'station': 948703, 'date': '2022-03-07', 'air_temperature_celcius': 18, 'relative_humidity': 55.6, 'windspeed_knots': 8.2, 'max_wind_speed': 12.0, 'precitipation': None, 'GHI_w/m2': 147, 'geohash3': 'r1w', 'Fire_Cause': 'other', '_id': ObjectId('628a72f025967c93f524f153')}]
# Hotspot_lst:  [{'latitude': -36.8241, 'longitude': 145.1274, 'confidence': 56, 'surface_temperature_celcius': 39, 'Producer_id': 'TERRA_Producer_03', 'Created_Date': datetime.datetime(2022, 3, 7, 14, 24), 'Date': '2022-03-07', 'Create_datetime_str': '2022-03-07 14:24:00', 'Geohash3': 'r1r', 'Geohash5': 'r1rnw'}, {'latitude': -36.8741, 'longitude': 143.91, 'confidence': 71, 'surface_temperature_celcius': 45, 'Producer_id': 'AQUA_Producer_02', 'Created_Date': datetime.datetime(2022, 3, 7, 19, 12), 'Date': '2022-03-07', 'Create_datetime_str': '2022-03-07 19:12:00', 'Geohash3': 'r1q', 'Geohash5': 'r1qq4'}, {'latitude': -36.8986, 'longitude': 141.6385, 'confidence': 72, 'surface_temperature_celcius': 52, 'Producer_id': 'TERRA_Producer_03', 'Created_Date': datetime.datetime(2022, 3, 7, 19, 12), 'Date': '2022-03-07', 'Create_datetime_str': '2022-03-07 19:12:00', 'Geohash3': 'r1k', 'Geohash5': 'r1kwp'}, {'latitude': -36.5722, 'longitude': 146.7572, 'confidence': 85, 'surface_temperature_celcius': 59, 'Producer_id': 'AQUA_Producer_02', 'Created_Date': datetime.datetime(2022, 3, 7, 0, 0), 'Date': '2022-03-07', 'Create_datetime_str': '2022-03-07 00:00:00', 'Geohash3': 'r32', 'Geohash5': 'r32rg'}, {'latitude': -37.459, 'longitude': 142.9198, 'confidence': 54, 'surface_temperature_celcius': 39, 'Producer_id': 'TERRA_Producer_03', 'Created_Date': datetime.datetime(2022, 3, 7, 0, 0), 'Date': '2022-03-07', 'Create_datetime_str': '2022-03-07 00:00:00', 'Geohash3': 'r1m', 'Geohash5': 'r1mdu'}, {'latitude': -38.0771, 'longitude': 144.2044, 'confidence': 52, 'surface_temperature_celcius': 38, 'Producer_id': 'AQUA_Producer_02', 'Created_Date': datetime.datetime(2022, 3, 7, 4, 48), 'Date': '2022-03-07', 'Create_datetime_str': '2022-03-07 04:48:00', 'Geohash3': 'r1n', 'Geohash5': 'r1nx3'}, {'latitude': -36.1963, 'longitude': 145.194, 'confidence': 72, 'surface_temperature_celcius': 46, 'Producer_id': 'TERRA_Producer_03', 'Created_Date': datetime.datetime(2022, 3, 7, 4, 48), 'Date': '2022-03-07', 'Create_datetime_str': '2022-03-07 04:48:00', 'Geohash3': 'r1x', 'Geohash5': 'r1x4p'}, {'latitude': -36.0744, 'longitude': 146.688, 'confidence': 51, 'surface_temperature_celcius': 38, 'Producer_id': 'AQUA_Producer_02', 'Created_Date': datetime.datetime(2022, 3, 7, 9, 36), 'Date': '2022-03-07', 'Create_datetime_str': '2022-03-07 09:36:00', 'Geohash3': 'r38', 'Geohash5': 'r386c'}, {'latitude': -36.2257, 'longitude': 144.2904, 'confidence': 72, 'surface_temperature_celcius': 46, 'Producer_id': 'TERRA_Producer_03', 'Created_Date': datetime.datetime(2022, 3, 7, 9, 36), 'Date': '2022-03-07', 'Create_datetime_str': '2022-03-07 09:36:00', 'Geohash3': 'r1w', 'Geohash5': 'r1w9g'}, {'latitude': -37.368, 'longitude': 148.05, 'confidence': 79, 'surface_temperature_celcius': 53, 'Producer_id': 'AQUA_Producer_02', 'Created_Date': datetime.datetime(2022, 3, 7, 14, 24), 'Date': '2022-03-07', 'Create_datetime_str': '2022-03-07 14:24:00', 'Geohash3': 'r33', 'Geohash5': 'r3372'}]
# Same:  [{'latitude': -36.2257, 'longitude': 144.2904, 'confidence': 72, 'surface_temperature_celcius': 46, 'Producer_id': 'TERRA_Producer_03', 'Created_Date': datetime.datetime(2022, 3, 7, 9, 36), 'Date': '2022-03-07', 'Create_datetime_str': '2022-03-07 09:36:00', 'Geohash3': 'r1w', 'Geohash5': 'r1w9g'}]
# Same Geohash: [{'longitude': 144.2904, 'latitude': -36.2257, 'confidence': 72.0, 'surface_temperature': 46.0, 'Date': datetime.datetime(2022, 3, 7, 9, 36), 'Date_str': '2022-03-07', '_id': ObjectId('628a72f025967c93f524f154')}]
# Climate_lst:  [{'station': 948703, 'date': '2022-03-12', 'air_temperature_celcius': 22, 'relative_humidity': 55.5, 'windspeed_knots': 10.3, 'max_wind_speed': 19.0, 'precitipation': None, 'GHI_w/m2': 180, 'geohash3': 'r1s', 'Fire_Cause': 'other', '_id': ObjectId('628a732225967c93f524f159')}]
# Hotspot_lst:  [{'latitude': -36.6228, 'longitude': 142.428, 'confidence': 67, 'surface_temperature_celcius': 43, 'Producer_id': 'TERRA_Producer_03', 'Created_Date': datetime.datetime(2022, 3, 12, 14, 24), 'Date': '2022-03-12', 'Create_datetime_str': '2022-03-12 14:24:00', 'Geohash3': 'r1m', 'Geohash5': 'r1mr9'}, {'latitude': -36.7611, 'longitude': 141.6048, 'confidence': 68, 'surface_temperature_celcius': 44, 'Producer_id': 'AQUA_Producer_02', 'Created_Date': datetime.datetime(2022, 3, 12, 19, 12), 'Date': '2022-03-12', 'Create_datetime_str': '2022-03-12 19:12:00', 'Geohash3': 'r1k', 'Geohash5': 'r1kwy'}, {'latitude': -36.2377, 'longitude': 141.1427, 'confidence': 73, 'surface_temperature_celcius': 47, 'Producer_id': 'TERRA_Producer_03', 'Created_Date': datetime.datetime(2022, 3, 12, 19, 12), 'Date': '2022-03-12', 'Create_datetime_str': '2022-03-12 19:12:00', 'Geohash3': 'r1s', 'Geohash5': 'r1s3g'}, {'latitude': -37.3785, 'longitude': 145.6226, 'confidence': 77, 'surface_temperature_celcius': 50, 'Producer_id': 'AQUA_Producer_02', 'Created_Date': datetime.datetime(2022, 3, 12, 0, 0), 'Date': '2022-03-12', 'Create_datetime_str': '2022-03-12 00:00:00', 'Geohash3': 'r1r', 'Geohash5': 'r1re3'}, {'latitude': -36.1614, 'longitude': 141.2978, 'confidence': 72, 'surface_temperature_celcius': 47, 'Producer_id': 'TERRA_Producer_03', 'Created_Date': datetime.datetime(2022, 3, 12, 0, 0), 'Date': '2022-03-12', 'Create_datetime_str': '2022-03-12 00:00:00', 'Geohash3': 'r1s', 'Geohash5': 'r1s6r'}, {'latitude': -36.3987, 'longitude': 142.6332, 'confidence': 59, 'surface_temperature_celcius': 40, 'Producer_id': 'AQUA_Producer_02', 'Created_Date': datetime.datetime(2022, 3, 12, 4, 48), 'Date': '2022-03-12', 'Create_datetime_str': '2022-03-12 04:48:00', 'Geohash3': 'r1t', 'Geohash5': 'r1t2v'}, {'latitude': -38.075, 'longitude': 143.76, 'confidence': 72, 'surface_temperature_celcius': 46, 'Producer_id': 'TERRA_Producer_03', 'Created_Date': datetime.datetime(2022, 3, 12, 4, 48), 'Date': '2022-03-12', 'Create_datetime_str': '2022-03-12 04:48:00', 'Geohash3': 'r1n', 'Geohash5': 'r1npr'}, {'latitude': -37.861999999999995, 'longitude': 144.175, 'confidence': 87, 'surface_temperature_celcius': 65, 'Producer_id': 'AQUA_Producer_02', 'Created_Date': datetime.datetime(2022, 3, 12, 9, 36), 'Date': '2022-03-12', 'Create_datetime_str': '2022-03-12 09:36:00', 'Geohash3': 'r1q', 'Geohash5': 'r1q88'}, {'latitude': -36.7742, 'longitude': 145.1991, 'confidence': 100, 'surface_temperature_celcius': 89, 'Producer_id': 'TERRA_Producer_03', 'Created_Date': datetime.datetime(2022, 3, 12, 9, 36), 'Date': '2022-03-12', 'Create_datetime_str': '2022-03-12 09:36:00', 'Geohash3': 'r1r', 'Geohash5': 'r1rqb'}, {'latitude': -36.4251, 'longitude': 142.2216, 'confidence': 58, 'surface_temperature_celcius': 40, 'Producer_id': 'AQUA_Producer_02', 'Created_Date': datetime.datetime(2022, 3, 12, 14, 24), 'Date': '2022-03-12', 'Create_datetime_str': '2022-03-12 14:24:00', 'Geohash3': 'r1t', 'Geohash5': 'r1t0u'}]
# Same:  [{'latitude': -36.2377, 'longitude': 141.1427, 'confidence': 73, 'surface_temperature_celcius': 47, 'Producer_id': 'TERRA_Producer_03', 'Created_Date': datetime.datetime(2022, 3, 12, 19, 12), 'Date': '2022-03-12', 'Create_datetime_str': '2022-03-12 19:12:00', 'Geohash3': 'r1s', 'Geohash5': 'r1s3g'}, {'latitude': -36.1614, 'longitude': 141.2978, 'confidence': 72, 'surface_temperature_celcius': 47, 'Producer_id': 'TERRA_Producer_03', 'Created_Date': datetime.datetime(2022, 3, 12, 0, 0), 'Date': '2022-03-12', 'Create_datetime_str': '2022-03-12 00:00:00', 'Geohash3': 'r1s', 'Geohash5': 'r1s6r'}]
# Same Geohash: [{'longitude': 141.1427, 'latitude': -36.2377, 'confidence': 73.0, 'surface_temperature': 47.0, 'Date': datetime.datetime(2022, 3, 12, 19, 12), 'Date_str': '2022-03-12', '_id': ObjectId('628a732225967c93f524f15a')}, {'longitude': 141.2978, 'latitude': -36.1614, 'confidence': 72.0, 'surface_temperature': 47.0, 'Date': datetime.datetime(2022, 3, 12, 0, 0), 'Date_str': '2022-03-12', '_id': ObjectId('628a732225967c93f524f15b')}]
# Climate_lst:  [{'station': 948703, 'date': '2022-03-14', 'air_temperature_celcius': 12, 'relative_humidity': 44.0, 'windspeed_knots': 4.7, 'max_wind_speed': 7.0, 'precitipation': None, 'GHI_w/m2': 108, 'geohash3': 'r1w', 'Fire_Cause': 'other', '_id': ObjectId('628a733625967c93f524f15d')}]
# Hotspot_lst:  [{'latitude': -35.4407, 'longitude': 142.3644, 'confidence': 57, 'surface_temperature_celcius': 35, 'Producer_id': 'TERRA_Producer_03', 'Created_Date': datetime.datetime(2022, 3, 14, 14, 24), 'Date': '2022-03-14', 'Create_datetime_str': '2022-03-14 14:24:00', 'Geohash3': 'r1t', 'Geohash5': 'r1tnr'}, {'latitude': -36.3728, 'longitude': 141.3641, 'confidence': 71, 'surface_temperature_celcius': 46, 'Producer_id': 'AQUA_Producer_02', 'Created_Date': datetime.datetime(2022, 3, 14, 19, 12), 'Date': '2022-03-14', 'Create_datetime_str': '2022-03-14 19:12:00', 'Geohash3': 'r1s', 'Geohash5': 'r1s90'}, {'latitude': -36.0806, 'longitude': 143.7614, 'confidence': 63, 'surface_temperature_celcius': 42, 'Producer_id': 'TERRA_Producer_03', 'Created_Date': datetime.datetime(2022, 3, 14, 19, 12), 'Date': '2022-03-14', 'Create_datetime_str': '2022-03-14 19:12:00', 'Geohash3': 'r1w', 'Geohash5': 'r1w4x'}, {'latitude': -37.164, 'longitude': 148.915, 'confidence': 55, 'surface_temperature_celcius': 42, 'Producer_id': 'AQUA_Producer_02', 'Created_Date': datetime.datetime(2022, 3, 14, 0, 0), 'Date': '2022-03-14', 'Create_datetime_str': '2022-03-14 00:00:00', 'Geohash3': 'r33', 'Geohash5': 'r33us'}, {'latitude': -37.3189, 'longitude': 145.5894, 'confidence': 81, 'surface_temperature_celcius': 60, 'Producer_id': 'TERRA_Producer_03', 'Created_Date': datetime.datetime(2022, 3, 14, 0, 0), 'Date': '2022-03-14', 'Create_datetime_str': '2022-03-14 00:00:00', 'Geohash3': 'r1r', 'Geohash5': 'r1re8'}, {'latitude': -36.8022, 'longitude': 145.2616, 'confidence': 74, 'surface_temperature_celcius': 48, 'Producer_id': 'AQUA_Producer_02', 'Created_Date': datetime.datetime(2022, 3, 14, 4, 48), 'Date': '2022-03-14', 'Create_datetime_str': '2022-03-14 04:48:00', 'Geohash3': 'r1r', 'Geohash5': 'r1rq9'}, {'latitude': -38.0866, 'longitude': 143.9534, 'confidence': 96, 'surface_temperature_celcius': 78, 'Producer_id': 'TERRA_Producer_03', 'Created_Date': datetime.datetime(2022, 3, 14, 4, 48), 'Date': '2022-03-14', 'Create_datetime_str': '2022-03-14 04:48:00', 'Geohash3': 'r1n', 'Geohash5': 'r1nr7'}, {'latitude': -36.5233, 'longitude': 146.7436, 'confidence': 63, 'surface_temperature_celcius': 42, 'Producer_id': 'AQUA_Producer_02', 'Created_Date': datetime.datetime(2022, 3, 14, 9, 36), 'Date': '2022-03-14', 'Create_datetime_str': '2022-03-14 09:36:00', 'Geohash3': 'r38', 'Geohash5': 'r3825'}, {'latitude': -36.7034, 'longitude': 141.6168, 'confidence': 71, 'surface_temperature_celcius': 46, 'Producer_id': 'TERRA_Producer_03', 'Created_Date': datetime.datetime(2022, 3, 14, 9, 36), 'Date': '2022-03-14', 'Create_datetime_str': '2022-03-14 09:36:00', 'Geohash3': 'r1k', 'Geohash5': 'r1kxn'}, {'latitude': -36.0077, 'longitude': 141.7747, 'confidence': 100, 'surface_temperature_celcius': 93, 'Producer_id': 'AQUA_Producer_02', 'Created_Date': datetime.datetime(2022, 3, 14, 14, 24), 'Date': '2022-03-14', 'Create_datetime_str': '2022-03-14 14:24:00', 'Geohash3': 'r1s', 'Geohash5': 'r1sg4'}]
# Same:  [{'latitude': -36.0806, 'longitude': 143.7614, 'confidence': 63, 'surface_temperature_celcius': 42, 'Producer_id': 'TERRA_Producer_03', 'Created_Date': datetime.datetime(2022, 3, 14, 19, 12), 'Date': '2022-03-14', 'Create_datetime_str': '2022-03-14 19:12:00', 'Geohash3': 'r1w', 'Geohash5': 'r1w4x'}]
# Same Geohash: [{'longitude': 143.7614, 'latitude': -36.0806, 'confidence': 63.0, 'surface_temperature': 42.0, 'Date': datetime.datetime(2022, 3, 14, 19, 12), 'Date_str': '2022-03-14', '_id': ObjectId('628a733625967c93f524f15e')}]
