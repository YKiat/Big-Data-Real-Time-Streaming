# %% [markdown]
# # Task A

# %% [markdown]
# ## Example of Data Model (Reference)

# %% [markdown]
# ### Climate

# %% [markdown]
# `{
#     {'_id': ObjectId('6287cc99c4c587048264cc0e'),
#     'station': 948702,
#     'date': datetime.datetime(2021, 12, 25, 0, 0),
#     'air_temperature_celcius': 17,
#     'relative_humidity': 50.4,
#     'windspeed_knots': 10.8,
#     'max_wind_speed': 16.9,
#     'precipitation ': ' 0.00I',
#     'GHI_w/m2': 145,
#     'precipitation_numeric': 0.0}
# }`

# %% [markdown]
# ### Hotspot

# %% [markdown]
# `{
#     '_id': ObjectId('628104241b875bcdc821215a'),
#     'latitude': -37.708,
#     'longitude': 145.1,
#     'datetime': '2021-12-25T04:29:08',
#     'confidence': 80,
#     'date': datetime.datetime(2021, 12, 25, 0, 0),
#     'surface_temperature_celcius': 54}
# }`

# %% [markdown]
# ## Justification
#
# The reason I used reference model is I think that for the climate data, we can re-use the same mongo database for the next 10 years since referencing model is scalable compares to embedding.Referencing model allow us to work with larger data compare to the embedding model since the embedding model require all data to be stored/wrapped within a dict, when referencing model allow us to work with different collection, so with referencing model we can work with larger dataset that store within 1 document.
#
# Other than that, referencing model is more suitable for one-to-many relationship according to the lecture. And the climate_historic dataset is the dataset where having all the date from 31st December 2020, which is the "one" in the one-to-many relationship, and the hotspot_historic dataset will be the "many" since there will be more than one row within the same day.
#
# Lastly, although referencing model require more complex query/work to be done when we want to have the attribute from both dataset, but I think for the climate, the number of operations to write to the data is significantly more than reading/query from the database.
#
# Hence, based on the 3 reason listed above I choose to use the referencing model.

# %%
import pymongo 
import pandas as pd
from datetime import datetime
from datetime import timezone
import dateutil.parser
from pymongo import MongoClient 
client = pymongo.MongoClient()
mydb = client.fit3182_assignment_db
climate_coll = mydb['climate']
hotspot_coll = mydb['hotspot']
climate_coll.drop()
hotspot_coll.drop()

# %%
climate_history = pd.read_csv('climate_historic.csv')
hotspot_history = pd.read_csv('hotspot_historic.csv')

# %%
climate_history.dtypes
# Out:
# station                      int64
# date                        object
# air_temperature_celcius      int64
# relative_humidity          float64
# windspeed_knots            float64
# max_wind_speed             float64
# precipitation               object
# GHI_w/m2                     int64
# dtype: object

# %%
hotspot_history.dtypes
# Out:
# latitude                       float64
# longitude                      float64
# datetime                        object
# confidence                       int64
# date                            object
# surface_temperature_celcius      int64
# dtype: object

# %%
# conversion of object to datetime 
climate_history['date'] = pd.to_datetime(climate_history['date'],dayfirst=True)

hotspot_history['date'] = pd.to_datetime(hotspot_history['date'],dayfirst=True)

# %%
# preprocess `precipitation` column 
climate_history['precipitation_numeric'] = climate_history['precipitation '].str.strip('IGAB')
climate_history['precipitation_numeric'] = climate_history['precipitation_numeric'].astype(str).astype(float)

# %%
climate_history.head()
# Out:
#    station       date  air_temperature_celcius  relative_humidity  \
# 0   948700 2020-12-31                       19               56.8
# 1   948700 2021-01-02                       15               50.7
# 2   948700 2021-01-03                       16               53.6
# 3   948700 2021-01-04                       24               61.6
# 4   948700 2021-01-05                       24               62.3
#
#    windspeed_knots  max_wind_speed precipitation   GHI_w/m2  \
# 0              7.9            11.1          0.00I       154
# 1              9.2            13.0          0.02G       128
# 2              8.1            15.0          0.00G       133
# 3              7.7            14.0          0.00I       186
# 4              7.0            13.0          0.00I       185
#
#    precipitation_numeric
# 0                   0.00
# 1                   0.02
# 2                   0.00
# 3                   0.00
# 4                   0.00

# %%
climate_dict = climate_history.to_dict(orient='records')
hotspot_dict = hotspot_history.to_dict(orient='records')

# %%
print(climate_dict[0])
print(hotspot_dict[0])
# Out:
# {'station': 948700, 'date': Timestamp('2020-12-31 00:00:00'), 'air_temperature_celcius': 19, 'relative_humidity': 56.8, 'windspeed_knots': 7.9, 'max_wind_speed': 11.1, 'precipitation ': ' 0.00I', 'GHI_w/m2': 154, 'precipitation_numeric': 0.0}
# {'latitude': -37.966, 'longitude': 145.05100000000002, 'datetime': '2021-12-27T04:16:51', 'confidence': 78, 'date': Timestamp('2021-12-27 00:00:00'), 'surface_temperature_celcius': 68}

# %%
climate_coll.insert_many(climate_dict)

# %%
for x in climate_coll.find():
    print(x)
    break
# Out:
# {'_id': ObjectId('628a4076c40eee0972357850'), 'station': 948700, 'date': datetime.datetime(2020, 12, 31, 0, 0), 'air_temperature_celcius': 19, 'relative_humidity': 56.8, 'windspeed_knots': 7.9, 'max_wind_speed': 11.1, 'precipitation ': ' 0.00I', 'GHI_w/m2': 154, 'precipitation_numeric': 0.0}

# %%
hotspot_coll.insert_many(hotspot_dict)

# %%
for x in hotspot_coll.find():
    print(x)
    break
# Out:
# {'_id': ObjectId('628a4077c40eee09723579be'), 'latitude': -37.966, 'longitude': 145.05100000000002, 'datetime': '2021-12-27T04:16:51', 'confidence': 78, 'date': datetime.datetime(2021, 12, 27, 0, 0), 'surface_temperature_celcius': 68}

# %% [markdown]
# # Part A Task 2

# %% [markdown]
# ## a. Find climate data on 12th December 2021.

# %%
mq = {"date":datetime.strptime("12/12/2021","%d/%m/%Y")}
for x in climate_coll.find(mq): 
    print(x)
# Out:
# {'_id': ObjectId('628a4076c40eee09723579a9'), 'station': 948702, 'date': datetime.datetime(2021, 12, 12, 0, 0), 'air_temperature_celcius': 19, 'relative_humidity': 55.3, 'windspeed_knots': 6.2, 'max_wind_speed': 12.0, 'precipitation ': ' 0.00I', 'GHI_w/m2': 156, 'precipitation_numeric': 0.0}

# %% [markdown]
# ## b. Find the latitude, longitude, surface temperature (°C), and confidence when the surface temperature (°C) was between 65 °C and 100 °C.

# %%
mq = {"surface_temperature_celcius":{"$gte": 65,"$lte":100}}
results = hotspot_coll.find(mq,{"latitude":1,"longitude":1,"confidence":1,"surface_temperature_celcius":1}).sort("surface_temperature_celcius")

for x in results:
    print(x)
# Out:
# {'_id': ObjectId('628a4077c40eee09723579f3'), 'latitude': -37.641999999999996, 'longitude': 149.263, 'confidence': 100, 'surface_temperature_celcius': 65}
# {'_id': ObjectId('628a4077c40eee0972357a16'), 'latitude': -37.861999999999995, 'longitude': 144.175, 'confidence': 87, 'surface_temperature_celcius': 65}
# {'_id': ObjectId('628a4077c40eee0972357a35'), 'latitude': -37.330999999999996, 'longitude': 143.122, 'confidence': 90, 'surface_temperature_celcius': 65}
# {'_id': ObjectId('628a4077c40eee0972357a74'), 'latitude': -37.46, 'longitude': 148.102, 'confidence': 88, 'surface_temperature_celcius': 65}
# {'_id': ObjectId('628a4077c40eee0972357a93'), 'latitude': -37.446, 'longitude': 148.102, 'confidence': 100, 'surface_temperature_celcius': 65}
# {'_id': ObjectId('628a4077c40eee0972357ab3'), 'latitude': -37.396, 'longitude': 148.086, 'confidence': 100, 'surface_temperature_celcius': 65}
# {'_id': ObjectId('628a4077c40eee0972357ae2'), 'latitude': -38.3998, 'longitude': 147.064, 'confidence': 89, 'surface_temperature_celcius': 65}
# {'_id': ObjectId('628a4077c40eee0972357b62'), 'latitude': -38.4792, 'longitude': 146.3081, 'confidence': 89, 'surface_temperature_celcius': 65}
# {'_id': ObjectId('628a4077c40eee0972357bab'), 'latitude': -36.5661, 'longitude': 142.2956, 'confidence': 89, 'surface_temperature_celcius': 65}
# {'_id': ObjectId('628a4077c40eee0972357bc9'), 'latitude': -35.4666, 'longitude': 142.0749, 'confidence': 89, 'surface_temperature_celcius': 65}
# {'_id': ObjectId('628a4077c40eee0972357c1e'), 'latitude': -36.7218, 'longitude': 141.6411, 'confidence': 89, 'surface_temperature_celcius': 65}
# {'_id': ObjectId('628a4077c40eee0972357d5b'), 'latitude': -36.4143, 'longitude': 143.27200000000002, 'confidence': 89, 'surface_temperature_celcius': 65}
# {'_id': ObjectId('628a4077c40eee0972357e2c'), 'latitude': -37.876, 'longitude': 143.7804, 'confidence': 89, 'surface_temperature_celcius': 65}
# {'_id': ObjectId('628a4077c40eee0972357e6a'), 'latitude': -36.2618, 'longitude': 141.8783, 'confidence': 89, 'surface_temperature_celcius': 65}
# {'_id': ObjectId('628a4077c40eee0972357eb2'), 'latitude': -37.0959, 'longitude': 143.8206, 'confidence': 89, 'surface_temperature_celcius': 65}
# {'_id': ObjectId('628a4077c40eee0972357f7e'), 'latitude': -34.9023, 'longitude': 142.0557, 'confidence': 89, 'surface_temperature_celcius': 65}
# {'_id': ObjectId('628a4077c40eee0972357fed'), 'latitude': -36.73, 'longitude': 143.935, 'confidence': 89, 'surface_temperature_celcius': 65}
# {'_id': ObjectId('628a4077c40eee097235802e'), 'latitude': -36.0295, 'longitude': 143.6409, 'confidence': 89, 'surface_temperature_celcius': 65}
# {'_id': ObjectId('628a4077c40eee097235805c'), 'latitude': -38.1561, 'longitude': 143.7846, 'confidence': 89, 'surface_temperature_celcius': 65}
# {'_id': ObjectId('628a4077c40eee0972358076'), 'latitude': -35.7642, 'longitude': 143.3321, 'confidence': 89, 'surface_temperature_celcius': 65}
# {'_id': ObjectId('628a4077c40eee09723580e1'), 'latitude': -36.1441, 'longitude': 145.2221, 'confidence': 89, 'surface_temperature_celcius': 65}
# {'_id': ObjectId('628a4077c40eee0972358145'), 'latitude': -37.88, 'longitude': 143.7233, 'confidence': 89, 'surface_temperature_celcius': 65}
# {'_id': ObjectId('628a4077c40eee0972358224'), 'latitude': -37.5816, 'longitude': 148.5862, 'confidence': 84, 'surface_temperature_celcius': 65}
# {'_id': ObjectId('628a4077c40eee097235822a'), 'latitude': -37.8062, 'longitude': 143.3598, 'confidence': 77, 'surface_temperature_celcius': 65}
# {'_id': ObjectId('628a4077c40eee0972358235'), 'latitude': -36.9902, 'longitude': 141.879, 'confidence': 89, 'surface_temperature_celcius': 65}
# {'_id': ObjectId('628a4077c40eee0972358236'), 'latitude': -37.745, 'longitude': 142.993, 'confidence': 89, 'surface_temperature_celcius': 65}
# {'_id': ObjectId('628a4077c40eee0972358241'), 'latitude': -34.3943, 'longitude': 141.7567, 'confidence': 89, 'surface_temperature_celcius': 65}
# {'_id': ObjectId('628a4077c40eee0972358261'), 'latitude': -37.7746, 'longitude': 148.3673, 'confidence': 88, 'surface_temperature_celcius': 65}
# {'_id': ObjectId('628a4077c40eee09723582b8'), 'latitude': -37.4471, 'longitude': 147.6331, 'confidence': 89, 'surface_temperature_celcius': 65}
# {'_id': ObjectId('628a4077c40eee09723582be'), 'latitude': -37.4449, 'longitude': 147.6594, 'confidence': 89, 'surface_temperature_celcius': 65}
# {'_id': ObjectId('628a4077c40eee09723582ef'), 'latitude': -35.4255, 'longitude': 143.6306, 'confidence': 89, 'surface_temperature_celcius': 65}
# {'_id': ObjectId('628a4077c40eee0972358362'), 'latitude': -36.1556, 'longitude': 141.5904, 'confidence': 89, 'surface_temperature_celcius': 65}
# {'_id': ObjectId('628a4077c40eee0972358365'), 'latitude': -35.7647, 'longitude': 142.0858, 'confidence': 89, 'surface_temperature_celcius': 65}
# {'_id': ObjectId('628a4077c40eee09723583d8'), 'latitude': -37.8973, 'longitude': 143.4754, 'confidence': 82, 'surface_temperature_celcius': 65}
# {'_id': ObjectId('628a4077c40eee097235840e'), 'latitude': -34.3654, 'longitude': 141.543, 'confidence': 89, 'surface_temperature_celcius': 65}
# {'_id': ObjectId('628a4077c40eee09723579cc'), 'latitude': -37.624, 'longitude': 149.314, 'confidence': 90, 'surface_temperature_celcius': 66}
# {'_id': ObjectId('628a4077c40eee0972357aa8'), 'latitude': -37.444, 'longitude': 148.101, 'confidence': 73, 'surface_temperature_celcius': 66}
# {'_id': ObjectId('628a4077c40eee0972357b97'), 'latitude': -36.7032, 'longitude': 144.0992, 'confidence': 90, 'surface_temperature_celcius': 66}
# {'_id': ObjectId('628a4077c40eee0972357bb7'), 'latitude': -36.5023, 'longitude': 143.6038, 'confidence': 85, 'surface_temperature_celcius': 66}
# {'_id': ObjectId('628a4077c40eee0972357d54'), 'latitude': -36.5116, 'longitude': 144.562, 'confidence': 89, 'surface_temperature_celcius': 66}
# {'_id': ObjectId('628a4077c40eee0972357e34'), 'latitude': -36.1559, 'longitude': 141.8102, 'confidence': 80, 'surface_temperature_celcius': 66}
# {'_id': ObjectId('628a4077c40eee0972357e5e'), 'latitude': -37.6267, 'longitude': 142.9993, 'confidence': 90, 'surface_temperature_celcius': 66}
# {'_id': ObjectId('628a4077c40eee0972357e6c'), 'latitude': -36.6828, 'longitude': 144.784, 'confidence': 90, 'surface_temperature_celcius': 66}
# {'_id': ObjectId('628a4077c40eee0972357e6f'), 'latitude': -37.4843, 'longitude': 143.0592, 'confidence': 89, 'surface_temperature_celcius': 66}
# {'_id': ObjectId('628a4077c40eee0972357ed0'), 'latitude': -38.0423, 'longitude': 146.4048, 'confidence': 84, 'surface_temperature_celcius': 66}
# {'_id': ObjectId('628a4077c40eee0972357f85'), 'latitude': -37.2609, 'longitude': 141.7999, 'confidence': 89, 'surface_temperature_celcius': 66}
# {'_id': ObjectId('628a4077c40eee0972357fe4'), 'latitude': -35.9326, 'longitude': 141.958, 'confidence': 78, 'surface_temperature_celcius': 66}
# {'_id': ObjectId('628a4077c40eee0972358042'), 'latitude': -35.1949, 'longitude': 141.0622, 'confidence': 90, 'surface_temperature_celcius': 66}
# {'_id': ObjectId('628a4077c40eee0972358048'), 'latitude': -35.8071, 'longitude': 142.7318, 'confidence': 89, 'surface_temperature_celcius': 66}
# {'_id': ObjectId('628a4077c40eee097235805e'), 'latitude': -37.8185, 'longitude': 142.5609, 'confidence': 90, 'surface_temperature_celcius': 66}
# {'_id': ObjectId('628a4077c40eee097235808e'), 'latitude': -36.1462, 'longitude': 145.2096, 'confidence': 90, 'surface_temperature_celcius': 66}
# {'_id': ObjectId('628a4077c40eee0972358099'), 'latitude': -36.8867, 'longitude': 142.1873, 'confidence': 90, 'surface_temperature_celcius': 66}
# {'_id': ObjectId('628a4077c40eee09723580ce'), 'latitude': -36.5399, 'longitude': 144.678, 'confidence': 90, 'surface_temperature_celcius': 66}
# {'_id': ObjectId('628a4077c40eee09723581f7'), 'latitude': -36.7165, 'longitude': 142.6155, 'confidence': 90, 'surface_temperature_celcius': 66}
# {'_id': ObjectId('628a4077c40eee0972358226'), 'latitude': -37.7966, 'longitude': 142.3196, 'confidence': 76, 'surface_temperature_celcius': 66}
# {'_id': ObjectId('628a4077c40eee0972358255'), 'latitude': -36.6384, 'longitude': 142.4075, 'confidence': 90, 'surface_temperature_celcius': 66}
# {'_id': ObjectId('628a4077c40eee09723582bb'), 'latitude': -37.7835, 'longitude': 148.4138, 'confidence': 90, 'surface_temperature_celcius': 66}
# {'_id': ObjectId('628a4077c40eee09723582d5'), 'latitude': -36.111, 'longitude': 145.124, 'confidence': 85, 'surface_temperature_celcius': 66}
# {'_id': ObjectId('628a4077c40eee09723582d6'), 'latitude': -36.1615, 'longitude': 141.8728, 'confidence': 90, 'surface_temperature_celcius': 66}
# {'_id': ObjectId('628a4077c40eee09723582f3'), 'latitude': -35.4533, 'longitude': 143.2029, 'confidence': 85, 'surface_temperature_celcius': 66}
# {'_id': ObjectId('628a4077c40eee0972358345'), 'latitude': -37.7446, 'longitude': 143.4085, 'confidence': 89, 'surface_temperature_celcius': 66}
# {'_id': ObjectId('628a4077c40eee0972358352'), 'latitude': -35.7657, 'longitude': 142.0906, 'confidence': 90, 'surface_temperature_celcius': 66}
# {'_id': ObjectId('628a4077c40eee09723583e9'), 'latitude': -37.4523, 'longitude': 147.0175, 'confidence': 90, 'surface_temperature_celcius': 66}
# {'_id': ObjectId('628a4077c40eee09723579c1'), 'latitude': -35.543, 'longitude': 143.316, 'confidence': 86, 'surface_temperature_celcius': 67}
# {'_id': ObjectId('628a4077c40eee0972357a46'), 'latitude': -36.098, 'longitude': 143.74, 'confidence': 92, 'surface_temperature_celcius': 67}
# {'_id': ObjectId('628a4077c40eee0972357b23'), 'latitude': -36.4325, 'longitude': 144.3142, 'confidence': 90, 'surface_temperature_celcius': 67}
# {'_id': ObjectId('628a4077c40eee0972357bc5'), 'latitude': -38.0372, 'longitude': 146.0616, 'confidence': 90, 'surface_temperature_celcius': 67}
# {'_id': ObjectId('628a4077c40eee0972357c1b'), 'latitude': -36.2911, 'longitude': 141.1664, 'confidence': 90, 'surface_temperature_celcius': 67}
# {'_id': ObjectId('628a4077c40eee0972357d8d'), 'latitude': -36.3435, 'longitude': 141.5513, 'confidence': 90, 'surface_temperature_celcius': 67}
# {'_id': ObjectId('628a4077c40eee0972357dad'), 'latitude': -36.094, 'longitude': 145.7646, 'confidence': 90, 'surface_temperature_celcius': 67}
# {'_id': ObjectId('628a4077c40eee0972357e07'), 'latitude': -36.1303, 'longitude': 146.3606, 'confidence': 90, 'surface_temperature_celcius': 67}
# {'_id': ObjectId('628a4077c40eee0972357e9d'), 'latitude': -36.7101, 'longitude': 142.3865, 'confidence': 90, 'surface_temperature_celcius': 67}
# {'_id': ObjectId('628a4077c40eee0972357f06'), 'latitude': -37.7756, 'longitude': 143.1388, 'confidence': 90, 'surface_temperature_celcius': 67}
# {'_id': ObjectId('628a4077c40eee0972357fb5'), 'latitude': -37.1349, 'longitude': 141.9491, 'confidence': 90, 'surface_temperature_celcius': 67}
# {'_id': ObjectId('628a4077c40eee097235807b'), 'latitude': -36.429, 'longitude': 141.5759, 'confidence': 90, 'surface_temperature_celcius': 67}
# {'_id': ObjectId('628a4077c40eee09723580a5'), 'latitude': -36.8835, 'longitude': 142.2098, 'confidence': 90, 'surface_temperature_celcius': 67}
# {'_id': ObjectId('628a4077c40eee09723580d4'), 'latitude': -36.7903, 'longitude': 141.618, 'confidence': 90, 'surface_temperature_celcius': 67}
# {'_id': ObjectId('628a4077c40eee09723580f1'), 'latitude': -36.782, 'longitude': 141.8851, 'confidence': 90, 'surface_temperature_celcius': 67}
# {'_id': ObjectId('628a4077c40eee0972358175'), 'latitude': -36.2857, 'longitude': 141.3467, 'confidence': 90, 'surface_temperature_celcius': 67}
# {'_id': ObjectId('628a4077c40eee0972358180'), 'latitude': -36.5532, 'longitude': 142.5349, 'confidence': 90, 'surface_temperature_celcius': 67}
# {'_id': ObjectId('628a4077c40eee0972358253'), 'latitude': -37.5788, 'longitude': 148.592, 'confidence': 90, 'surface_temperature_celcius': 67}
# {'_id': ObjectId('628a4077c40eee097235827f'), 'latitude': -36.0387, 'longitude': 145.6787, 'confidence': 90, 'surface_temperature_celcius': 67}
# {'_id': ObjectId('628a4077c40eee09723582d3'), 'latitude': -35.4033, 'longitude': 143.267, 'confidence': 90, 'surface_temperature_celcius': 67}
# {'_id': ObjectId('628a4077c40eee0972358314'), 'latitude': -36.883, 'longitude': 142.1637, 'confidence': 79, 'surface_temperature_celcius': 67}
# {'_id': ObjectId('628a4077c40eee0972358409'), 'latitude': -34.357, 'longitude': 141.5361, 'confidence': 90, 'surface_temperature_celcius': 67}
# {'_id': ObjectId('628a4077c40eee09723579be'), 'latitude': -37.966, 'longitude': 145.05100000000002, 'confidence': 78, 'surface_temperature_celcius': 68}
# {'_id': ObjectId('628a4077c40eee0972357a52'), 'latitude': -37.247, 'longitude': 141.278, 'confidence': 91, 'surface_temperature_celcius': 68}
# {'_id': ObjectId('628a4077c40eee0972357b04'), 'latitude': -36.3774, 'longitude': 143.7079, 'confidence': 91, 'surface_temperature_celcius': 68}
# {'_id': ObjectId('628a4077c40eee0972357b29'), 'latitude': -36.7801, 'longitude': 142.7151, 'confidence': 91, 'surface_temperature_celcius': 68}
# {'_id': ObjectId('628a4077c40eee0972357b59'), 'latitude': -36.7746, 'longitude': 146.6642, 'confidence': 91, 'surface_temperature_celcius': 68}
# {'_id': ObjectId('628a4077c40eee0972357c07'), 'latitude': -35.6871, 'longitude': 143.5235, 'confidence': 90, 'surface_temperature_celcius': 68}
# {'_id': ObjectId('628a4077c40eee0972357c3e'), 'latitude': -37.8323, 'longitude': 147.2232, 'confidence': 84, 'surface_temperature_celcius': 68}
# {'_id': ObjectId('628a4077c40eee0972357cb8'), 'latitude': -36.4168, 'longitude': 141.6939, 'confidence': 91, 'surface_temperature_celcius': 68}
# {'_id': ObjectId('628a4077c40eee0972357ccb'), 'latitude': -35.6138, 'longitude': 143.8666, 'confidence': 91, 'surface_temperature_celcius': 68}
# {'_id': ObjectId('628a4077c40eee0972357d11'), 'latitude': -36.5061, 'longitude': 144.5675, 'confidence': 91, 'surface_temperature_celcius': 68}
# {'_id': ObjectId('628a4077c40eee0972357d21'), 'latitude': -36.3635, 'longitude': 142.2809, 'confidence': 91, 'surface_temperature_celcius': 68}
# {'_id': ObjectId('628a4077c40eee0972357d48'), 'latitude': -36.7751, 'longitude': 145.1696, 'confidence': 91, 'surface_temperature_celcius': 68}
# {'_id': ObjectId('628a4077c40eee0972357e59'), 'latitude': -37.6397, 'longitude': 142.5968, 'confidence': 91, 'surface_temperature_celcius': 68}
# {'_id': ObjectId('628a4077c40eee0972357eb1'), 'latitude': -36.7101, 'longitude': 142.981, 'confidence': 77, 'surface_temperature_celcius': 68}
# {'_id': ObjectId('628a4077c40eee0972357f0f'), 'latitude': -37.7171, 'longitude': 142.9505, 'confidence': 91, 'surface_temperature_celcius': 68}
# {'_id': ObjectId('628a4077c40eee0972357fac'), 'latitude': -37.0782, 'longitude': 145.3625, 'confidence': 91, 'surface_temperature_celcius': 68}
# {'_id': ObjectId('628a4077c40eee0972357fc5'), 'latitude': -36.7651, 'longitude': 143.5801, 'confidence': 91, 'surface_temperature_celcius': 68}
# {'_id': ObjectId('628a4077c40eee09723580be'), 'latitude': -36.3487, 'longitude': 145.5315, 'confidence': 91, 'surface_temperature_celcius': 68}
# {'_id': ObjectId('628a4077c40eee09723580fb'), 'latitude': -36.5568, 'longitude': 144.0538, 'confidence': 90, 'surface_temperature_celcius': 68}
# {'_id': ObjectId('628a4077c40eee097235812b'), 'latitude': -37.6171, 'longitude': 142.9426, 'confidence': 91, 'surface_temperature_celcius': 68}
# {'_id': ObjectId('628a4077c40eee097235817a'), 'latitude': -36.4449, 'longitude': 140.9836, 'confidence': 91, 'surface_temperature_celcius': 68}
# {'_id': ObjectId('628a4077c40eee0972358250'), 'latitude': -37.5814, 'longitude': 148.5777, 'confidence': 86, 'surface_temperature_celcius': 68}
# {'_id': ObjectId('628a4077c40eee097235826a'), 'latitude': -37.3803, 'longitude': 145.611, 'confidence': 91, 'surface_temperature_celcius': 68}
# {'_id': ObjectId('628a4077c40eee09723582d4'), 'latitude': -36.6281, 'longitude': 142.4349, 'confidence': 64, 'surface_temperature_celcius': 68}
# {'_id': ObjectId('628a4077c40eee09723583cc'), 'latitude': -38.0674, 'longitude': 142.965, 'confidence': 91, 'surface_temperature_celcius': 68}
# {'_id': ObjectId('628a4077c40eee097235840b'), 'latitude': -36.9939, 'longitude': 148.2244, 'confidence': 90, 'surface_temperature_celcius': 68}
# {'_id': ObjectId('628a4077c40eee0972358418'), 'latitude': -37.0055, 'longitude': 148.1582, 'confidence': 80, 'surface_temperature_celcius': 68}
# {'_id': ObjectId('628a4077c40eee0972357a22'), 'latitude': -36.94, 'longitude': 143.281, 'confidence': 89, 'surface_temperature_celcius': 69}
# {'_id': ObjectId('628a4077c40eee0972357aa6'), 'latitude': -37.45, 'longitude': 148.126, 'confidence': 64, 'surface_temperature_celcius': 69}
# {'_id': ObjectId('628a4077c40eee0972357aeb'), 'latitude': -37.8644, 'longitude': 143.4263, 'confidence': 91, 'surface_temperature_celcius': 69}
# {'_id': ObjectId('628a4077c40eee0972357b26'), 'latitude': -36.7685, 'longitude': 142.7134, 'confidence': 91, 'surface_temperature_celcius': 69}
# {'_id': ObjectId('628a4077c40eee0972357c01'), 'latitude': -36.5541, 'longitude': 144.1321, 'confidence': 91, 'surface_temperature_celcius': 69}
# {'_id': ObjectId('628a4077c40eee0972357c04'), 'latitude': -35.6819, 'longitude': 143.5275, 'confidence': 91, 'surface_temperature_celcius': 69}
# {'_id': ObjectId('628a4077c40eee0972357c27'), 'latitude': -36.3153, 'longitude': 140.9789, 'confidence': 91, 'surface_temperature_celcius': 69}
# {'_id': ObjectId('628a4077c40eee0972357d24'), 'latitude': -36.6564, 'longitude': 142.8615, 'confidence': 91, 'surface_temperature_celcius': 69}
# {'_id': ObjectId('628a4077c40eee0972357d4c'), 'latitude': -36.3961, 'longitude': 140.9781, 'confidence': 91, 'surface_temperature_celcius': 69}
# {'_id': ObjectId('628a4077c40eee0972357d83'), 'latitude': -36.7593, 'longitude': 142.895, 'confidence': 92, 'surface_temperature_celcius': 69}
# {'_id': ObjectId('628a4077c40eee0972357e89'), 'latitude': -37.6964, 'longitude': 142.8583, 'confidence': 91, 'surface_temperature_celcius': 69}
# {'_id': ObjectId('628a4077c40eee0972357f84'), 'latitude': -36.2637, 'longitude': 145.3649, 'confidence': 91, 'surface_temperature_celcius': 69}
# {'_id': ObjectId('628a4077c40eee0972357fec'), 'latitude': -36.6892, 'longitude': 145.2775, 'confidence': 91, 'surface_temperature_celcius': 69}
# {'_id': ObjectId('628a4077c40eee097235803e'), 'latitude': -36.1748, 'longitude': 145.7582, 'confidence': 91, 'surface_temperature_celcius': 69}
# {'_id': ObjectId('628a4077c40eee0972358136'), 'latitude': -37.4611, 'longitude': 144.9371, 'confidence': 91, 'surface_temperature_celcius': 69}
# {'_id': ObjectId('628a4077c40eee097235815a'), 'latitude': -35.6453, 'longitude': 142.387, 'confidence': 91, 'surface_temperature_celcius': 69}
# {'_id': ObjectId('628a4077c40eee09723581eb'), 'latitude': -35.2363, 'longitude': 143.0004, 'confidence': 91, 'surface_temperature_celcius': 69}
# {'_id': ObjectId('628a4077c40eee0972358225'), 'latitude': -36.6334, 'longitude': 142.2244, 'confidence': 92, 'surface_temperature_celcius': 69}
# {'_id': ObjectId('628a4077c40eee097235824e'), 'latitude': -36.031, 'longitude': 145.6824, 'confidence': 91, 'surface_temperature_celcius': 69}
# {'_id': ObjectId('628a4077c40eee09723579d8'), 'latitude': -37.95, 'longitude': 142.366, 'confidence': 92, 'surface_temperature_celcius': 70}
# {'_id': ObjectId('628a4077c40eee0972357b7d'), 'latitude': -36.9396, 'longitude': 143.1462, 'confidence': 92, 'surface_temperature_celcius': 70}
# {'_id': ObjectId('628a4077c40eee0972357c23'), 'latitude': -36.3207, 'longitude': 140.9737, 'confidence': 92, 'surface_temperature_celcius': 70}
# {'_id': ObjectId('628a4077c40eee0972357c51'), 'latitude': -37.4463, 'longitude': 142.7829, 'confidence': 92, 'surface_temperature_celcius': 70}
# {'_id': ObjectId('628a4077c40eee0972357d56'), 'latitude': -36.803000000000004, 'longitude': 142.9261, 'confidence': 92, 'surface_temperature_celcius': 70}
# {'_id': ObjectId('628a4077c40eee0972357d66'), 'latitude': -36.882, 'longitude': 142.7108, 'confidence': 92, 'surface_temperature_celcius': 70}
# {'_id': ObjectId('628a4077c40eee0972357e30'), 'latitude': -37.9091, 'longitude': 143.5105, 'confidence': 87, 'surface_temperature_celcius': 70}
# {'_id': ObjectId('628a4077c40eee0972357e8f'), 'latitude': -37.9284, 'longitude': 143.108, 'confidence': 92, 'surface_temperature_celcius': 70}
# {'_id': ObjectId('628a4077c40eee0972357f1c'), 'latitude': -37.6498, 'longitude': 142.5997, 'confidence': 92, 'surface_temperature_celcius': 70}
# {'_id': ObjectId('628a4077c40eee0972357f47'), 'latitude': -36.5828, 'longitude': 144.5775, 'confidence': 92, 'surface_temperature_celcius': 70}
# {'_id': ObjectId('628a4077c40eee0972357f8e'), 'latitude': -36.2652, 'longitude': 145.3769, 'confidence': 92, 'surface_temperature_celcius': 70}
# {'_id': ObjectId('628a4077c40eee097235802a'), 'latitude': -36.1924, 'longitude': 143.1716, 'confidence': 92, 'surface_temperature_celcius': 70}
# {'_id': ObjectId('628a4077c40eee097235809b'), 'latitude': -36.9364, 'longitude': 143.4996, 'confidence': 92, 'surface_temperature_celcius': 70}
# {'_id': ObjectId('628a4077c40eee0972358177'), 'latitude': -36.0749, 'longitude': 143.4058, 'confidence': 92, 'surface_temperature_celcius': 70}
# {'_id': ObjectId('628a4077c40eee09723581a4'), 'latitude': -37.4033, 'longitude': 143.6884, 'confidence': 92, 'surface_temperature_celcius': 70}
# {'_id': ObjectId('628a4077c40eee097235821f'), 'latitude': -37.2063, 'longitude': 147.4713, 'confidence': 92, 'surface_temperature_celcius': 70}
# {'_id': ObjectId('628a4077c40eee0972358220'), 'latitude': -37.2082, 'longitude': 147.4368, 'confidence': 92, 'surface_temperature_celcius': 70}
# {'_id': ObjectId('628a4077c40eee097235823a'), 'latitude': -36.0157, 'longitude': 145.9414, 'confidence': 92, 'surface_temperature_celcius': 70}
# {'_id': ObjectId('628a4077c40eee09723583cd'), 'latitude': -38.0715, 'longitude': 142.9591, 'confidence': 92, 'surface_temperature_celcius': 70}
# {'_id': ObjectId('628a4077c40eee09723583f4'), 'latitude': -37.6625, 'longitude': 144.287, 'confidence': 92, 'surface_temperature_celcius': 70}
# {'_id': ObjectId('628a4077c40eee09723579e3'), 'latitude': -36.282, 'longitude': 146.157, 'confidence': 100, 'surface_temperature_celcius': 71}
# {'_id': ObjectId('628a4077c40eee09723579f4'), 'latitude': -37.634, 'longitude': 149.237, 'confidence': 100, 'surface_temperature_celcius': 71}
# {'_id': ObjectId('628a4077c40eee0972357c64'), 'latitude': -38.2391, 'longitude': 142.82, 'confidence': 92, 'surface_temperature_celcius': 71}
# {'_id': ObjectId('628a4077c40eee0972357cd7'), 'latitude': -37.7889, 'longitude': 143.1324, 'confidence': 92, 'surface_temperature_celcius': 71}
# {'_id': ObjectId('628a4077c40eee0972357cf8'), 'latitude': -36.663000000000004, 'longitude': 142.8567, 'confidence': 92, 'surface_temperature_celcius': 71}
# {'_id': ObjectId('628a4077c40eee0972357d7a'), 'latitude': -38.0148, 'longitude': 146.5413, 'confidence': 87, 'surface_temperature_celcius': 71}
# {'_id': ObjectId('628a4077c40eee097235807c'), 'latitude': -36.1346, 'longitude': 145.2196, 'confidence': 92, 'surface_temperature_celcius': 71}
# {'_id': ObjectId('628a4077c40eee09723580ad'), 'latitude': -36.0714, 'longitude': 145.7665, 'confidence': 92, 'surface_temperature_celcius': 71}
# {'_id': ObjectId('628a4077c40eee09723580fa'), 'latitude': -36.5586, 'longitude': 144.0423, 'confidence': 92, 'surface_temperature_celcius': 71}
# {'_id': ObjectId('628a4077c40eee0972358181'), 'latitude': -36.1367, 'longitude': 145.2071, 'confidence': 92, 'surface_temperature_celcius': 71}
# {'_id': ObjectId('628a4077c40eee09723581be'), 'latitude': -36.6823, 'longitude': 142.5024, 'confidence': 93, 'surface_temperature_celcius': 71}
# {'_id': ObjectId('628a4077c40eee0972358249'), 'latitude': -36.0844, 'longitude': 141.4934, 'confidence': 81, 'surface_temperature_celcius': 71}
# {'_id': ObjectId('628a4077c40eee097235826e'), 'latitude': -37.8161, 'longitude': 142.9286, 'confidence': 92, 'surface_temperature_celcius': 71}
# {'_id': ObjectId('628a4077c40eee09723582fe'), 'latitude': -36.6299, 'longitude': 142.4234, 'confidence': 66, 'surface_temperature_celcius': 71}
# {'_id': ObjectId('628a4077c40eee0972358391'), 'latitude': -36.4557, 'longitude': 142.2434, 'confidence': 92, 'surface_temperature_celcius': 71}
# {'_id': ObjectId('628a4077c40eee0972358416'), 'latitude': -37.0193, 'longitude': 148.1459, 'confidence': 84, 'surface_temperature_celcius': 71}
# {'_id': ObjectId('628a4077c40eee0972357aa9'), 'latitude': -37.562, 'longitude': 148.05, 'confidence': 61, 'surface_temperature_celcius': 72}
# {'_id': ObjectId('628a4077c40eee0972357cae'), 'latitude': -36.2306, 'longitude': 143.6408, 'confidence': 93, 'surface_temperature_celcius': 72}
# {'_id': ObjectId('628a4077c40eee0972357d36'), 'latitude': -36.6657, 'longitude': 143.1675, 'confidence': 93, 'surface_temperature_celcius': 72}
# {'_id': ObjectId('628a4077c40eee0972357d6d'), 'latitude': -37.5135, 'longitude': 142.7238, 'confidence': 93, 'surface_temperature_celcius': 72}
# {'_id': ObjectId('628a4077c40eee0972357d93'), 'latitude': -36.6942, 'longitude': 143.8021, 'confidence': 93, 'surface_temperature_celcius': 72}
# {'_id': ObjectId('628a4077c40eee0972357dd2'), 'latitude': -36.9303, 'longitude': 143.1034, 'confidence': 70, 'surface_temperature_celcius': 72}
# {'_id': ObjectId('628a4077c40eee0972357df3'), 'latitude': -36.9111, 'longitude': 142.692, 'confidence': 93, 'surface_temperature_celcius': 72}
# {'_id': ObjectId('628a4077c40eee0972357e04'), 'latitude': -37.769, 'longitude': 147.94, 'confidence': 93, 'surface_temperature_celcius': 72}
# {'_id': ObjectId('628a4077c40eee0972357e4c'), 'latitude': -36.1964, 'longitude': 144.5217, 'confidence': 93, 'surface_temperature_celcius': 72}
# {'_id': ObjectId('628a4077c40eee0972357e67'), 'latitude': -36.5871, 'longitude': 144.4958, 'confidence': 93, 'surface_temperature_celcius': 72}
# {'_id': ObjectId('628a4077c40eee0972357eee'), 'latitude': -37.9157, 'longitude': 143.3544, 'confidence': 93, 'surface_temperature_celcius': 72}
# {'_id': ObjectId('628a4077c40eee0972357f61'), 'latitude': -36.8879, 'longitude': 141.6647, 'confidence': 93, 'surface_temperature_celcius': 72}
# {'_id': ObjectId('628a4077c40eee0972357f70'), 'latitude': -36.663000000000004, 'longitude': 141.3038, 'confidence': 93, 'surface_temperature_celcius': 72}
# {'_id': ObjectId('628a4077c40eee0972358027'), 'latitude': -36.1941, 'longitude': 143.1604, 'confidence': 93, 'surface_temperature_celcius': 72}
# {'_id': ObjectId('628a4077c40eee0972358090'), 'latitude': -36.5243, 'longitude': 142.0839, 'confidence': 93, 'surface_temperature_celcius': 72}
# {'_id': ObjectId('628a4077c40eee097235823f'), 'latitude': -37.5888, 'longitude': 148.5949, 'confidence': 93, 'surface_temperature_celcius': 72}
# {'_id': ObjectId('628a4077c40eee0972358288'), 'latitude': -36.6986, 'longitude': 142.7259, 'confidence': 86, 'surface_temperature_celcius': 72}
# {'_id': ObjectId('628a4077c40eee09723582b2'), 'latitude': -37.3165, 'longitude': 147.4932, 'confidence': 93, 'surface_temperature_celcius': 72}
# {'_id': ObjectId('628a4077c40eee0972358311'), 'latitude': -37.0769, 'longitude': 141.042, 'confidence': 93, 'surface_temperature_celcius': 72}
# {'_id': ObjectId('628a4077c40eee097235832b'), 'latitude': -37.7465, 'longitude': 143.3806, 'confidence': 93, 'surface_temperature_celcius': 72}
# {'_id': ObjectId('628a4077c40eee097235835c'), 'latitude': -37.3046, 'longitude': 143.5448, 'confidence': 93, 'surface_temperature_celcius': 72}
# {'_id': ObjectId('628a4077c40eee097235840a'), 'latitude': -34.3539, 'longitude': 141.5547, 'confidence': 93, 'surface_temperature_celcius': 72}
# {'_id': ObjectId('628a4077c40eee09723579c8'), 'latitude': -37.875, 'longitude': 142.51, 'confidence': 93, 'surface_temperature_celcius': 73}
# {'_id': ObjectId('628a4077c40eee09723579cf'), 'latitude': -38.056999999999995, 'longitude': 144.211, 'confidence': 93, 'surface_temperature_celcius': 73}
# {'_id': ObjectId('628a4077c40eee0972357a0f'), 'latitude': -37.945, 'longitude': 144.35399999999998, 'confidence': 93, 'surface_temperature_celcius': 73}
# {'_id': ObjectId('628a4077c40eee0972357b77'), 'latitude': -37.4984, 'longitude': 142.9739, 'confidence': 93, 'surface_temperature_celcius': 73}
# {'_id': ObjectId('628a4077c40eee0972357c15'), 'latitude': -37.4671, 'longitude': 145.9962, 'confidence': 93, 'surface_temperature_celcius': 73}
# {'_id': ObjectId('628a4077c40eee0972357d02'), 'latitude': -37.6982, 'longitude': 143.0549, 'confidence': 94, 'surface_temperature_celcius': 73}
# {'_id': ObjectId('628a4077c40eee0972357d78'), 'latitude': -38.0132, 'longitude': 146.5269, 'confidence': 88, 'surface_temperature_celcius': 73}
# {'_id': ObjectId('628a4077c40eee0972357d9b'), 'latitude': -36.4046, 'longitude': 141.1534, 'confidence': 93, 'surface_temperature_celcius': 73}
# {'_id': ObjectId('628a4077c40eee0972357dab'), 'latitude': -36.388000000000005, 'longitude': 141.8309, 'confidence': 93, 'surface_temperature_celcius': 73}
# {'_id': ObjectId('628a4077c40eee0972357e88'), 'latitude': -37.7274, 'longitude': 142.9536, 'confidence': 94, 'surface_temperature_celcius': 73}
# {'_id': ObjectId('628a4077c40eee0972357ea2'), 'latitude': -38.1693, 'longitude': 143.0466, 'confidence': 93, 'surface_temperature_celcius': 73}
# {'_id': ObjectId('628a4077c40eee0972357ed9'), 'latitude': -38.1224, 'longitude': 143.7553, 'confidence': 94, 'surface_temperature_celcius': 73}
# {'_id': ObjectId('628a4077c40eee0972357f10'), 'latitude': -37.7236, 'longitude': 142.947, 'confidence': 94, 'surface_temperature_celcius': 73}
# {'_id': ObjectId('628a4077c40eee0972357f6e'), 'latitude': -36.4899, 'longitude': 142.2805, 'confidence': 93, 'surface_temperature_celcius': 73}
# {'_id': ObjectId('628a4077c40eee0972357f88'), 'latitude': -36.91, 'longitude': 141.0704, 'confidence': 93, 'surface_temperature_celcius': 73}
# {'_id': ObjectId('628a4077c40eee0972357fff'), 'latitude': -36.8238, 'longitude': 143.5724, 'confidence': 93, 'surface_temperature_celcius': 73}
# {'_id': ObjectId('628a4077c40eee0972358037'), 'latitude': -35.0616, 'longitude': 141.4417, 'confidence': 93, 'surface_temperature_celcius': 73}
# {'_id': ObjectId('628a4077c40eee0972358173'), 'latitude': -36.3313, 'longitude': 141.0017, 'confidence': 94, 'surface_temperature_celcius': 73}
# {'_id': ObjectId('628a4077c40eee09723581c6'), 'latitude': -36.4489, 'longitude': 144.7685, 'confidence': 93, 'surface_temperature_celcius': 73}
# {'_id': ObjectId('628a4077c40eee0972358394'), 'latitude': -36.8099, 'longitude': 142.72799999999998, 'confidence': 93, 'surface_temperature_celcius': 73}
# {'_id': ObjectId('628a4077c40eee09723583cb'), 'latitude': -37.522, 'longitude': 143.3874, 'confidence': 71, 'surface_temperature_celcius': 73}
# {'_id': ObjectId('628a4077c40eee097235841c'), 'latitude': -37.2284, 'longitude': 147.9187, 'confidence': 94, 'surface_temperature_celcius': 73}
# {'_id': ObjectId('628a4077c40eee0972357bc6'), 'latitude': -38.049, 'longitude': 146.0513, 'confidence': 94, 'surface_temperature_celcius': 74}
# {'_id': ObjectId('628a4077c40eee0972357bd1'), 'latitude': -36.2775, 'longitude': 146.1026, 'confidence': 94, 'surface_temperature_celcius': 74}
# {'_id': ObjectId('628a4077c40eee0972357c8b'), 'latitude': -37.4357, 'longitude': 142.7813, 'confidence': 94, 'surface_temperature_celcius': 74}
# {'_id': ObjectId('628a4077c40eee0972357d53'), 'latitude': -37.7609, 'longitude': 143.1633, 'confidence': 94, 'surface_temperature_celcius': 74}
# {'_id': ObjectId('628a4077c40eee0972357d6e'), 'latitude': -36.2121, 'longitude': 144.6885, 'confidence': 94, 'surface_temperature_celcius': 74}
# {'_id': ObjectId('628a4077c40eee0972357e2d'), 'latitude': -36.1546, 'longitude': 141.8146, 'confidence': 88, 'surface_temperature_celcius': 74}
# {'_id': ObjectId('628a4077c40eee0972357fb2'), 'latitude': -36.3966, 'longitude': 141.406, 'confidence': 94, 'surface_temperature_celcius': 74}
# {'_id': ObjectId('628a4077c40eee09723581e8'), 'latitude': -37.34, 'longitude': 149.3668, 'confidence': 67, 'surface_temperature_celcius': 74}
# {'_id': ObjectId('628a4077c40eee0972358399'), 'latitude': -36.7806, 'longitude': 141.5597, 'confidence': 94, 'surface_temperature_celcius': 74}
# {'_id': ObjectId('628a4077c40eee09723583fd'), 'latitude': -36.7152, 'longitude': 141.3853, 'confidence': 94, 'surface_temperature_celcius': 74}
# {'_id': ObjectId('628a4077c40eee09723579ca'), 'latitude': -37.613, 'longitude': 149.305, 'confidence': 95, 'surface_temperature_celcius': 75}
# {'_id': ObjectId('628a4077c40eee0972357bfa'), 'latitude': -36.0828, 'longitude': 145.873, 'confidence': 94, 'surface_temperature_celcius': 75}
# {'_id': ObjectId('628a4077c40eee0972357c21'), 'latitude': -36.4179, 'longitude': 144.2924, 'confidence': 94, 'surface_temperature_celcius': 75}
# {'_id': ObjectId('628a4077c40eee0972357f7c'), 'latitude': -36.092, 'longitude': 141.7306, 'confidence': 94, 'surface_temperature_celcius': 75}
# {'_id': ObjectId('628a4077c40eee09723580b9'), 'latitude': -36.2933, 'longitude': 141.36, 'confidence': 94, 'surface_temperature_celcius': 75}
# {'_id': ObjectId('628a4077c40eee09723580ea'), 'latitude': -36.4816, 'longitude': 141.6635, 'confidence': 94, 'surface_temperature_celcius': 75}
# {'_id': ObjectId('628a4077c40eee097235814c'), 'latitude': -35.0706, 'longitude': 141.4435, 'confidence': 95, 'surface_temperature_celcius': 75}
# {'_id': ObjectId('628a4077c40eee0972358166'), 'latitude': -37.8906, 'longitude': 146.2035, 'confidence': 95, 'surface_temperature_celcius': 75}
# {'_id': ObjectId('628a4077c40eee0972358196'), 'latitude': -37.5812, 'longitude': 142.7374, 'confidence': 94, 'surface_temperature_celcius': 75}
# {'_id': ObjectId('628a4077c40eee09723581a2'), 'latitude': -37.4028, 'longitude': 143.6932, 'confidence': 95, 'surface_temperature_celcius': 75}
# {'_id': ObjectId('628a4077c40eee09723583da'), 'latitude': -37.7805, 'longitude': 143.5003, 'confidence': 95, 'surface_temperature_celcius': 75}
# {'_id': ObjectId('628a4077c40eee097235840d'), 'latitude': -36.9959, 'longitude': 148.2118, 'confidence': 95, 'surface_temperature_celcius': 75}
# {'_id': ObjectId('628a4077c40eee0972358412'), 'latitude': -34.3555, 'longitude': 141.5495, 'confidence': 94, 'surface_temperature_celcius': 75}
# {'_id': ObjectId('628a4077c40eee09723579ff'), 'latitude': -37.618, 'longitude': 149.281, 'confidence': 95, 'surface_temperature_celcius': 76}
# {'_id': ObjectId('628a4077c40eee0972357aa7'), 'latitude': -37.436, 'longitude': 148.088, 'confidence': 86, 'surface_temperature_celcius': 76}
# {'_id': ObjectId('628a4077c40eee0972357bcc'), 'latitude': -36.0396, 'longitude': 141.7183, 'confidence': 95, 'surface_temperature_celcius': 76}
# {'_id': ObjectId('628a4077c40eee0972357c5c'), 'latitude': -37.6854, 'longitude': 143.4543, 'confidence': 95, 'surface_temperature_celcius': 76}
# {'_id': ObjectId('628a4077c40eee0972357cce'), 'latitude': -36.0885, 'longitude': 145.0359, 'confidence': 95, 'surface_temperature_celcius': 76}
# {'_id': ObjectId('628a4077c40eee0972357cdf'), 'latitude': -37.9509, 'longitude': 143.9599, 'confidence': 95, 'surface_temperature_celcius': 76}
# {'_id': ObjectId('628a4077c40eee0972357d05'), 'latitude': -36.7187, 'longitude': 143.805, 'confidence': 95, 'surface_temperature_celcius': 76}
# {'_id': ObjectId('628a4077c40eee0972357db9'), 'latitude': -36.6537, 'longitude': 143.8781, 'confidence': 95, 'surface_temperature_celcius': 76}
# {'_id': ObjectId('628a4077c40eee0972357dc1'), 'latitude': -38.1987, 'longitude': 147.0666, 'confidence': 95, 'surface_temperature_celcius': 76}
# {'_id': ObjectId('628a4077c40eee0972357dd8'), 'latitude': -36.3014, 'longitude': 143.203, 'confidence': 95, 'surface_temperature_celcius': 76}
# {'_id': ObjectId('628a4077c40eee0972357f5c'), 'latitude': -36.6995, 'longitude': 142.97799999999998, 'confidence': 95, 'surface_temperature_celcius': 76}
# {'_id': ObjectId('628a4077c40eee0972358115'), 'latitude': -36.8681, 'longitude': 143.5186, 'confidence': 95, 'surface_temperature_celcius': 76}
# {'_id': ObjectId('628a4077c40eee0972358188'), 'latitude': -36.1418, 'longitude': 144.0261, 'confidence': 95, 'surface_temperature_celcius': 76}
# {'_id': ObjectId('628a4077c40eee0972358221'), 'latitude': -37.224000000000004, 'longitude': 147.4347, 'confidence': 95, 'surface_temperature_celcius': 76}
# {'_id': ObjectId('628a4077c40eee097235822e'), 'latitude': -36.1104, 'longitude': 145.9829, 'confidence': 90, 'surface_temperature_celcius': 76}
# {'_id': ObjectId('628a4077c40eee09723582b6'), 'latitude': -37.3158, 'longitude': 147.4986, 'confidence': 95, 'surface_temperature_celcius': 76}
# {'_id': ObjectId('628a4077c40eee09723582c0'), 'latitude': -37.4323, 'longitude': 147.6583, 'confidence': 95, 'surface_temperature_celcius': 76}
# {'_id': ObjectId('628a4077c40eee09723582e9'), 'latitude': -36.1122, 'longitude': 142.1491, 'confidence': 90, 'surface_temperature_celcius': 76}
# {'_id': ObjectId('628a4077c40eee097235835f'), 'latitude': -36.4312, 'longitude': 141.2064, 'confidence': 95, 'surface_temperature_celcius': 76}
# {'_id': ObjectId('628a4077c40eee0972358392'), 'latitude': -36.8009, 'longitude': 142.7259, 'confidence': 95, 'surface_temperature_celcius': 76}
# {'_id': ObjectId('628a4077c40eee0972357a2d'), 'latitude': -37.475, 'longitude': 143.365, 'confidence': 96, 'surface_temperature_celcius': 77}
# {'_id': ObjectId('628a4077c40eee0972357a5a'), 'latitude': -38.126999999999995, 'longitude': 143.82, 'confidence': 96, 'surface_temperature_celcius': 77}
# {'_id': ObjectId('628a4077c40eee0972357aa4'), 'latitude': -37.452, 'longitude': 148.115, 'confidence': 68, 'surface_temperature_celcius': 77}
# {'_id': ObjectId('628a4077c40eee0972357b84'), 'latitude': -36.3387, 'longitude': 141.7542, 'confidence': 96, 'surface_temperature_celcius': 77}
# {'_id': ObjectId('628a4077c40eee0972357ba6'), 'latitude': -36.3402, 'longitude': 141.7429, 'confidence': 96, 'surface_temperature_celcius': 77}
# {'_id': ObjectId('628a4077c40eee0972357bdd'), 'latitude': -36.3254, 'longitude': 144.3638, 'confidence': 95, 'surface_temperature_celcius': 77}
# {'_id': ObjectId('628a4077c40eee0972357c2e'), 'latitude': -36.8094, 'longitude': 142.8885, 'confidence': 96, 'surface_temperature_celcius': 77}
# {'_id': ObjectId('628a4077c40eee0972357cd9'), 'latitude': -36.6139, 'longitude': 143.501, 'confidence': 95, 'surface_temperature_celcius': 77}
# {'_id': ObjectId('628a4077c40eee0972357dd4'), 'latitude': -36.3195, 'longitude': 146.0601, 'confidence': 83, 'surface_temperature_celcius': 77}
# {'_id': ObjectId('628a4077c40eee0972357ea4'), 'latitude': -36.7128, 'longitude': 142.3717, 'confidence': 95, 'surface_temperature_celcius': 77}
# {'_id': ObjectId('628a4077c40eee0972357f90'), 'latitude': -36.738, 'longitude': 142.1177, 'confidence': 95, 'surface_temperature_celcius': 77}
# {'_id': ObjectId('628a4077c40eee0972357fa8'), 'latitude': -36.5199, 'longitude': 144.7311, 'confidence': 95, 'surface_temperature_celcius': 77}
# {'_id': ObjectId('628a4077c40eee097235808d'), 'latitude': -36.3823, 'longitude': 141.3146, 'confidence': 95, 'surface_temperature_celcius': 77}
# {'_id': ObjectId('628a4077c40eee0972358163'), 'latitude': -37.9152, 'longitude': 145.8808, 'confidence': 95, 'surface_temperature_celcius': 77}
# {'_id': ObjectId('628a4077c40eee097235819c'), 'latitude': -37.8247, 'longitude': 143.6243, 'confidence': 95, 'surface_temperature_celcius': 77}
# {'_id': ObjectId('628a4077c40eee0972358269'), 'latitude': -37.7542, 'longitude': 142.9949, 'confidence': 96, 'surface_temperature_celcius': 77}
# {'_id': ObjectId('628a4077c40eee0972358330'), 'latitude': -37.8072, 'longitude': 145.9738, 'confidence': 95, 'surface_temperature_celcius': 77}
# {'_id': ObjectId('628a4077c40eee09723583dd'), 'latitude': -37.8774, 'longitude': 145.8213, 'confidence': 95, 'surface_temperature_celcius': 77}
# {'_id': ObjectId('628a4077c40eee0972357ab1'), 'latitude': -37.379, 'longitude': 148.132, 'confidence': 62, 'surface_temperature_celcius': 78}
# {'_id': ObjectId('628a4077c40eee0972357b1b'), 'latitude': -36.1002, 'longitude': 142.3405, 'confidence': 96, 'surface_temperature_celcius': 78}
# {'_id': ObjectId('628a4077c40eee0972357b5b'), 'latitude': -36.8359, 'longitude': 146.6448, 'confidence': 96, 'surface_temperature_celcius': 78}
# {'_id': ObjectId('628a4077c40eee0972357b78'), 'latitude': -37.253, 'longitude': 144.3681, 'confidence': 96, 'surface_temperature_celcius': 78}
# {'_id': ObjectId('628a4077c40eee0972357bb9'), 'latitude': -36.8616, 'longitude': 142.8025, 'confidence': 90, 'surface_temperature_celcius': 78}
# {'_id': ObjectId('628a4077c40eee0972357c1f'), 'latitude': -37.3656, 'longitude': 141.3903, 'confidence': 84, 'surface_temperature_celcius': 78}
# {'_id': ObjectId('628a4077c40eee0972357c63'), 'latitude': -38.0866, 'longitude': 143.9534, 'confidence': 96, 'surface_temperature_celcius': 78}
# {'_id': ObjectId('628a4077c40eee0972357c84'), 'latitude': -36.3438, 'longitude': 141.5832, 'confidence': 96, 'surface_temperature_celcius': 78}
# {'_id': ObjectId('628a4077c40eee0972357ccf'), 'latitude': -36.3193, 'longitude': 145.9162, 'confidence': 96, 'surface_temperature_celcius': 78}
# {'_id': ObjectId('628a4077c40eee0972357cf6'), 'latitude': -38.0933, 'longitude': 143.9824, 'confidence': 96, 'surface_temperature_celcius': 78}
# {'_id': ObjectId('628a4077c40eee0972357d7c'), 'latitude': -37.8429, 'longitude': 147.2691, 'confidence': 96, 'surface_temperature_celcius': 78}
# {'_id': ObjectId('628a4077c40eee0972357de8'), 'latitude': -37.6775, 'longitude': 148.5131, 'confidence': 86, 'surface_temperature_celcius': 78}
# {'_id': ObjectId('628a4077c40eee0972357e19'), 'latitude': -36.5847, 'longitude': 145.1968, 'confidence': 96, 'surface_temperature_celcius': 78}
# {'_id': ObjectId('628a4077c40eee0972357f03'), 'latitude': -37.7935, 'longitude': 143.1606, 'confidence': 96, 'surface_temperature_celcius': 78}
# {'_id': ObjectId('628a4077c40eee0972357ff5'), 'latitude': -36.1898, 'longitude': 145.0922, 'confidence': 96, 'surface_temperature_celcius': 78}
# {'_id': ObjectId('628a4077c40eee097235801d'), 'latitude': -36.7531, 'longitude': 141.3253, 'confidence': 84, 'surface_temperature_celcius': 78}
# {'_id': ObjectId('628a4077c40eee0972358026'), 'latitude': -36.9498, 'longitude': 142.2012, 'confidence': 96, 'surface_temperature_celcius': 78}
# {'_id': ObjectId('628a4077c40eee097235821d'), 'latitude': -37.222, 'longitude': 147.4689, 'confidence': 96, 'surface_temperature_celcius': 78}
# {'_id': ObjectId('628a4077c40eee0972358266'), 'latitude': -37.803000000000004, 'longitude': 142.3151, 'confidence': 83, 'surface_temperature_celcius': 78}
# {'_id': ObjectId('628a4077c40eee09723582f2'), 'latitude': -36.1955, 'longitude': 145.914, 'confidence': 96, 'surface_temperature_celcius': 78}
# {'_id': ObjectId('628a4077c40eee097235830f'), 'latitude': -36.6006, 'longitude': 141.9657, 'confidence': 96, 'surface_temperature_celcius': 78}
# {'_id': ObjectId('628a4077c40eee0972358331'), 'latitude': -37.3704, 'longitude': 145.8942, 'confidence': 96, 'surface_temperature_celcius': 78}
# {'_id': ObjectId('628a4077c40eee0972357ab9'), 'latitude': -37.400999999999996, 'longitude': 148.067, 'confidence': 100, 'surface_temperature_celcius': 79}
# {'_id': ObjectId('628a4077c40eee0972357c1c'), 'latitude': -36.2842, 'longitude': 141.1741, 'confidence': 96, 'surface_temperature_celcius': 79}
# {'_id': ObjectId('628a4077c40eee0972357da0'), 'latitude': -36.0594, 'longitude': 141.5907, 'confidence': 96, 'surface_temperature_celcius': 79}
# {'_id': ObjectId('628a4077c40eee0972357ec8'), 'latitude': -36.6787, 'longitude': 144.8042, 'confidence': 96, 'surface_temperature_celcius': 79}
# {'_id': ObjectId('628a4077c40eee0972357f48'), 'latitude': -36.5987, 'longitude': 144.4995, 'confidence': 96, 'surface_temperature_celcius': 79}
# {'_id': ObjectId('628a4077c40eee0972357ffb'), 'latitude': -36.8298, 'longitude': 143.4483, 'confidence': 96, 'surface_temperature_celcius': 79}
# {'_id': ObjectId('628a4077c40eee097235801b'), 'latitude': -36.7432, 'longitude': 141.3296, 'confidence': 84, 'surface_temperature_celcius': 79}
# {'_id': ObjectId('628a4077c40eee09723580e0'), 'latitude': -36.1067, 'longitude': 143.7948, 'confidence': 97, 'surface_temperature_celcius': 79}
# {'_id': ObjectId('628a4077c40eee0972358187'), 'latitude': -36.1518, 'longitude': 144.0233, 'confidence': 96, 'surface_temperature_celcius': 79}
# {'_id': ObjectId('628a4077c40eee0972358303'), 'latitude': -36.1925, 'longitude': 145.93, 'confidence': 97, 'surface_temperature_celcius': 79}
# {'_id': ObjectId('628a4077c40eee09723583e6'), 'latitude': -37.6622, 'longitude': 142.1001, 'confidence': 96, 'surface_temperature_celcius': 79}
# {'_id': ObjectId('628a4077c40eee0972358411'), 'latitude': -34.3554, 'longitude': 141.5413, 'confidence': 96, 'surface_temperature_celcius': 79}
# {'_id': ObjectId('628a4077c40eee0972357a0b'), 'latitude': -37.61, 'longitude': 149.30700000000002, 'confidence': 97, 'surface_temperature_celcius': 80}
# {'_id': ObjectId('628a4077c40eee0972357a30'), 'latitude': -37.69, 'longitude': 143.605, 'confidence': 97, 'surface_temperature_celcius': 80}
# {'_id': ObjectId('628a4077c40eee0972357b06'), 'latitude': -36.369, 'longitude': 143.7132, 'confidence': 97, 'surface_temperature_celcius': 80}
# {'_id': ObjectId('628a4077c40eee0972357cec'), 'latitude': -36.6224, 'longitude': 143.5092, 'confidence': 97, 'surface_temperature_celcius': 80}
# {'_id': ObjectId('628a4077c40eee0972357d73'), 'latitude': -36.2206, 'longitude': 144.6856, 'confidence': 97, 'surface_temperature_celcius': 80}
# {'_id': ObjectId('628a4077c40eee097235804a'), 'latitude': -36.7787, 'longitude': 141.4449, 'confidence': 97, 'surface_temperature_celcius': 80}
# {'_id': ObjectId('628a4077c40eee09723580aa'), 'latitude': -37.0669, 'longitude': 141.0556, 'confidence': 97, 'surface_temperature_celcius': 80}
# {'_id': ObjectId('628a4077c40eee09723580d1'), 'latitude': -36.8158, 'longitude': 142.6229, 'confidence': 97, 'surface_temperature_celcius': 80}
# {'_id': ObjectId('628a4077c40eee09723580fe'), 'latitude': -36.4612, 'longitude': 144.7775, 'confidence': 91, 'surface_temperature_celcius': 80}
# {'_id': ObjectId('628a4077c40eee097235810c'), 'latitude': -36.601, 'longitude': 144.6378, 'confidence': 97, 'surface_temperature_celcius': 80}
# {'_id': ObjectId('628a4077c40eee0972358132'), 'latitude': -37.7587, 'longitude': 142.8521, 'confidence': 84, 'surface_temperature_celcius': 80}
# {'_id': ObjectId('628a4077c40eee09723581f5'), 'latitude': -37.3493, 'longitude': 149.3691, 'confidence': 66, 'surface_temperature_celcius': 80}
# {'_id': ObjectId('628a4077c40eee097235839e'), 'latitude': -37.0924, 'longitude': 141.89700000000002, 'confidence': 97, 'surface_temperature_celcius': 80}
# {'_id': ObjectId('628a4077c40eee09723583a6'), 'latitude': -37.9452, 'longitude': 143.5834, 'confidence': 97, 'surface_temperature_celcius': 80}
# {'_id': ObjectId('628a4077c40eee09723583fb'), 'latitude': -37.0155, 'longitude': 148.1432, 'confidence': 97, 'surface_temperature_celcius': 80}
# {'_id': ObjectId('628a4077c40eee097235841d'), 'latitude': -37.6572, 'longitude': 142.0703, 'confidence': 97, 'surface_temperature_celcius': 80}
# {'_id': ObjectId('628a4077c40eee0972357c29'), 'latitude': -36.4169, 'longitude': 144.2994, 'confidence': 97, 'surface_temperature_celcius': 81}
# {'_id': ObjectId('628a4077c40eee0972357cc3'), 'latitude': -36.4211, 'longitude': 141.6875, 'confidence': 97, 'surface_temperature_celcius': 81}
# {'_id': ObjectId('628a4077c40eee0972357ea5'), 'latitude': -37.4885, 'longitude': 142.0658, 'confidence': 97, 'surface_temperature_celcius': 81}
# {'_id': ObjectId('628a4077c40eee0972357ff4'), 'latitude': -36.6527, 'longitude': 142.7392, 'confidence': 97, 'surface_temperature_celcius': 81}
# {'_id': ObjectId('628a4077c40eee09723580fc'), 'latitude': -36.4538, 'longitude': 144.763, 'confidence': 97, 'surface_temperature_celcius': 81}
# {'_id': ObjectId('628a4077c40eee097235826b'), 'latitude': -37.7617, 'longitude': 143.08100000000002, 'confidence': 97, 'surface_temperature_celcius': 81}
# {'_id': ObjectId('628a4077c40eee09723582f5'), 'latitude': -36.5989, 'longitude': 141.9771, 'confidence': 92, 'surface_temperature_celcius': 81}
# {'_id': ObjectId('628a4077c40eee09723583b6'), 'latitude': -37.9247, 'longitude': 142.8999, 'confidence': 97, 'surface_temperature_celcius': 81}
# {'_id': ObjectId('628a4077c40eee09723583be'), 'latitude': -35.0805, 'longitude': 142.4642, 'confidence': 97, 'surface_temperature_celcius': 81}
# {'_id': ObjectId('628a4077c40eee0972357ab0'), 'latitude': -37.379, 'longitude': 148.126, 'confidence': 58, 'surface_temperature_celcius': 82}
# ...
# {'_id': ObjectId('628a4077c40eee097235823e'), 'latitude': -37.777, 'longitude': 148.4128, 'confidence': 99, 'surface_temperature_celcius': 85}
# {'_id': ObjectId('628a4077c40eee09723579fa'), 'latitude': -37.6, 'longitude': 149.325, 'confidence': 99, 'surface_temperature_celcius': 86}
# {'_id': ObjectId('628a4077c40eee0972357c26'), 'latitude': -36.2882, 'longitude': 141.1821, 'confidence': 99, 'surface_temperature_celcius': 86}
# {'_id': ObjectId('628a4077c40eee0972357d5f'), 'latitude': -36.7153, 'longitude': 143.8226, 'confidence': 99, 'surface_temperature_celcius': 86}
# {'_id': ObjectId('628a4077c40eee0972357df9'), 'latitude': -37.5115, 'longitude': 143.14, 'confidence': 99, 'surface_temperature_celcius': 86}
# {'_id': ObjectId('628a4077c40eee0972357f6d'), 'latitude': -35.8768, 'longitude': 145.4627, 'confidence': 100, 'surface_temperature_celcius': 86}
# {'_id': ObjectId('628a4077c40eee0972358281'), 'latitude': -36.6349, 'longitude': 142.2125, 'confidence': 94, 'surface_temperature_celcius': 86}
# {'_id': ObjectId('628a4077c40eee097235835a'), 'latitude': -37.7236, 'longitude': 143.3995, 'confidence': 99, 'surface_temperature_celcius': 86}
# {'_id': ObjectId('628a4077c40eee09723583ac'), 'latitude': -34.351, 'longitude': 141.6567, 'confidence': 99, 'surface_temperature_celcius': 86}
# {'_id': ObjectId('628a4077c40eee0972357a09'), 'latitude': -37.606, 'longitude': 149.312, 'confidence': 100, 'surface_temperature_celcius': 87}
# {'_id': ObjectId('628a4077c40eee0972357a56'), 'latitude': -37.294000000000004, 'longitude': 141.232, 'confidence': 100, 'surface_temperature_celcius': 87}
# {'_id': ObjectId('628a4077c40eee0972357ae0'), 'latitude': -37.4796, 'longitude': 141.9403, 'confidence': 94, 'surface_temperature_celcius': 87}
# {'_id': ObjectId('628a4077c40eee0972357b96'), 'latitude': -36.345, 'longitude': 143.4256, 'confidence': 100, 'surface_temperature_celcius': 87}
# {'_id': ObjectId('628a4077c40eee0972357d22'), 'latitude': -36.664, 'longitude': 142.8802, 'confidence': 100, 'surface_temperature_celcius': 87}
# {'_id': ObjectId('628a4077c40eee0972357d7b'), 'latitude': -37.8412, 'longitude': 147.2536, 'confidence': 100, 'surface_temperature_celcius': 87}
# {'_id': ObjectId('628a4077c40eee0972357eb6'), 'latitude': -37.9594, 'longitude': 143.5638, 'confidence': 100, 'surface_temperature_celcius': 87}
# {'_id': ObjectId('628a4077c40eee0972358023'), 'latitude': -36.7957, 'longitude': 143.9652, 'confidence': 100, 'surface_temperature_celcius': 87}
# {'_id': ObjectId('628a4077c40eee09723580ec'), 'latitude': -36.0837, 'longitude': 144.2448, 'confidence': 100, 'surface_temperature_celcius': 87}
# {'_id': ObjectId('628a4077c40eee0972357aa2'), 'latitude': -37.406, 'longitude': 148.123, 'confidence': 100, 'surface_temperature_celcius': 88}
# {'_id': ObjectId('628a4077c40eee0972357b05'), 'latitude': -36.3756, 'longitude': 143.7243, 'confidence': 100, 'surface_temperature_celcius': 88}
# {'_id': ObjectId('628a4077c40eee0972357d65'), 'latitude': -36.7309, 'longitude': 142.3633, 'confidence': 100, 'surface_temperature_celcius': 88}
# {'_id': ObjectId('628a4077c40eee0972357e38'), 'latitude': -37.9071, 'longitude': 143.53799999999998, 'confidence': 100, 'surface_temperature_celcius': 88}
# {'_id': ObjectId('628a4077c40eee0972358038'), 'latitude': -36.3999, 'longitude': 144.737, 'confidence': 100, 'surface_temperature_celcius': 88}
# {'_id': ObjectId('628a4077c40eee097235809d'), 'latitude': -37.3847, 'longitude': 142.8935, 'confidence': 100, 'surface_temperature_celcius': 88}
# {'_id': ObjectId('628a4077c40eee0972358228'), 'latitude': -37.8429, 'longitude': 143.8366, 'confidence': 100, 'surface_temperature_celcius': 88}
# {'_id': ObjectId('628a4077c40eee09723582a9'), 'latitude': -37.6387, 'longitude': 142.9032, 'confidence': 87, 'surface_temperature_celcius': 88}
# {'_id': ObjectId('628a4077c40eee0972357b07'), 'latitude': -36.3799, 'longitude': 143.7149, 'confidence': 100, 'surface_temperature_celcius': 89}
# {'_id': ObjectId('628a4077c40eee0972357c67'), 'latitude': -38.5123, 'longitude': 146.4007, 'confidence': 100, 'surface_temperature_celcius': 89}
# {'_id': ObjectId('628a4077c40eee0972357d08'), 'latitude': -36.7742, 'longitude': 145.1991, 'confidence': 100, 'surface_temperature_celcius': 89}
# {'_id': ObjectId('628a4077c40eee0972357f12'), 'latitude': -37.7002, 'longitude': 142.9562, 'confidence': 100, 'surface_temperature_celcius': 89}
# {'_id': ObjectId('628a4077c40eee0972358035'), 'latitude': -37.0761, 'longitude': 141.0574, 'confidence': 100, 'surface_temperature_celcius': 89}
# {'_id': ObjectId('628a4077c40eee09723580bc'), 'latitude': -37.4591, 'longitude': 144.9492, 'confidence': 100, 'surface_temperature_celcius': 89}
# {'_id': ObjectId('628a4077c40eee097235821c'), 'latitude': -37.2168, 'longitude': 147.4748, 'confidence': 100, 'surface_temperature_celcius': 89}
# {'_id': ObjectId('628a4077c40eee0972358293'), 'latitude': -38.0052, 'longitude': 142.6179, 'confidence': 94, 'surface_temperature_celcius': 89}
# {'_id': ObjectId('628a4077c40eee0972358340'), 'latitude': -37.383, 'longitude': 145.9089, 'confidence': 100, 'surface_temperature_celcius': 89}
# {'_id': ObjectId('628a4077c40eee09723583ce'), 'latitude': -38.0693, 'longitude': 142.9722, 'confidence': 100, 'surface_temperature_celcius': 89}
# {'_id': ObjectId('628a4077c40eee0972357a73'), 'latitude': -37.461999999999996, 'longitude': 148.089, 'confidence': 100, 'surface_temperature_celcius': 90}
# {'_id': ObjectId('628a4077c40eee0972357b67'), 'latitude': -37.9047, 'longitude': 141.0945, 'confidence': 100, 'surface_temperature_celcius': 90}
# {'_id': ObjectId('628a4077c40eee0972357bd8'), 'latitude': -38.0361, 'longitude': 146.0567, 'confidence': 100, 'surface_temperature_celcius': 90}
# {'_id': ObjectId('628a4077c40eee0972357be6'), 'latitude': -36.1532, 'longitude': 143.5527, 'confidence': 100, 'surface_temperature_celcius': 90}
# {'_id': ObjectId('628a4077c40eee0972357cd3'), 'latitude': -36.0682, 'longitude': 146.0602, 'confidence': 100, 'surface_temperature_celcius': 90}
# {'_id': ObjectId('628a4077c40eee0972357ddd'), 'latitude': -36.3332, 'longitude': 145.8594, 'confidence': 87, 'surface_temperature_celcius': 90}
# {'_id': ObjectId('628a4077c40eee0972357ffe'), 'latitude': -36.6615, 'longitude': 144.6014, 'confidence': 100, 'surface_temperature_celcius': 90}
# {'_id': ObjectId('628a4077c40eee0972358080'), 'latitude': -37.0899, 'longitude': 141.0238, 'confidence': 100, 'surface_temperature_celcius': 90}
# {'_id': ObjectId('628a4077c40eee097235811f'), 'latitude': -37.1999, 'longitude': 143.8231, 'confidence': 100, 'surface_temperature_celcius': 90}
# {'_id': ObjectId('628a4077c40eee097235817f'), 'latitude': -36.3972, 'longitude': 141.6041, 'confidence': 100, 'surface_temperature_celcius': 90}
# {'_id': ObjectId('628a4077c40eee097235833a'), 'latitude': -37.2988, 'longitude': 143.5487, 'confidence': 100, 'surface_temperature_celcius': 90}
# {'_id': ObjectId('628a4077c40eee09723583b2'), 'latitude': -37.5012, 'longitude': 142.5853, 'confidence': 100, 'surface_temperature_celcius': 90}
# {'_id': ObjectId('628a4077c40eee0972357d96'), 'latitude': -36.3459, 'longitude': 141.5586, 'confidence': 100, 'surface_temperature_celcius': 91}
# {'_id': ObjectId('628a4077c40eee097235814d'), 'latitude': -38.0795, 'longitude': 143.2449, 'confidence': 100, 'surface_temperature_celcius': 91}
# {'_id': ObjectId('628a4077c40eee09723583f0'), 'latitude': -37.3949, 'longitude': 147.0175, 'confidence': 100, 'surface_temperature_celcius': 91}
# {'_id': ObjectId('628a4077c40eee09723580a6'), 'latitude': -36.4125, 'longitude': 143.1189, 'confidence': 100, 'surface_temperature_celcius': 92}
# {'_id': ObjectId('628a4077c40eee0972358150'), 'latitude': -35.1857, 'longitude': 141.0604, 'confidence': 100, 'surface_temperature_celcius': 92}
# {'_id': ObjectId('628a4077c40eee097235815f'), 'latitude': -36.4409, 'longitude': 141.6948, 'confidence': 100, 'surface_temperature_celcius': 92}
# {'_id': ObjectId('628a4077c40eee097235816f'), 'latitude': -35.8182, 'longitude': 143.8739, 'confidence': 100, 'surface_temperature_celcius': 92}
# {'_id': ObjectId('628a4077c40eee09723582c1'), 'latitude': -37.4343, 'longitude': 147.6327, 'confidence': 100, 'surface_temperature_celcius': 92}
# {'_id': ObjectId('628a4077c40eee0972358315'), 'latitude': -36.0973, 'longitude': 143.4279, 'confidence': 87, 'surface_temperature_celcius': 92}
# {'_id': ObjectId('628a4077c40eee0972357a2c'), 'latitude': -37.477, 'longitude': 143.352, 'confidence': 100, 'surface_temperature_celcius': 93}
# {'_id': ObjectId('628a4077c40eee0972357b61'), 'latitude': -38.4349, 'longitude': 146.3122, 'confidence': 100, 'surface_temperature_celcius': 93}
# {'_id': ObjectId('628a4077c40eee0972357bee'), 'latitude': -36.0077, 'longitude': 141.7747, 'confidence': 100, 'surface_temperature_celcius': 93}
# {'_id': ObjectId('628a4077c40eee0972357d62'), 'latitude': -36.8791, 'longitude': 142.7261, 'confidence': 100, 'surface_temperature_celcius': 93}
# {'_id': ObjectId('628a4077c40eee0972357e41'), 'latitude': -37.5043, 'longitude': 146.3299, 'confidence': 100, 'surface_temperature_celcius': 93}
# {'_id': ObjectId('628a4077c40eee0972357ede'), 'latitude': -38.0792, 'longitude': 143.7361, 'confidence': 94, 'surface_temperature_celcius': 93}
# {'_id': ObjectId('628a4077c40eee0972357fef'), 'latitude': -36.8283, 'longitude': 143.4605, 'confidence': 100, 'surface_temperature_celcius': 93}
# {'_id': ObjectId('628a4077c40eee0972358071'), 'latitude': -36.1771, 'longitude': 145.7451, 'confidence': 100, 'surface_temperature_celcius': 93}
# {'_id': ObjectId('628a4077c40eee0972358101'), 'latitude': -36.7089, 'longitude': 143.3518, 'confidence': 100, 'surface_temperature_celcius': 93}
# {'_id': ObjectId('628a4077c40eee0972358159'), 'latitude': -35.6469, 'longitude': 142.376, 'confidence': 100, 'surface_temperature_celcius': 93}
# {'_id': ObjectId('628a4077c40eee0972358162'), 'latitude': -37.9174, 'longitude': 145.8678, 'confidence': 100, 'surface_temperature_celcius': 93}
# {'_id': ObjectId('628a4077c40eee0972358332'), 'latitude': -37.297, 'longitude': 143.5753, 'confidence': 100, 'surface_temperature_celcius': 93}
# {'_id': ObjectId('628a4077c40eee0972357b92'), 'latitude': -36.3433, 'longitude': 143.4369, 'confidence': 100, 'surface_temperature_celcius': 94}
# {'_id': ObjectId('628a4077c40eee0972357da1'), 'latitude': -36.0576, 'longitude': 141.6122, 'confidence': 100, 'surface_temperature_celcius': 94}
# {'_id': ObjectId('628a4077c40eee0972357dbf'), 'latitude': -38.1917, 'longitude': 147.0745, 'confidence': 100, 'surface_temperature_celcius': 94}
# {'_id': ObjectId('628a4077c40eee0972357dd6'), 'latitude': -36.5854, 'longitude': 143.0462, 'confidence': 100, 'surface_temperature_celcius': 94}
# {'_id': ObjectId('628a4077c40eee0972357e93'), 'latitude': -37.5701, 'longitude': 142.6497, 'confidence': 100, 'surface_temperature_celcius': 94}
# {'_id': ObjectId('628a4077c40eee09723581ed'), 'latitude': -35.2378, 'longitude': 142.9864, 'confidence': 100, 'surface_temperature_celcius': 94}
# {'_id': ObjectId('628a4077c40eee0972357c0c'), 'latitude': -36.1506, 'longitude': 143.5671, 'confidence': 100, 'surface_temperature_celcius': 95}
# {'_id': ObjectId('628a4077c40eee0972357d15'), 'latitude': -36.4035, 'longitude': 140.9935, 'confidence': 100, 'surface_temperature_celcius': 95}
# {'_id': ObjectId('628a4077c40eee0972357e40'), 'latitude': -37.5027, 'longitude': 146.347, 'confidence': 100, 'surface_temperature_celcius': 95}
# {'_id': ObjectId('628a4077c40eee0972358074'), 'latitude': -38.027, 'longitude': 142.3844, 'confidence': 100, 'surface_temperature_celcius': 95}
# {'_id': ObjectId('628a4077c40eee09723580a4'), 'latitude': -35.6374, 'longitude': 142.3787, 'confidence': 100, 'surface_temperature_celcius': 95}
# {'_id': ObjectId('628a4077c40eee0972358227'), 'latitude': -35.805, 'longitude': 142.1326, 'confidence': 100, 'surface_temperature_celcius': 95}
# {'_id': ObjectId('628a4077c40eee0972358260'), 'latitude': -36.9034, 'longitude': 141.0013, 'confidence': 100, 'surface_temperature_celcius': 95}
# {'_id': ObjectId('628a4077c40eee09723582ec'), 'latitude': -37.3735, 'longitude': 145.8384, 'confidence': 100, 'surface_temperature_celcius': 95}
# {'_id': ObjectId('628a4077c40eee0972357d7f'), 'latitude': -36.5454, 'longitude': 144.7402, 'confidence': 100, 'surface_temperature_celcius': 96}
# {'_id': ObjectId('628a4077c40eee0972357f23'), 'latitude': -37.4352, 'longitude': 143.1444, 'confidence': 100, 'surface_temperature_celcius': 96}
# {'_id': ObjectId('628a4077c40eee0972358045'), 'latitude': -36.91, 'longitude': 141.2705, 'confidence': 100, 'surface_temperature_celcius': 96}
# {'_id': ObjectId('628a4077c40eee0972358172'), 'latitude': -37.9246, 'longitude': 146.2464, 'confidence': 100, 'surface_temperature_celcius': 96}
# {'_id': ObjectId('628a4077c40eee097235825a'), 'latitude': -35.811, 'longitude': 142.1403, 'confidence': 94, 'surface_temperature_celcius': 96}
# {'_id': ObjectId('628a4077c40eee0972358329'), 'latitude': -37.3735, 'longitude': 145.886, 'confidence': 87, 'surface_temperature_celcius': 96}
# {'_id': ObjectId('628a4077c40eee0972358028'), 'latitude': -36.4142, 'longitude': 143.1077, 'confidence': 100, 'surface_temperature_celcius': 97}
# {'_id': ObjectId('628a4077c40eee09723580d2'), 'latitude': -36.4518, 'longitude': 144.7752, 'confidence': 100, 'surface_temperature_celcius': 97}
# {'_id': ObjectId('628a4077c40eee097235822c'), 'latitude': -36.9918, 'longitude': 141.8667, 'confidence': 100, 'surface_temperature_celcius': 97}
# {'_id': ObjectId('628a4077c40eee097235834d'), 'latitude': -37.7974, 'longitude': 145.9535, 'confidence': 87, 'surface_temperature_celcius': 97}
# {'_id': ObjectId('628a4077c40eee0972357be2'), 'latitude': -36.0816, 'longitude': 145.859, 'confidence': 100, 'surface_temperature_celcius': 98}
# {'_id': ObjectId('628a4077c40eee0972357d4e'), 'latitude': -36.7708, 'longitude': 145.1908, 'confidence': 100, 'surface_temperature_celcius': 98}
# {'_id': ObjectId('628a4077c40eee0972357e3e'), 'latitude': -37.3902, 'longitude': 148.2955, 'confidence': 100, 'surface_temperature_celcius': 98}
# {'_id': ObjectId('628a4077c40eee0972357f20'), 'latitude': -37.5728, 'longitude': 142.6348, 'confidence': 100, 'surface_temperature_celcius': 98}
# {'_id': ObjectId('628a4077c40eee0972358198'), 'latitude': -37.5949, 'longitude': 142.6857, 'confidence': 100, 'surface_temperature_celcius': 98}
# {'_id': ObjectId('628a4077c40eee09723581b4'), 'latitude': -37.8249, 'longitude': 143.6174, 'confidence': 100, 'surface_temperature_celcius': 98}
# {'_id': ObjectId('628a4077c40eee097235831f'), 'latitude': -36.1819, 'longitude': 145.9269, 'confidence': 100, 'surface_temperature_celcius': 98}
# {'_id': ObjectId('628a4077c40eee097235833f'), 'latitude': -37.3025, 'longitude': 143.5714, 'confidence': 100, 'surface_temperature_celcius': 98}
# {'_id': ObjectId('628a4077c40eee0972358419'), 'latitude': -37.4128, 'longitude': 147.0242, 'confidence': 85, 'surface_temperature_celcius': 98}
# {'_id': ObjectId('628a4077c40eee0972357dd5'), 'latitude': -36.5839, 'longitude': 143.0588, 'confidence': 100, 'surface_temperature_celcius': 99}
# {'_id': ObjectId('628a4077c40eee0972358014'), 'latitude': -36.7499, 'longitude': 141.3006, 'confidence': 75, 'surface_temperature_celcius': 99}
# {'_id': ObjectId('628a4077c40eee0972358140'), 'latitude': -38.0254, 'longitude': 142.3959, 'confidence': 100, 'surface_temperature_celcius': 99}
# {'_id': ObjectId('628a4077c40eee097235822f'), 'latitude': -37.782, 'longitude': 148.3844, 'confidence': 100, 'surface_temperature_celcius': 99}
# {'_id': ObjectId('628a4077c40eee09723583df'), 'latitude': -37.8881, 'longitude': 145.8229, 'confidence': 100, 'surface_temperature_celcius': 99}
# {'_id': ObjectId('628a4077c40eee0972358417'), 'latitude': -37.4229, 'longitude': 147.02700000000002, 'confidence': 100, 'surface_temperature_celcius': 99}
# {'_id': ObjectId('628a4077c40eee0972358012'), 'latitude': -36.1988, 'longitude': 145.0941, 'confidence': 100, 'surface_temperature_celcius': 100}
# {'_id': ObjectId('628a4077c40eee0972358287'), 'latitude': -36.9018, 'longitude': 141.0146, 'confidence': 100, 'surface_temperature_celcius': 100}
# 476

# %% [markdown]
# ## c. Find date, surface temperature (°C), air temperature (°C), relative humidity and max wind speed on 15th and 16th of December 2021.

# %%
results = mydb.climate.aggregate([
    {
        "$lookup":{
            "from":"hotspot",
            "localField": "date",
            "foreignField": "date",
            "as":"hotspot"
        }
    },
    {
        "$match":{
            "$or":
            [
            {"date":datetime.strptime("15/12/2021","%d/%m/%Y")},
            {"date":datetime.strptime("16/12/2021","%d/%m/%Y")}
            ]
        }
    },
    {
        "$project":
        {
            "date":1, 
            "air_temperature_celcius":1, 
            "relative_humidity":1, 
            "max_wind_speed":1, 
            "hotspot":{"surface_temperature_celcius":1}
        }
    }
    
])
for x in results: 
    print (x)
# Out:
# {'_id': ObjectId('628a4076c40eee09723579ac'), 'date': datetime.datetime(2021, 12, 15, 0, 0), 'air_temperature_celcius': 18, 'relative_humidity': 52.0, 'max_wind_speed': 14.0, 'hotspot': [{'surface_temperature_celcius': 42}, {'surface_temperature_celcius': 36}, {'surface_temperature_celcius': 38}, {'surface_temperature_celcius': 40}]}
# {'_id': ObjectId('628a4076c40eee09723579ad'), 'date': datetime.datetime(2021, 12, 16, 0, 0), 'air_temperature_celcius': 18, 'relative_humidity': 53.7, 'max_wind_speed': 13.0, 'hotspot': [{'surface_temperature_celcius': 43}, {'surface_temperature_celcius': 33}, {'surface_temperature_celcius': 54}, {'surface_temperature_celcius': 73}, {'surface_temperature_celcius': 55}, {'surface_temperature_celcius': 75}, {'surface_temperature_celcius': 55}, {'surface_temperature_celcius': 66}, {'surface_temperature_celcius': 56}, {'surface_temperature_celcius': 60}, {'surface_temperature_celcius': 73}, {'surface_temperature_celcius': 48}, {'surface_temperature_celcius': 55}, {'surface_temperature_celcius': 64}, {'surface_temperature_celcius': 57}]}

# %% [markdown]
# ## d. Find datetime, air temperature (°C), surface temperature (°C) and confidence when the confidence is between 80 and 100.

# %%
results = mydb.hotspot.aggregate([
    {
        "$lookup":{
            "from":"climate",
            "localField": "date",
            "foreignField": "date",
            "as":"climate"
        }
    },
    {
        "$match":
            {"confidence":{"$gte":80,"$lte":100}}
            
        
    },
    {
        "$project":
        {
            "datetime":1, 
            "surface_temperature_celcius":1, 
            "confidence":1, 
            "climate":{"air_temperature_celcius":1}
        }
    },
    {
        "$sort":{"confidence":1}
    }
    
])

for x in results: 
    print(x)
# Out:
# {'_id': ObjectId('628a4077c40eee09723579c2'), 'datetime': '2021-12-25T04:29:08', 'confidence': 80, 'surface_temperature_celcius': 54, 'climate': [{'air_temperature_celcius': 17}]}
# {'_id': ObjectId('628a4077c40eee0972357a24'), 'datetime': '2021-11-11T13:30:08', 'confidence': 80, 'surface_temperature_celcius': 37, 'climate': [{'air_temperature_celcius': 18}]}
# {'_id': ObjectId('628a4077c40eee0972357a47'), 'datetime': '2021-10-20T04:41:19', 'confidence': 80, 'surface_temperature_celcius': 46, 'climate': [{'air_temperature_celcius': 13}]}
# {'_id': ObjectId('628a4077c40eee0972357a62'), 'datetime': '2021-10-04T04:41:02', 'confidence': 80, 'surface_temperature_celcius': 46, 'climate': [{'air_temperature_celcius': 19}]}
# {'_id': ObjectId('628a4077c40eee0972357a63'), 'datetime': '2021-10-04T04:41:00', 'confidence': 80, 'surface_temperature_celcius': 46, 'climate': [{'air_temperature_celcius': 19}]}
# {'_id': ObjectId('628a4077c40eee0972357abe'), 'datetime': '2021-09-23T04:59:11', 'confidence': 80, 'surface_temperature_celcius': 50, 'climate': [{'air_temperature_celcius': 17}]}
# {'_id': ObjectId('628a4077c40eee0972357acc'), 'datetime': '2021-09-10T04:00:00', 'confidence': 80, 'surface_temperature_celcius': 54, 'climate': [{'air_temperature_celcius': 11}]}
# {'_id': ObjectId('628a4077c40eee0972357ad8'), 'datetime': '2021-08-13T05:05:10', 'confidence': 80, 'surface_temperature_celcius': 53, 'climate': [{'air_temperature_celcius': 15}]}
# {'_id': ObjectId('628a4077c40eee0972357b49'), 'datetime': '2021-05-22T04:43:30', 'confidence': 80, 'surface_temperature_celcius': 53, 'climate': [{'air_temperature_celcius': 17}]}
# {'_id': ObjectId('628a4077c40eee0972357baa'), 'datetime': '2021-05-15T04:26:20', 'confidence': 80, 'surface_temperature_celcius': 53, 'climate': [{'air_temperature_celcius': 10}]}
# {'_id': ObjectId('628a4077c40eee0972357c2a'), 'datetime': '2021-05-11T04:50:40', 'confidence': 80, 'surface_temperature_celcius': 53, 'climate': [{'air_temperature_celcius': 9}]}
# {'_id': ObjectId('628a4077c40eee0972357c61'), 'datetime': '2021-05-10T04:08:10', 'confidence': 80, 'surface_temperature_celcius': 54, 'climate': [{'air_temperature_celcius': 10}]}
# {'_id': ObjectId('628a4077c40eee0972357c66'), 'datetime': '2021-05-10T04:08:10', 'confidence': 80, 'surface_temperature_celcius': 53, 'climate': [{'air_temperature_celcius': 10}]}
# {'_id': ObjectId('628a4077c40eee0972357c6b'), 'datetime': '2021-05-10T04:08:10', 'confidence': 80, 'surface_temperature_celcius': 53, 'climate': [{'air_temperature_celcius': 10}]}
# {'_id': ObjectId('628a4077c40eee0972357c73'), 'datetime': '2021-05-10T04:08:10', 'confidence': 80, 'surface_temperature_celcius': 53, 'climate': [{'air_temperature_celcius': 10}]}
# {'_id': ObjectId('628a4077c40eee0972357c9e'), 'datetime': '2021-05-10T04:08:10', 'confidence': 80, 'surface_temperature_celcius': 53, 'climate': [{'air_temperature_celcius': 10}]}
# {'_id': ObjectId('628a4077c40eee0972357cb4'), 'datetime': '2021-05-08T04:20:40', 'confidence': 80, 'surface_temperature_celcius': 54, 'climate': [{'air_temperature_celcius': 12}]}
# {'_id': ObjectId('628a4077c40eee0972357cfb'), 'datetime': '2021-05-04T04:51:40', 'confidence': 80, 'surface_temperature_celcius': 54, 'climate': [{'air_temperature_celcius': 10}]}
# {'_id': ObjectId('628a4077c40eee0972357cff'), 'datetime': '2021-05-04T04:51:20', 'confidence': 80, 'surface_temperature_celcius': 53, 'climate': [{'air_temperature_celcius': 10}]}
# {'_id': ObjectId('628a4077c40eee0972357d06'), 'datetime': '2021-05-04T04:48:10', 'confidence': 80, 'surface_temperature_celcius': 53, 'climate': [{'air_temperature_celcius': 10}]}
# {'_id': ObjectId('628a4077c40eee0972357d19'), 'datetime': '2021-05-04T04:46:00', 'confidence': 80, 'surface_temperature_celcius': 54, 'climate': [{'air_temperature_celcius': 10}]}
# {'_id': ObjectId('628a4077c40eee0972357d26'), 'datetime': '2021-05-04T04:45:00', 'confidence': 80, 'surface_temperature_celcius': 53, 'climate': [{'air_temperature_celcius': 10}]}
# {'_id': ObjectId('628a4077c40eee0972357d31'), 'datetime': '2021-05-04T04:44:40', 'confidence': 80, 'surface_temperature_celcius': 53, 'climate': [{'air_temperature_celcius': 10}]}
# {'_id': ObjectId('628a4077c40eee0972357dd1'), 'datetime': '2021-05-01T04:14:20', 'confidence': 80, 'surface_temperature_celcius': 54, 'climate': [{'air_temperature_celcius': 14}]}
# {'_id': ObjectId('628a4077c40eee0972357e0c'), 'datetime': '2021-04-20T04:32:30', 'confidence': 80, 'surface_temperature_celcius': 53, 'climate': [{'air_temperature_celcius': 20}]}
# {'_id': ObjectId('628a4077c40eee0972357e20'), 'datetime': '2021-04-19T13:23:10', 'confidence': 80, 'surface_temperature_celcius': 39, 'climate': [{'air_temperature_celcius': 22}]}
# {'_id': ObjectId('628a4077c40eee0972357e34'), 'datetime': '2021-04-19T03:51:20', 'confidence': 80, 'surface_temperature_celcius': 66, 'climate': [{'air_temperature_celcius': 22}]}
# {'_id': ObjectId('628a4077c40eee0972357e69'), 'datetime': '2021-04-18T04:51:30', 'confidence': 80, 'surface_temperature_celcius': 53, 'climate': [{'air_temperature_celcius': 15}]}
# {'_id': ObjectId('628a4077c40eee0972357e78'), 'datetime': '2021-04-18T04:50:20', 'confidence': 80, 'surface_temperature_celcius': 53, 'climate': [{'air_temperature_celcius': 15}]}
# {'_id': ObjectId('628a4077c40eee0972357e99'), 'datetime': '2021-04-18T04:46:30', 'confidence': 80, 'surface_temperature_celcius': 53, 'climate': [{'air_temperature_celcius': 15}]}
# {'_id': ObjectId('628a4077c40eee0972357f26'), 'datetime': '2021-04-18T04:44:50', 'confidence': 80, 'surface_temperature_celcius': 53, 'climate': [{'air_temperature_celcius': 15}]}
# {'_id': ObjectId('628a4077c40eee0972357f2e'), 'datetime': '2021-04-18T04:44:50', 'confidence': 80, 'surface_temperature_celcius': 53, 'climate': [{'air_temperature_celcius': 15}]}
# {'_id': ObjectId('628a4077c40eee0972357f2f'), 'datetime': '2021-04-18T04:44:50', 'confidence': 80, 'surface_temperature_celcius': 54, 'climate': [{'air_temperature_celcius': 15}]}
# {'_id': ObjectId('628a4077c40eee0972357f3a'), 'datetime': '2021-04-18T04:44:50', 'confidence': 80, 'surface_temperature_celcius': 53, 'climate': [{'air_temperature_celcius': 15}]}
# {'_id': ObjectId('628a4077c40eee0972357f55'), 'datetime': '2021-04-18T04:44:50', 'confidence': 80, 'surface_temperature_celcius': 54, 'climate': [{'air_temperature_celcius': 15}]}
# {'_id': ObjectId('628a4077c40eee0972357f72'), 'datetime': '2021-04-18T04:44:50', 'confidence': 80, 'surface_temperature_celcius': 53, 'climate': [{'air_temperature_celcius': 15}]}
# {'_id': ObjectId('628a4077c40eee0972357fba'), 'datetime': '2021-04-17T01:20:30', 'confidence': 80, 'surface_temperature_celcius': 53, 'climate': [{'air_temperature_celcius': 13}]}
# {'_id': ObjectId('628a4077c40eee0972357fc2'), 'datetime': '2021-04-16T04:57:20', 'confidence': 80, 'surface_temperature_celcius': 53, 'climate': [{'air_temperature_celcius': 15}]}
# {'_id': ObjectId('628a4077c40eee0972357fde'), 'datetime': '2021-04-15T04:16:40', 'confidence': 80, 'surface_temperature_celcius': 53, 'climate': [{'air_temperature_celcius': 12}]}
# {'_id': ObjectId('628a4077c40eee0972358010'), 'datetime': '2021-04-15T04:14:20', 'confidence': 80, 'surface_temperature_celcius': 53, 'climate': [{'air_temperature_celcius': 12}]}
# {'_id': ObjectId('628a4077c40eee0972358011'), 'datetime': '2021-04-15T04:14:20', 'confidence': 80, 'surface_temperature_celcius': 54, 'climate': [{'air_temperature_celcius': 12}]}
# {'_id': ObjectId('628a4077c40eee097235802f'), 'datetime': '2021-04-13T04:36:20', 'confidence': 80, 'surface_temperature_celcius': 53, 'climate': [{'air_temperature_celcius': 16}]}
# {'_id': ObjectId('628a4077c40eee0972358053'), 'datetime': '2021-04-13T04:33:00', 'confidence': 80, 'surface_temperature_celcius': 54, 'climate': [{'air_temperature_celcius': 16}]}
# {'_id': ObjectId('628a4077c40eee0972358055'), 'datetime': '2021-04-13T04:32:20', 'confidence': 80, 'surface_temperature_celcius': 54, 'climate': [{'air_temperature_celcius': 16}]}
# {'_id': ObjectId('628a4077c40eee097235806f'), 'datetime': '2021-04-13T04:29:40', 'confidence': 80, 'surface_temperature_celcius': 56, 'climate': [{'air_temperature_celcius': 16}]}
# {'_id': ObjectId('628a4077c40eee0972358089'), 'datetime': '2021-04-13T04:28:10', 'confidence': 80, 'surface_temperature_celcius': 53, 'climate': [{'air_temperature_celcius': 16}]}
# {'_id': ObjectId('628a4077c40eee09723580a1'), 'datetime': '2021-04-13T04:27:20', 'confidence': 80, 'surface_temperature_celcius': 54, 'climate': [{'air_temperature_celcius': 16}]}
# {'_id': ObjectId('628a4077c40eee09723580bf'), 'datetime': '2021-04-13T04:26:50', 'confidence': 80, 'surface_temperature_celcius': 54, 'climate': [{'air_temperature_celcius': 16}]}
# {'_id': ObjectId('628a4077c40eee09723580d0'), 'datetime': '2021-04-13T04:26:40', 'confidence': 80, 'surface_temperature_celcius': 53, 'climate': [{'air_temperature_celcius': 16}]}
# {'_id': ObjectId('628a4077c40eee0972358110'), 'datetime': '2021-04-13T04:26:30', 'confidence': 80, 'surface_temperature_celcius': 54, 'climate': [{'air_temperature_celcius': 16}]}
# {'_id': ObjectId('628a4077c40eee0972358133'), 'datetime': '2021-04-13T04:26:30', 'confidence': 80, 'surface_temperature_celcius': 53, 'climate': [{'air_temperature_celcius': 16}]}
# {'_id': ObjectId('628a4077c40eee097235814f'), 'datetime': '2021-04-13T04:26:30', 'confidence': 80, 'surface_temperature_celcius': 53, 'climate': [{'air_temperature_celcius': 16}]}
# {'_id': ObjectId('628a4077c40eee09723581ee'), 'datetime': '2021-04-08T04:12:00', 'confidence': 80, 'surface_temperature_celcius': 59, 'climate': [{'air_temperature_celcius': 19}]}
# {'_id': ObjectId('628a4077c40eee09723581f9'), 'datetime': '2021-04-08T04:08:30', 'confidence': 80, 'surface_temperature_celcius': 54, 'climate': [{'air_temperature_celcius': 19}]}
# {'_id': ObjectId('628a4077c40eee09723581fa'), 'datetime': '2021-04-08T04:08:30', 'confidence': 80, 'surface_temperature_celcius': 53, 'climate': [{'air_temperature_celcius': 19}]}
# {'_id': ObjectId('628a4077c40eee09723581fb'), 'datetime': '2021-04-08T04:08:30', 'confidence': 80, 'surface_temperature_celcius': 58, 'climate': [{'air_temperature_celcius': 19}]}
# {'_id': ObjectId('628a4077c40eee09723581ff'), 'datetime': '2021-04-07T12:56:30', 'confidence': 80, 'surface_temperature_celcius': 39, 'climate': [{'air_temperature_celcius': 21}]}
# {'_id': ObjectId('628a4077c40eee0972358211'), 'datetime': '2021-04-07T05:09:50', 'confidence': 80, 'surface_temperature_celcius': 54, 'climate': [{'air_temperature_celcius': 21}]}
# {'_id': ObjectId('628a4077c40eee0972358215'), 'datetime': '2021-04-07T05:03:10', 'confidence': 80, 'surface_temperature_celcius': 53, 'climate': [{'air_temperature_celcius': 21}]}
# {'_id': ObjectId('628a4077c40eee097235827a'), 'datetime': '2021-04-06T04:20:40', 'confidence': 80, 'surface_temperature_celcius': 53, 'climate': [{'air_temperature_celcius': 19}]}
# {'_id': ObjectId('628a4077c40eee09723582a7'), 'datetime': '2021-04-05T13:02:40', 'confidence': 80, 'surface_temperature_celcius': 39, 'climate': [{'air_temperature_celcius': 17}]}
# {'_id': ObjectId('628a4077c40eee09723582fa'), 'datetime': '2021-04-04T04:33:30', 'confidence': 80, 'surface_temperature_celcius': 58, 'climate': [{'air_temperature_celcius': 16}]}
# {'_id': ObjectId('628a4077c40eee097235830e'), 'datetime': '2021-04-04T04:32:40', 'confidence': 80, 'surface_temperature_celcius': 54, 'climate': [{'air_temperature_celcius': 16}]}
# {'_id': ObjectId('628a4077c40eee0972358322'), 'datetime': '2021-04-04T00:12:50', 'confidence': 80, 'surface_temperature_celcius': 53, 'climate': [{'air_temperature_celcius': 16}]}
# {'_id': ObjectId('628a4077c40eee097235834b'), 'datetime': '2021-04-03T03:51:00', 'confidence': 80, 'surface_temperature_celcius': 53, 'climate': [{'air_temperature_celcius': 15}]}
# {'_id': ObjectId('628a4077c40eee097235837f'), 'datetime': '2021-03-31T04:58:00', 'confidence': 80, 'surface_temperature_celcius': 53, 'climate': [{'air_temperature_celcius': 14}]}
# {'_id': ObjectId('628a4077c40eee0972358398'), 'datetime': '2021-03-28T04:30:20', 'confidence': 80, 'surface_temperature_celcius': 54, 'climate': [{'air_temperature_celcius': 18}]}
# {'_id': ObjectId('628a4077c40eee09723583b0'), 'datetime': '2021-03-28T04:26:50', 'confidence': 80, 'surface_temperature_celcius': 53, 'climate': [{'air_temperature_celcius': 18}]}
# {'_id': ObjectId('628a4077c40eee09723583c8'), 'datetime': '2021-03-26T04:40:50', 'confidence': 80, 'surface_temperature_celcius': 53, 'climate': [{'air_temperature_celcius': 23}]}
# {'_id': ObjectId('628a4077c40eee0972358418'), 'datetime': '2021-03-12T04:28:00', 'confidence': 80, 'surface_temperature_celcius': 68, 'climate': [{'air_temperature_celcius': 21}]}
# {'_id': ObjectId('628a4077c40eee09723579de'), 'datetime': '2021-12-09T00:14:34', 'confidence': 81, 'surface_temperature_celcius': 54, 'climate': [{'air_temperature_celcius': 17}]}
# {'_id': ObjectId('628a4077c40eee09723579f1'), 'datetime': '2021-11-30T12:22:15', 'confidence': 81, 'surface_temperature_celcius': 42, 'climate': [{'air_temperature_celcius': 26}]}
# {'_id': ObjectId('628a4077c40eee09723579f8'), 'datetime': '2021-11-30T04:34:57', 'confidence': 81, 'surface_temperature_celcius': 57, 'climate': [{'air_temperature_celcius': 26}]}
# {'_id': ObjectId('628a4077c40eee0972357a00'), 'datetime': '2021-11-30T00:20:53', 'confidence': 81, 'surface_temperature_celcius': 56, 'climate': [{'air_temperature_celcius': 26}]}
# {'_id': ObjectId('628a4077c40eee0972357a02'), 'datetime': '2021-11-30T00:20:53', 'confidence': 81, 'surface_temperature_celcius': 55, 'climate': [{'air_temperature_celcius': 26}]}
# {'_id': ObjectId('628a4077c40eee0972357a1a'), 'datetime': '2021-11-13T03:52:14', 'confidence': 81, 'surface_temperature_celcius': 53, 'climate': [{'air_temperature_celcius': 24}]}
# {'_id': ObjectId('628a4077c40eee0972357a37'), 'datetime': '2021-10-28T03:52:17', 'confidence': 81, 'surface_temperature_celcius': 56, 'climate': [{'air_temperature_celcius': 15}]}
# {'_id': ObjectId('628a4077c40eee0972357a6d'), 'datetime': '2021-10-03T03:58:15', 'confidence': 81, 'surface_temperature_celcius': 48, 'climate': [{'air_temperature_celcius': 13}]}
# {'_id': ObjectId('628a4077c40eee0972357acf'), 'datetime': '2021-09-10T03:50:10', 'confidence': 81, 'surface_temperature_celcius': 54, 'climate': [{'air_temperature_celcius': 11}]}
# {'_id': ObjectId('628a4077c40eee0972357afd'), 'datetime': '2021-06-30T00:27:19', 'confidence': 81, 'surface_temperature_celcius': 48, 'climate': [{'air_temperature_celcius': 5}]}
# {'_id': ObjectId('628a4077c40eee0972357b00'), 'datetime': '2021-06-30T00:27:19', 'confidence': 81, 'surface_temperature_celcius': 48, 'climate': [{'air_temperature_celcius': 5}]}
# {'_id': ObjectId('628a4077c40eee0972357b1f'), 'datetime': '2021-06-07T04:32:10', 'confidence': 81, 'surface_temperature_celcius': 54, 'climate': [{'air_temperature_celcius': 8}]}
# {'_id': ObjectId('628a4077c40eee0972357b47'), 'datetime': '2021-05-23T00:54:50', 'confidence': 81, 'surface_temperature_celcius': 55, 'climate': [{'air_temperature_celcius': 15}]}
# {'_id': ObjectId('628a4077c40eee0972357bd0'), 'datetime': '2021-05-15T04:26:20', 'confidence': 81, 'surface_temperature_celcius': 54, 'climate': [{'air_temperature_celcius': 10}]}
# {'_id': ObjectId('628a4077c40eee0972357be8'), 'datetime': '2021-05-13T04:39:50', 'confidence': 81, 'surface_temperature_celcius': 55, 'climate': [{'air_temperature_celcius': 9}]}
# {'_id': ObjectId('628a4077c40eee0972357bf2'), 'datetime': '2021-05-13T04:38:40', 'confidence': 81, 'surface_temperature_celcius': 54, 'climate': [{'air_temperature_celcius': 9}]}
# {'_id': ObjectId('628a4077c40eee0972357c40'), 'datetime': '2021-05-10T04:11:10', 'confidence': 81, 'surface_temperature_celcius': 55, 'climate': [{'air_temperature_celcius': 10}]}
# {'_id': ObjectId('628a4077c40eee0972357c70'), 'datetime': '2021-05-10T04:08:10', 'confidence': 81, 'surface_temperature_celcius': 55, 'climate': [{'air_temperature_celcius': 10}]}
# {'_id': ObjectId('628a4077c40eee0972357c74'), 'datetime': '2021-05-10T04:08:10', 'confidence': 81, 'surface_temperature_celcius': 55, 'climate': [{'air_temperature_celcius': 10}]}
# {'_id': ObjectId('628a4077c40eee0972357c7c'), 'datetime': '2021-05-10T04:08:10', 'confidence': 81, 'surface_temperature_celcius': 54, 'climate': [{'air_temperature_celcius': 10}]}
# {'_id': ObjectId('628a4077c40eee0972357ca0'), 'datetime': '2021-05-09T12:56:40', 'confidence': 81, 'surface_temperature_celcius': 39, 'climate': [{'air_temperature_celcius': 12}]}
# {'_id': ObjectId('628a4077c40eee0972357ca5'), 'datetime': '2021-05-09T05:02:50', 'confidence': 81, 'surface_temperature_celcius': 54, 'climate': [{'air_temperature_celcius': 12}]}
# {'_id': ObjectId('628a4077c40eee0972357cda'), 'datetime': '2021-05-05T03:57:00', 'confidence': 81, 'surface_temperature_celcius': 54, 'climate': [{'air_temperature_celcius': 14}]}
# {'_id': ObjectId('628a4077c40eee0972357d0f'), 'datetime': '2021-05-04T04:46:30', 'confidence': 81, 'surface_temperature_celcius': 54, 'climate': [{'air_temperature_celcius': 10}]}
# {'_id': ObjectId('628a4077c40eee0972357d1b'), 'datetime': '2021-05-04T04:45:40', 'confidence': 81, 'surface_temperature_celcius': 54, 'climate': [{'air_temperature_celcius': 10}]}
# {'_id': ObjectId('628a4077c40eee0972357d28'), 'datetime': '2021-05-04T04:44:50', 'confidence': 81, 'surface_temperature_celcius': 54, 'climate': [{'air_temperature_celcius': 10}]}
# {'_id': ObjectId('628a4077c40eee0972357d2c'), 'datetime': '2021-05-04T04:44:50', 'confidence': 81, 'surface_temperature_celcius': 55, 'climate': [{'air_temperature_celcius': 10}]}
# {'_id': ObjectId('628a4077c40eee0972357dc3'), 'datetime': '2021-05-02T23:44:00', 'confidence': 81, 'surface_temperature_celcius': 54, 'climate': [{'air_temperature_celcius': 10}]}
# {'_id': ObjectId('628a4077c40eee0972357dfe'), 'datetime': '2021-04-23T05:02:50', 'confidence': 81, 'surface_temperature_celcius': 54, 'climate': [{'air_temperature_celcius': 17}]}
# {'_id': ObjectId('628a4077c40eee0972357e22'), 'datetime': '2021-04-19T13:15:10', 'confidence': 81, 'surface_temperature_celcius': 39, 'climate': [{'air_temperature_celcius': 22}]}
# {'_id': ObjectId('628a4077c40eee0972357e74'), 'datetime': '2021-04-18T04:51:20', 'confidence': 81, 'surface_temperature_celcius': 55, 'climate': [{'air_temperature_celcius': 15}]}
# {'_id': ObjectId('628a4077c40eee0972357eb3'), 'datetime': '2021-04-18T04:45:20', 'confidence': 81, 'surface_temperature_celcius': 54, 'climate': [{'air_temperature_celcius': 15}]}
# {'_id': ObjectId('628a4077c40eee0972357ec6'), 'datetime': '2021-04-18T04:45:00', 'confidence': 81, 'surface_temperature_celcius': 54, 'climate': [{'air_temperature_celcius': 15}]}
# {'_id': ObjectId('628a4077c40eee0972357eef'), 'datetime': '2021-04-18T04:44:50', 'confidence': 81, 'surface_temperature_celcius': 54, 'climate': [{'air_temperature_celcius': 15}]}
# {'_id': ObjectId('628a4077c40eee0972357efb'), 'datetime': '2021-04-18T04:44:50', 'confidence': 81, 'surface_temperature_celcius': 60, 'climate': [{'air_temperature_celcius': 15}]}
# {'_id': ObjectId('628a4077c40eee0972357f00'), 'datetime': '2021-04-18T04:44:50', 'confidence': 81, 'surface_temperature_celcius': 54, 'climate': [{'air_temperature_celcius': 15}]}
# {'_id': ObjectId('628a4077c40eee0972357f21'), 'datetime': '2021-04-18T04:44:50', 'confidence': 81, 'surface_temperature_celcius': 54, 'climate': [{'air_temperature_celcius': 15}]}
# {'_id': ObjectId('628a4077c40eee0972357f44'), 'datetime': '2021-04-18T04:44:50', 'confidence': 81, 'surface_temperature_celcius': 54, 'climate': [{'air_temperature_celcius': 15}]}
# {'_id': ObjectId('628a4077c40eee0972357f4f'), 'datetime': '2021-04-18T04:44:50', 'confidence': 81, 'surface_temperature_celcius': 54, 'climate': [{'air_temperature_celcius': 15}]}
# {'_id': ObjectId('628a4077c40eee0972357f60'), 'datetime': '2021-04-18T04:44:50', 'confidence': 81, 'surface_temperature_celcius': 54, 'climate': [{'air_temperature_celcius': 15}]}
# {'_id': ObjectId('628a4077c40eee0972357f99'), 'datetime': '2021-04-17T04:08:20', 'confidence': 81, 'surface_temperature_celcius': 55, 'climate': [{'air_temperature_celcius': 13}]}
# {'_id': ObjectId('628a4077c40eee0972357fa5'), 'datetime': '2021-04-17T04:02:40', 'confidence': 81, 'surface_temperature_celcius': 54, 'climate': [{'air_temperature_celcius': 13}]}
# {'_id': ObjectId('628a4077c40eee0972357fe0'), 'datetime': '2021-04-15T04:16:00', 'confidence': 81, 'surface_temperature_celcius': 55, 'climate': [{'air_temperature_celcius': 12}]}
# {'_id': ObjectId('628a4077c40eee0972357ff0'), 'datetime': '2021-04-15T04:15:00', 'confidence': 81, 'surface_temperature_celcius': 54, 'climate': [{'air_temperature_celcius': 12}]}
# {'_id': ObjectId('628a4077c40eee0972357ff3'), 'datetime': '2021-04-15T04:14:50', 'confidence': 81, 'surface_temperature_celcius': 54, 'climate': [{'air_temperature_celcius': 12}]}
# {'_id': ObjectId('628a4077c40eee0972357ffc'), 'datetime': '2021-04-15T04:14:20', 'confidence': 81, 'surface_temperature_celcius': 55, 'climate': [{'air_temperature_celcius': 12}]}
# {'_id': ObjectId('628a4077c40eee0972358036'), 'datetime': '2021-04-13T04:34:40', 'confidence': 81, 'surface_temperature_celcius': 54, 'climate': [{'air_temperature_celcius': 16}]}
# {'_id': ObjectId('628a4077c40eee097235803c'), 'datetime': '2021-04-13T04:33:40', 'confidence': 81, 'surface_temperature_celcius': 54, 'climate': [{'air_temperature_celcius': 16}]}
# {'_id': ObjectId('628a4077c40eee0972358062'), 'datetime': '2021-04-13T04:29:50', 'confidence': 81, 'surface_temperature_celcius': 55, 'climate': [{'air_temperature_celcius': 16}]}
# {'_id': ObjectId('628a4077c40eee097235806e'), 'datetime': '2021-04-13T04:29:40', 'confidence': 81, 'surface_temperature_celcius': 54, 'climate': [{'air_temperature_celcius': 16}]}
# {'_id': ObjectId('628a4077c40eee0972358081'), 'datetime': '2021-04-13T04:28:10', 'confidence': 81, 'surface_temperature_celcius': 55, 'climate': [{'air_temperature_celcius': 16}]}
# {'_id': ObjectId('628a4077c40eee0972358084'), 'datetime': '2021-04-13T04:28:10', 'confidence': 81, 'surface_temperature_celcius': 54, 'climate': [{'air_temperature_celcius': 16}]}
# {'_id': ObjectId('628a4077c40eee09723580ae'), 'datetime': '2021-04-13T04:27:20', 'confidence': 81, 'surface_temperature_celcius': 55, 'climate': [{'air_temperature_celcius': 16}]}
# {'_id': ObjectId('628a4077c40eee09723580af'), 'datetime': '2021-04-13T04:27:20', 'confidence': 81, 'surface_temperature_celcius': 54, 'climate': [{'air_temperature_celcius': 16}]}
# {'_id': ObjectId('628a4077c40eee09723580e4'), 'datetime': '2021-04-13T04:26:30', 'confidence': 81, 'surface_temperature_celcius': 55, 'climate': [{'air_temperature_celcius': 16}]}
# {'_id': ObjectId('628a4077c40eee09723580e7'), 'datetime': '2021-04-13T04:26:30', 'confidence': 81, 'surface_temperature_celcius': 55, 'climate': [{'air_temperature_celcius': 16}]}
# {'_id': ObjectId('628a4077c40eee09723580e9'), 'datetime': '2021-04-13T04:26:30', 'confidence': 81, 'surface_temperature_celcius': 54, 'climate': [{'air_temperature_celcius': 16}]}
# {'_id': ObjectId('628a4077c40eee09723580ee'), 'datetime': '2021-04-13T04:26:30', 'confidence': 81, 'surface_temperature_celcius': 54, 'climate': [{'air_temperature_celcius': 16}]}
# {'_id': ObjectId('628a4077c40eee09723580ef'), 'datetime': '2021-04-13T04:26:30', 'confidence': 81, 'surface_temperature_celcius': 55, 'climate': [{'air_temperature_celcius': 16}]}
# {'_id': ObjectId('628a4077c40eee0972358100'), 'datetime': '2021-04-13T04:26:30', 'confidence': 81, 'surface_temperature_celcius': 55, 'climate': [{'air_temperature_celcius': 16}]}
# {'_id': ObjectId('628a4077c40eee097235812d'), 'datetime': '2021-04-13T04:26:30', 'confidence': 81, 'surface_temperature_celcius': 54, 'climate': [{'air_temperature_celcius': 16}]}
# {'_id': ObjectId('628a4077c40eee0972358151'), 'datetime': '2021-04-13T04:26:30', 'confidence': 81, 'surface_temperature_celcius': 54, 'climate': [{'air_temperature_celcius': 16}]}
# {'_id': ObjectId('628a4077c40eee0972358165'), 'datetime': '2021-04-13T04:26:30', 'confidence': 81, 'surface_temperature_celcius': 54, 'climate': [{'air_temperature_celcius': 16}]}
# {'_id': ObjectId('628a4077c40eee097235817b'), 'datetime': '2021-04-13T04:26:30', 'confidence': 81, 'surface_temperature_celcius': 54, 'climate': [{'air_temperature_celcius': 16}]}
# {'_id': ObjectId('628a4077c40eee097235817c'), 'datetime': '2021-04-13T04:26:30', 'confidence': 81, 'surface_temperature_celcius': 54, 'climate': [{'air_temperature_celcius': 16}]}
# {'_id': ObjectId('628a4077c40eee097235817d'), 'datetime': '2021-04-13T04:26:30', 'confidence': 81, 'surface_temperature_celcius': 55, 'climate': [{'air_temperature_celcius': 16}]}
# {'_id': ObjectId('628a4077c40eee09723581d9'), 'datetime': '2021-04-11T04:39:20', 'confidence': 81, 'surface_temperature_celcius': 54, 'climate': [{'air_temperature_celcius': 14}]}
# {'_id': ObjectId('628a4077c40eee0972358217'), 'datetime': '2021-04-07T05:03:10', 'confidence': 81, 'surface_temperature_celcius': 54, 'climate': [{'air_temperature_celcius': 21}]}
# {'_id': ObjectId('628a4077c40eee097235822b'), 'datetime': '2021-04-06T04:27:10', 'confidence': 81, 'surface_temperature_celcius': 54, 'climate': [{'air_temperature_celcius': 19}]}
# {'_id': ObjectId('628a4077c40eee0972358249'), 'datetime': '2021-04-06T04:22:20', 'confidence': 81, 'surface_temperature_celcius': 71, 'climate': [{'air_temperature_celcius': 19}]}
# {'_id': ObjectId('628a4077c40eee0972358265'), 'datetime': '2021-04-06T04:20:40', 'confidence': 81, 'surface_temperature_celcius': 60, 'climate': [{'air_temperature_celcius': 19}]}
# {'_id': ObjectId('628a4077c40eee0972358277'), 'datetime': '2021-04-06T04:20:40', 'confidence': 81, 'surface_temperature_celcius': 61, 'climate': [{'air_temperature_celcius': 19}]}
# {'_id': ObjectId('628a4077c40eee0972358291'), 'datetime': '2021-04-06T04:20:40', 'confidence': 81, 'surface_temperature_celcius': 57, 'climate': [{'air_temperature_celcius': 19}]}
# {'_id': ObjectId('628a4077c40eee097235829b'), 'datetime': '2021-04-05T13:09:00', 'confidence': 81, 'surface_temperature_celcius': 39, 'climate': [{'air_temperature_celcius': 17}]}
# {'_id': ObjectId('628a4077c40eee09723582a4'), 'datetime': '2021-04-05T13:03:00', 'confidence': 81, 'surface_temperature_celcius': 39, 'climate': [{'air_temperature_celcius': 17}]}
# {'_id': ObjectId('628a4077c40eee09723582b7'), 'datetime': '2021-04-05T03:40:20', 'confidence': 81, 'surface_temperature_celcius': 54, 'climate': [{'air_temperature_celcius': 17}]}
# {'_id': ObjectId('628a4077c40eee09723582d7'), 'datetime': '2021-04-04T04:39:40', 'confidence': 81, 'surface_temperature_celcius': 54, 'climate': [{'air_temperature_celcius': 16}]}
# {'_id': ObjectId('628a4077c40eee09723582f6'), 'datetime': '2021-04-04T04:33:40', 'confidence': 81, 'surface_temperature_celcius': 54, 'climate': [{'air_temperature_celcius': 16}]}
# {'_id': ObjectId('628a4077c40eee097235831d'), 'datetime': '2021-04-04T04:32:40', 'confidence': 81, 'surface_temperature_celcius': 54, 'climate': [{'air_temperature_celcius': 16}]}
# {'_id': ObjectId('628a4077c40eee0972358349'), 'datetime': '2021-04-03T03:51:00', 'confidence': 81, 'surface_temperature_celcius': 54, 'climate': [{'air_temperature_celcius': 15}]}
# {'_id': ObjectId('628a4077c40eee0972358369'), 'datetime': '2021-04-03T01:07:20', 'confidence': 81, 'surface_temperature_celcius': 54, 'climate': [{'air_temperature_celcius': 15}]}
# {'_id': ObjectId('628a4077c40eee097235838b'), 'datetime': '2021-03-31T00:36:30', 'confidence': 81, 'surface_temperature_celcius': 54, 'climate': [{'air_temperature_celcius': 14}]}
# {'_id': ObjectId('628a4077c40eee097235839d'), 'datetime': '2021-03-28T04:30:10', 'confidence': 81, 'surface_temperature_celcius': 54, 'climate': [{'air_temperature_celcius': 18}]}
# {'_id': ObjectId('628a4077c40eee09723583a1'), 'datetime': '2021-03-28T04:28:30', 'confidence': 81, 'surface_temperature_celcius': 54, 'climate': [{'air_temperature_celcius': 18}]}
# {'_id': ObjectId('628a4077c40eee09723583af'), 'datetime': '2021-03-28T04:26:50', 'confidence': 81, 'surface_temperature_celcius': 55, 'climate': [{'air_temperature_celcius': 18}]}
# {'_id': ObjectId('628a4077c40eee09723583c6'), 'datetime': '2021-03-26T04:43:20', 'confidence': 81, 'surface_temperature_celcius': 54, 'climate': [{'air_temperature_celcius': 23}]}
# {'_id': ObjectId('628a4077c40eee09723583ca'), 'datetime': '2021-03-26T04:39:50', 'confidence': 81, 'surface_temperature_celcius': 54, 'climate': [{'air_temperature_celcius': 23}]}
# {'_id': ObjectId('628a4077c40eee0972358410'), 'datetime': '2021-03-14T04:14:40', 'confidence': 81, 'surface_temperature_celcius': 55, 'climate': [{'air_temperature_celcius': 25}]}
# {'_id': ObjectId('628a4077c40eee097235841e'), 'datetime': '2021-03-10T04:43:50', 'confidence': 81, 'surface_temperature_celcius': 55, 'climate': [{'air_temperature_celcius': 19}]}
# {'_id': ObjectId('628a4077c40eee09723579bf'), 'datetime': '2021-12-27T00:02:15', 'confidence': 82, 'surface_temperature_celcius': 63, 'climate': [{'air_temperature_celcius': 28}]}
# {'_id': ObjectId('628a4077c40eee09723579d1'), 'datetime': '2021-12-16T00:21:11', 'confidence': 82, 'surface_temperature_celcius': 55, 'climate': [{'air_temperature_celcius': 18}]}
# {'_id': ObjectId('628a4077c40eee09723579d2'), 'datetime': '2021-12-16T00:20:53', 'confidence': 82, 'surface_temperature_celcius': 64, 'climate': [{'air_temperature_celcius': 18}]}
# {'_id': ObjectId('628a4077c40eee0972357a48'), 'datetime': '2021-10-20T04:41:19', 'confidence': 82, 'surface_temperature_celcius': 50, 'climate': [{'air_temperature_celcius': 13}]}
# {'_id': ObjectId('628a4077c40eee0972357a4e'), 'datetime': '2021-10-18T00:39:02', 'confidence': 82, 'surface_temperature_celcius': 56, 'climate': [{'air_temperature_celcius': 26}]}
# {'_id': ObjectId('628a4077c40eee0972357a54'), 'datetime': '2021-10-17T04:10:32', 'confidence': 82, 'surface_temperature_celcius': 55, 'climate': [{'air_temperature_celcius': 22}]}
# {'_id': ObjectId('628a4077c40eee0972357a6e'), 'datetime': '2021-10-03T03:58:15', 'confidence': 82, 'surface_temperature_celcius': 49, 'climate': [{'air_temperature_celcius': 13}]}
# {'_id': ObjectId('628a4077c40eee0972357a88'), 'datetime': '2021-09-29T04:22:31', 'confidence': 82, 'surface_temperature_celcius': 49, 'climate': [{'air_temperature_celcius': 14}]}
# {'_id': ObjectId('628a4077c40eee0972357a9e'), 'datetime': '2021-09-24T13:30:09', 'confidence': 82, 'surface_temperature_celcius': 38, 'climate': [{'air_temperature_celcius': 14}]}
# {'_id': ObjectId('628a4077c40eee0972357b3b'), 'datetime': '2021-06-01T05:09:20', 'confidence': 82, 'surface_temperature_celcius': 56, 'climate': [{'air_temperature_celcius': 11}]}
# {'_id': ObjectId('628a4077c40eee0972357bb5'), 'datetime': '2021-05-15T04:26:20', 'confidence': 82, 'surface_temperature_celcius': 55, 'climate': [{'air_temperature_celcius': 10}]}
# {'_id': ObjectId('628a4077c40eee0972357bbf'), 'datetime': '2021-05-15T04:26:20', 'confidence': 82, 'surface_temperature_celcius': 55, 'climate': [{'air_temperature_celcius': 10}]}
# {'_id': ObjectId('628a4077c40eee0972357c00'), 'datetime': '2021-05-13T04:38:40', 'confidence': 82, 'surface_temperature_celcius': 56, 'climate': [{'air_temperature_celcius': 9}]}
# {'_id': ObjectId('628a4077c40eee0972357c05'), 'datetime': '2021-05-13T04:38:40', 'confidence': 82, 'surface_temperature_celcius': 55, 'climate': [{'air_temperature_celcius': 9}]}
# {'_id': ObjectId('628a4077c40eee0972357c4c'), 'datetime': '2021-05-10T04:08:50', 'confidence': 82, 'surface_temperature_celcius': 55, 'climate': [{'air_temperature_celcius': 10}]}
# {'_id': ObjectId('628a4077c40eee0972357c50'), 'datetime': '2021-05-10T04:08:50', 'confidence': 82, 'surface_temperature_celcius': 55, 'climate': [{'air_temperature_celcius': 10}]}
# {'_id': ObjectId('628a4077c40eee0972357c8d'), 'datetime': '2021-05-10T04:08:10', 'confidence': 82, 'surface_temperature_celcius': 55, 'climate': [{'air_temperature_celcius': 10}]}
# {'_id': ObjectId('628a4077c40eee0972357ce1'), 'datetime': '2021-05-05T03:51:50', 'confidence': 82, 'surface_temperature_celcius': 55, 'climate': [{'air_temperature_celcius': 14}]}
# {'_id': ObjectId('628a4077c40eee0972357ce7'), 'datetime': '2021-05-05T03:50:20', 'confidence': 82, 'surface_temperature_celcius': 55, 'climate': [{'air_temperature_celcius': 14}]}
# {'_id': ObjectId('628a4077c40eee0972357ceb'), 'datetime': '2021-05-05T03:50:20', 'confidence': 82, 'surface_temperature_celcius': 56, 'climate': [{'air_temperature_celcius': 14}]}
# {'_id': ObjectId('628a4077c40eee0972357d14'), 'datetime': '2021-05-04T04:46:20', 'confidence': 82, 'surface_temperature_celcius': 55, 'climate': [{'air_temperature_celcius': 10}]}
# {'_id': ObjectId('628a4077c40eee0972357d1a'), 'datetime': '2021-05-04T04:45:40', 'confidence': 82, 'surface_temperature_celcius': 55, 'climate': [{'air_temperature_celcius': 10}]}
# {'_id': ObjectId('628a4077c40eee0972357d87'), 'datetime': '2021-05-03T04:08:10', 'confidence': 82, 'surface_temperature_celcius': 55, 'climate': [{'air_temperature_celcius': 10}]}
# {'_id': ObjectId('628a4077c40eee0972357dcf'), 'datetime': '2021-05-01T04:14:30', 'confidence': 82, 'surface_temperature_celcius': 55, 'climate': [{'air_temperature_celcius': 14}]}
# {'_id': ObjectId('628a4077c40eee0972357dd0'), 'datetime': '2021-05-01T04:14:30', 'confidence': 82, 'surface_temperature_celcius': 55, 'climate': [{'air_temperature_celcius': 14}]}
# {'_id': ObjectId('628a4077c40eee0972357dd7'), 'datetime': '2021-05-01T04:14:20', 'confidence': 82, 'surface_temperature_celcius': 62, 'climate': [{'air_temperature_celcius': 14}]}
# {'_id': ObjectId('628a4077c40eee0972357de1'), 'datetime': '2021-04-25T05:02:30', 'confidence': 82, 'surface_temperature_celcius': 56, 'climate': [{'air_temperature_celcius': 14}]}
# {'_id': ObjectId('628a4077c40eee0972357e32'), 'datetime': '2021-04-19T03:51:50', 'confidence': 82, 'surface_temperature_celcius': 56, 'climate': [{'air_temperature_celcius': 22}]}
# {'_id': ObjectId('628a4077c40eee0972357e55'), 'datetime': '2021-04-18T04:55:00', 'confidence': 82, 'surface_temperature_celcius': 56, 'climate': [{'air_temperature_celcius': 15}]}
# {'_id': ObjectId('628a4077c40eee0972357e6b'), 'datetime': '2021-04-18T04:51:30', 'confidence': 82, 'surface_temperature_celcius': 58, 'climate': [{'air_temperature_celcius': 15}]}
# {'_id': ObjectId('628a4077c40eee0972357e73'), 'datetime': '2021-04-18T04:51:20', 'confidence': 82, 'surface_temperature_celcius': 56, 'climate': [{'air_temperature_celcius': 15}]}
# {'_id': ObjectId('628a4077c40eee0972357ea6'), 'datetime': '2021-04-18T04:45:50', 'confidence': 82, 'surface_temperature_celcius': 55, 'climate': [{'air_temperature_celcius': 15}]}
# {'_id': ObjectId('628a4077c40eee0972357eac'), 'datetime': '2021-04-18T04:45:40', 'confidence': 82, 'surface_temperature_celcius': 55, 'climate': [{'air_temperature_celcius': 15}]}
# {'_id': ObjectId('628a4077c40eee0972357eff'), 'datetime': '2021-04-18T04:44:50', 'confidence': 82, 'surface_temperature_celcius': 56, 'climate': [{'air_temperature_celcius': 15}]}
# {'_id': ObjectId('628a4077c40eee0972357f17'), 'datetime': '2021-04-18T04:44:50', 'confidence': 82, 'surface_temperature_celcius': 56, 'climate': [{'air_temperature_celcius': 15}]}
# {'_id': ObjectId('628a4077c40eee0972357f54'), 'datetime': '2021-04-18T04:44:50', 'confidence': 82, 'surface_temperature_celcius': 56, 'climate': [{'air_temperature_celcius': 15}]}
# {'_id': ObjectId('628a4077c40eee0972357f58'), 'datetime': '2021-04-18T04:44:50', 'confidence': 82, 'surface_temperature_celcius': 56, 'climate': [{'air_temperature_celcius': 15}]}
# {'_id': ObjectId('628a4077c40eee0972357fa2'), 'datetime': '2021-04-17T04:03:10', 'confidence': 82, 'surface_temperature_celcius': 56, 'climate': [{'air_temperature_celcius': 13}]}
# {'_id': ObjectId('628a4077c40eee0972357fe2'), 'datetime': '2021-04-15T04:16:00', 'confidence': 82, 'surface_temperature_celcius': 55, 'climate': [{'air_temperature_celcius': 12}]}
# {'_id': ObjectId('628a4077c40eee0972357fe5'), 'datetime': '2021-04-15T04:15:40', 'confidence': 82, 'surface_temperature_celcius': 56, 'climate': [{'air_temperature_celcius': 12}]}
# {'_id': ObjectId('628a4077c40eee0972357fe8'), 'datetime': '2021-04-15T04:15:10', 'confidence': 82, 'surface_temperature_celcius': 55, 'climate': [{'air_temperature_celcius': 12}]}
# {'_id': ObjectId('628a4077c40eee0972358002'), 'datetime': '2021-04-15T04:14:20', 'confidence': 82, 'surface_temperature_celcius': 55, 'climate': [{'air_temperature_celcius': 12}]}
# {'_id': ObjectId('628a4077c40eee0972358006'), 'datetime': '2021-04-15T04:14:20', 'confidence': 82, 'surface_temperature_celcius': 55, 'climate': [{'air_temperature_celcius': 12}]}
# {'_id': ObjectId('628a4077c40eee0972358015'), 'datetime': '2021-04-14T05:15:50', 'confidence': 82, 'surface_temperature_celcius': 55, 'climate': [{'air_temperature_celcius': 13}]}
# {'_id': ObjectId('628a4077c40eee0972358054'), 'datetime': '2021-04-13T04:33:00', 'confidence': 82, 'surface_temperature_celcius': 55, 'climate': [{'air_temperature_celcius': 16}]}
# {'_id': ObjectId('628a4077c40eee0972358119'), 'datetime': '2021-04-13T04:26:30', 'confidence': 82, 'surface_temperature_celcius': 56, 'climate': [{'air_temperature_celcius': 16}]}
# {'_id': ObjectId('628a4077c40eee097235817e'), 'datetime': '2021-04-13T04:26:30', 'confidence': 82, 'surface_temperature_celcius': 55, 'climate': [{'air_temperature_celcius': 16}]}
# {'_id': ObjectId('628a4077c40eee0972358186'), 'datetime': '2021-04-13T00:07:40', 'confidence': 82, 'surface_temperature_celcius': 55, 'climate': [{'air_temperature_celcius': 16}]}
# {'_id': ObjectId('628a4077c40eee09723581c2'), 'datetime': '2021-04-12T03:44:40', 'confidence': 82, 'surface_temperature_celcius': 55, 'climate': [{'air_temperature_celcius': 14}]}
# {'_id': ObjectId('628a4077c40eee097235826c'), 'datetime': '2021-04-06T04:20:40', 'confidence': 82, 'surface_temperature_celcius': 56, 'climate': [{'air_temperature_celcius': 19}]}
# {'_id': ObjectId('628a4077c40eee097235829e'), 'datetime': '2021-04-05T13:07:00', 'confidence': 82, 'surface_temperature_celcius': 40, 'climate': [{'air_temperature_celcius': 17}]}
# {'_id': ObjectId('628a4077c40eee09723582ba'), 'datetime': '2021-04-05T03:39:30', 'confidence': 82, 'surface_temperature_celcius': 62, 'climate': [{'air_temperature_celcius': 17}]}
# {'_id': ObjectId('628a4077c40eee09723582cf'), 'datetime': '2021-04-04T04:41:10', 'confidence': 82, 'surface_temperature_celcius': 62, 'climate': [{'air_temperature_celcius': 16}]}
# {'_id': ObjectId('628a4077c40eee09723582ff'), 'datetime': '2021-04-04T04:33:10', 'confidence': 82, 'surface_temperature_celcius': 62, 'climate': [{'air_temperature_celcius': 16}]}
# {'_id': ObjectId('628a4077c40eee0972358300'), 'datetime': '2021-04-04T04:33:10', 'confidence': 82, 'surface_temperature_celcius': 62, 'climate': [{'air_temperature_celcius': 16}]}
# {'_id': ObjectId('628a4077c40eee0972358308'), 'datetime': '2021-04-04T04:32:50', 'confidence': 82, 'surface_temperature_celcius': 55, 'climate': [{'air_temperature_celcius': 16}]}
# {'_id': ObjectId('628a4077c40eee097235830c'), 'datetime': '2021-04-04T04:32:50', 'confidence': 82, 'surface_temperature_celcius': 55, 'climate': [{'air_temperature_celcius': 16}]}
# {'_id': ObjectId('628a4077c40eee097235832d'), 'datetime': '2021-04-03T03:56:20', 'confidence': 82, 'surface_temperature_celcius': 55, 'climate': [{'air_temperature_celcius': 15}]}
# {'_id': ObjectId('628a4077c40eee0972358364'), 'datetime': '2021-04-03T03:50:40', 'confidence': 82, 'surface_temperature_celcius': 55, 'climate': [{'air_temperature_celcius': 15}]}
# {'_id': ObjectId('628a4077c40eee0972358377'), 'datetime': '2021-03-31T05:07:10', 'confidence': 82, 'surface_temperature_celcius': 55, 'climate': [{'air_temperature_celcius': 14}]}
# {'_id': ObjectId('628a4077c40eee097235837b'), 'datetime': '2021-03-31T04:58:30', 'confidence': 82, 'surface_temperature_celcius': 56, 'climate': [{'air_temperature_celcius': 14}]}
# {'_id': ObjectId('628a4077c40eee09723583ab'), 'datetime': '2021-03-28T04:27:00', 'confidence': 82, 'surface_temperature_celcius': 55, 'climate': [{'air_temperature_celcius': 18}]}
# {'_id': ObjectId('628a4077c40eee09723583cf'), 'datetime': '2021-03-26T04:39:10', 'confidence': 82, 'surface_temperature_celcius': 55, 'climate': [{'air_temperature_celcius': 23}]}
# {'_id': ObjectId('628a4077c40eee09723583d8'), 'datetime': '2021-03-25T03:59:50', 'confidence': 82, 'surface_temperature_celcius': 65, 'climate': [{'air_temperature_celcius': 23}]}
# {'_id': ObjectId('628a4077c40eee09723579d9'), 'datetime': '2021-12-13T04:04:19', 'confidence': 83, 'surface_temperature_celcius': 60, 'climate': [{'air_temperature_celcius': 28}]}
# {'_id': ObjectId('628a4077c40eee09723579fd'), 'datetime': '2021-11-30T00:20:53', 'confidence': 83, 'surface_temperature_celcius': 58, 'climate': [{'air_temperature_celcius': 26}]}
# {'_id': ObjectId('628a4077c40eee0972357a33'), 'datetime': '2021-11-05T04:41:34', 'confidence': 83, 'surface_temperature_celcius': 58, 'climate': [{'air_temperature_celcius': 13}]}
# {'_id': ObjectId('628a4077c40eee0972357a7a'), 'datetime': '2021-10-02T04:53:10', 'confidence': 83, 'surface_temperature_celcius': 50, 'climate': [{'air_temperature_celcius': 11}]}
# {'_id': ObjectId('628a4077c40eee0972357a8a'), 'datetime': '2021-09-27T04:35:36', 'confidence': 83, 'surface_temperature_celcius': 56, 'climate': [{'air_temperature_celcius': 15}]}
# {'_id': ObjectId('628a4077c40eee0972357add'), 'datetime': '2021-08-13T05:02:30', 'confidence': 83, 'surface_temperature_celcius': 56, 'climate': [{'air_temperature_celcius': 15}]}
# {'_id': ObjectId('628a4077c40eee0972357aea'), 'datetime': '2021-07-06T04:08:00', 'confidence': 83, 'surface_temperature_celcius': 56, 'climate': [{'air_temperature_celcius': 9}]}
# {'_id': ObjectId('628a4077c40eee0972357b36'), 'datetime': '2021-06-02T04:14:10', 'confidence': 83, 'surface_temperature_celcius': 57, 'climate': [{'air_temperature_celcius': 12}]}
# {'_id': ObjectId('628a4077c40eee0972357b37'), 'datetime': '2021-06-02T04:14:10', 'confidence': 83, 'surface_temperature_celcius': 57, 'climate': [{'air_temperature_celcius': 12}]}
# {'_id': ObjectId('628a4077c40eee0972357b7c'), 'datetime': '2021-05-15T04:33:00', 'confidence': 83, 'surface_temperature_celcius': 57, 'climate': [{'air_temperature_celcius': 10}]}
# {'_id': ObjectId('628a4077c40eee0972357b87'), 'datetime': '2021-05-15T04:29:50', 'confidence': 83, 'surface_temperature_celcius': 63, 'climate': [{'air_temperature_celcius': 10}]}
# {'_id': ObjectId('628a4077c40eee0972357bb1'), 'datetime': '2021-05-15T04:26:20', 'confidence': 83, 'surface_temperature_celcius': 56, 'climate': [{'air_temperature_celcius': 10}]}
# {'_id': ObjectId('628a4077c40eee0972357bc2'), 'datetime': '2021-05-15T04:26:20', 'confidence': 83, 'surface_temperature_celcius': 56, 'climate': [{'air_temperature_celcius': 10}]}
# {'_id': ObjectId('628a4077c40eee0972357be9'), 'datetime': '2021-05-13T04:39:30', 'confidence': 83, 'surface_temperature_celcius': 63, 'climate': [{'air_temperature_celcius': 9}]}
# {'_id': ObjectId('628a4077c40eee0972357c12'), 'datetime': '2021-05-12T03:57:40', 'confidence': 83, 'surface_temperature_celcius': 57, 'climate': [{'air_temperature_celcius': 14}]}
# {'_id': ObjectId('628a4077c40eee0972357c3c'), 'datetime': '2021-05-10T04:11:30', 'confidence': 83, 'surface_temperature_celcius': 57, 'climate': [{'air_temperature_celcius': 10}]}
# {'_id': ObjectId('628a4077c40eee0972357c55'), 'datetime': '2021-05-10T04:08:30', 'confidence': 83, 'surface_temperature_celcius': 56, 'climate': [{'air_temperature_celcius': 10}]}
# {'_id': ObjectId('628a4077c40eee0972357cb5'), 'datetime': '2021-05-08T04:20:20', 'confidence': 83, 'surface_temperature_celcius': 56, 'climate': [{'air_temperature_celcius': 12}]}
# {'_id': ObjectId('628a4077c40eee0972357cd6'), 'datetime': '2021-05-06T00:16:40', 'confidence': 83, 'surface_temperature_celcius': 57, 'climate': [{'air_temperature_celcius': 12}]}
# {'_id': ObjectId('628a4077c40eee0972357d33'), 'datetime': '2021-05-04T04:44:40', 'confidence': 83, 'surface_temperature_celcius': 56, 'climate': [{'air_temperature_celcius': 10}]}
# {'_id': ObjectId('628a4077c40eee0972357d50'), 'datetime': '2021-05-04T04:44:40', 'confidence': 83, 'surface_temperature_celcius': 56, 'climate': [{'air_temperature_celcius': 10}]}
# {'_id': ObjectId('628a4077c40eee0972357dd4'), 'datetime': '2021-05-01T04:14:20', 'confidence': 83, 'surface_temperature_celcius': 77, 'climate': [{'air_temperature_celcius': 14}]}
# {'_id': ObjectId('628a4077c40eee0972357e21'), 'datetime': '2021-04-19T13:18:20', 'confidence': 83, 'surface_temperature_celcius': 40, 'climate': [{'air_temperature_celcius': 22}]}
# {'_id': ObjectId('628a4077c40eee0972357e84'), 'datetime': '2021-04-18T04:48:20', 'confidence': 83, 'surface_temperature_celcius': 56, 'climate': [{'air_temperature_celcius': 15}]}
# {'_id': ObjectId('628a4077c40eee0972357f4d'), 'datetime': '2021-04-18T04:44:50', 'confidence': 83, 'surface_temperature_celcius': 56, 'climate': [{'air_temperature_celcius': 15}]}
# {'_id': ObjectId('628a4077c40eee0972357f93'), 'datetime': '2021-04-18T00:24:40', 'confidence': 83, 'surface_temperature_celcius': 56, 'climate': [{'air_temperature_celcius': 15}]}
# {'_id': ObjectId('628a4077c40eee0972357f95'), 'datetime': '2021-04-18T00:24:40', 'confidence': 83, 'surface_temperature_celcius': 57, 'climate': [{'air_temperature_celcius': 15}]}
# {'_id': ObjectId('628a4077c40eee0972357f9e'), 'datetime': '2021-04-17T04:03:50', 'confidence': 83, 'surface_temperature_celcius': 57, 'climate': [{'air_temperature_celcius': 13}]}
# {'_id': ObjectId('628a4077c40eee0972357fbb'), 'datetime': '2021-04-17T01:19:10', 'confidence': 83, 'surface_temperature_celcius': 57, 'climate': [{'air_temperature_celcius': 13}]}
# {'_id': ObjectId('628a4077c40eee0972357fbd'), 'datetime': '2021-04-16T05:07:40', 'confidence': 83, 'surface_temperature_celcius': 57, 'climate': [{'air_temperature_celcius': 15}]}
# {'_id': ObjectId('628a4077c40eee0972357fc3'), 'datetime': '2021-04-16T04:56:50', 'confidence': 83, 'surface_temperature_celcius': 57, 'climate': [{'air_temperature_celcius': 15}]}
# {'_id': ObjectId('628a4077c40eee09723580d8'), 'datetime': '2021-04-13T04:26:40', 'confidence': 83, 'surface_temperature_celcius': 57, 'climate': [{'air_temperature_celcius': 16}]}
# {'_id': ObjectId('628a4077c40eee0972358121'), 'datetime': '2021-04-13T04:26:30', 'confidence': 83, 'surface_temperature_celcius': 56, 'climate': [{'air_temperature_celcius': 16}]}
# {'_id': ObjectId('628a4077c40eee0972358129'), 'datetime': '2021-04-13T04:26:30', 'confidence': 83, 'surface_temperature_celcius': 57, 'climate': [{'air_temperature_celcius': 16}]}
# {'_id': ObjectId('628a4077c40eee097235814b'), 'datetime': '2021-04-13T04:26:30', 'confidence': 83, 'surface_temperature_celcius': 57, 'climate': [{'air_temperature_celcius': 16}]}
# {'_id': ObjectId('628a4077c40eee097235814e'), 'datetime': '2021-04-13T04:26:30', 'confidence': 83, 'surface_temperature_celcius': 57, 'climate': [{'air_temperature_celcius': 16}]}
# {'_id': ObjectId('628a4077c40eee0972358170'), 'datetime': '2021-04-13T04:26:30', 'confidence': 83, 'surface_temperature_celcius': 56, 'climate': [{'air_temperature_celcius': 16}]}
# {'_id': ObjectId('628a4077c40eee0972358178'), 'datetime': '2021-04-13T04:26:30', 'confidence': 83, 'surface_temperature_celcius': 56, 'climate': [{'air_temperature_celcius': 16}]}
# {'_id': ObjectId('628a4077c40eee09723581a9'), 'datetime': '2021-04-12T03:47:20', 'confidence': 83, 'surface_temperature_celcius': 56, 'climate': [{'air_temperature_celcius': 14}]}
# {'_id': ObjectId('628a4077c40eee0972358230'), 'datetime': '2021-04-06T04:27:00', 'confidence': 83, 'surface_temperature_celcius': 57, 'climate': [{'air_temperature_celcius': 19}]}
# {'_id': ObjectId('628a4077c40eee0972358234'), 'datetime': '2021-04-06T04:24:40', 'confidence': 83, 'surface_temperature_celcius': 64, 'climate': [{'air_temperature_celcius': 19}]}
# {'_id': ObjectId('628a4077c40eee0972358248'), 'datetime': '2021-04-06T04:22:20', 'confidence': 83, 'surface_temperature_celcius': 56, 'climate': [{'air_temperature_celcius': 19}]}
# {'_id': ObjectId('628a4077c40eee0972358263'), 'datetime': '2021-04-06T04:20:50', 'confidence': 83, 'surface_temperature_celcius': 63, 'climate': [{'air_temperature_celcius': 19}]}
# ...
# {'_id': ObjectId('628a4077c40eee0972358038'), 'datetime': '2021-04-13T04:33:50', 'confidence': 100, 'surface_temperature_celcius': 88, 'climate': [{'air_temperature_celcius': 16}]}
# {'_id': ObjectId('628a4077c40eee0972358045'), 'datetime': '2021-04-13T04:33:20', 'confidence': 100, 'surface_temperature_celcius': 96, 'climate': [{'air_temperature_celcius': 16}]}
# {'_id': ObjectId('628a4077c40eee0972358071'), 'datetime': '2021-04-13T04:29:40', 'confidence': 100, 'surface_temperature_celcius': 93, 'climate': [{'air_temperature_celcius': 16}]}
# {'_id': ObjectId('628a4077c40eee0972358074'), 'datetime': '2021-04-13T04:29:20', 'confidence': 100, 'surface_temperature_celcius': 95, 'climate': [{'air_temperature_celcius': 16}]}
# {'_id': ObjectId('628a4077c40eee0972358077'), 'datetime': '2021-04-13T04:28:30', 'confidence': 100, 'surface_temperature_celcius': 114, 'climate': [{'air_temperature_celcius': 16}]}
# {'_id': ObjectId('628a4077c40eee097235807d'), 'datetime': '2021-04-13T04:28:10', 'confidence': 100, 'surface_temperature_celcius': 120, 'climate': [{'air_temperature_celcius': 16}]}
# {'_id': ObjectId('628a4077c40eee0972358080'), 'datetime': '2021-04-13T04:28:10', 'confidence': 100, 'surface_temperature_celcius': 90, 'climate': [{'air_temperature_celcius': 16}]}
# {'_id': ObjectId('628a4077c40eee0972358087'), 'datetime': '2021-04-13T04:28:10', 'confidence': 100, 'surface_temperature_celcius': 102, 'climate': [{'air_temperature_celcius': 16}]}
# {'_id': ObjectId('628a4077c40eee097235809d'), 'datetime': '2021-04-13T04:27:30', 'confidence': 100, 'surface_temperature_celcius': 88, 'climate': [{'air_temperature_celcius': 16}]}
# {'_id': ObjectId('628a4077c40eee097235809f'), 'datetime': '2021-04-13T04:27:20', 'confidence': 100, 'surface_temperature_celcius': 113, 'climate': [{'air_temperature_celcius': 16}]}
# {'_id': ObjectId('628a4077c40eee09723580a4'), 'datetime': '2021-04-13T04:27:20', 'confidence': 100, 'surface_temperature_celcius': 95, 'climate': [{'air_temperature_celcius': 16}]}
# {'_id': ObjectId('628a4077c40eee09723580a6'), 'datetime': '2021-04-13T04:27:20', 'confidence': 100, 'surface_temperature_celcius': 92, 'climate': [{'air_temperature_celcius': 16}]}
# {'_id': ObjectId('628a4077c40eee09723580b2'), 'datetime': '2021-04-13T04:27:00', 'confidence': 100, 'surface_temperature_celcius': 101, 'climate': [{'air_temperature_celcius': 16}]}
# {'_id': ObjectId('628a4077c40eee09723580b7'), 'datetime': '2021-04-13T04:26:50', 'confidence': 100, 'surface_temperature_celcius': 107, 'climate': [{'air_temperature_celcius': 16}]}
# {'_id': ObjectId('628a4077c40eee09723580bb'), 'datetime': '2021-04-13T04:26:50', 'confidence': 100, 'surface_temperature_celcius': 115, 'climate': [{'air_temperature_celcius': 16}]}
# {'_id': ObjectId('628a4077c40eee09723580bc'), 'datetime': '2021-04-13T04:26:50', 'confidence': 100, 'surface_temperature_celcius': 89, 'climate': [{'air_temperature_celcius': 16}]}
# {'_id': ObjectId('628a4077c40eee09723580c3'), 'datetime': '2021-04-13T04:26:40', 'confidence': 100, 'surface_temperature_celcius': 104, 'climate': [{'air_temperature_celcius': 16}]}
# {'_id': ObjectId('628a4077c40eee09723580d2'), 'datetime': '2021-04-13T04:26:40', 'confidence': 100, 'surface_temperature_celcius': 97, 'climate': [{'air_temperature_celcius': 16}]}
# {'_id': ObjectId('628a4077c40eee09723580ec'), 'datetime': '2021-04-13T04:26:30', 'confidence': 100, 'surface_temperature_celcius': 87, 'climate': [{'air_temperature_celcius': 16}]}
# {'_id': ObjectId('628a4077c40eee0972358101'), 'datetime': '2021-04-13T04:26:30', 'confidence': 100, 'surface_temperature_celcius': 93, 'climate': [{'air_temperature_celcius': 16}]}
# {'_id': ObjectId('628a4077c40eee0972358103'), 'datetime': '2021-04-13T04:26:30', 'confidence': 100, 'surface_temperature_celcius': 112, 'climate': [{'air_temperature_celcius': 16}]}
# {'_id': ObjectId('628a4077c40eee0972358116'), 'datetime': '2021-04-13T04:26:30', 'confidence': 100, 'surface_temperature_celcius': 110, 'climate': [{'air_temperature_celcius': 16}]}
# {'_id': ObjectId('628a4077c40eee097235811d'), 'datetime': '2021-04-13T04:26:30', 'confidence': 100, 'surface_temperature_celcius': 108, 'climate': [{'air_temperature_celcius': 16}]}
# {'_id': ObjectId('628a4077c40eee097235811f'), 'datetime': '2021-04-13T04:26:30', 'confidence': 100, 'surface_temperature_celcius': 90, 'climate': [{'air_temperature_celcius': 16}]}
# {'_id': ObjectId('628a4077c40eee0972358140'), 'datetime': '2021-04-13T04:26:30', 'confidence': 100, 'surface_temperature_celcius': 99, 'climate': [{'air_temperature_celcius': 16}]}
# {'_id': ObjectId('628a4077c40eee097235814d'), 'datetime': '2021-04-13T04:26:30', 'confidence': 100, 'surface_temperature_celcius': 91, 'climate': [{'air_temperature_celcius': 16}]}
# {'_id': ObjectId('628a4077c40eee0972358150'), 'datetime': '2021-04-13T04:26:30', 'confidence': 100, 'surface_temperature_celcius': 92, 'climate': [{'air_temperature_celcius': 16}]}
# {'_id': ObjectId('628a4077c40eee0972358159'), 'datetime': '2021-04-13T04:26:30', 'confidence': 100, 'surface_temperature_celcius': 93, 'climate': [{'air_temperature_celcius': 16}]}
# {'_id': ObjectId('628a4077c40eee097235815f'), 'datetime': '2021-04-13T04:26:30', 'confidence': 100, 'surface_temperature_celcius': 92, 'climate': [{'air_temperature_celcius': 16}]}
# {'_id': ObjectId('628a4077c40eee0972358160'), 'datetime': '2021-04-13T04:26:30', 'confidence': 100, 'surface_temperature_celcius': 111, 'climate': [{'air_temperature_celcius': 16}]}
# {'_id': ObjectId('628a4077c40eee0972358162'), 'datetime': '2021-04-13T04:26:30', 'confidence': 100, 'surface_temperature_celcius': 93, 'climate': [{'air_temperature_celcius': 16}]}
# {'_id': ObjectId('628a4077c40eee097235816f'), 'datetime': '2021-04-13T04:26:30', 'confidence': 100, 'surface_temperature_celcius': 92, 'climate': [{'air_temperature_celcius': 16}]}
# {'_id': ObjectId('628a4077c40eee0972358171'), 'datetime': '2021-04-13T04:26:30', 'confidence': 100, 'surface_temperature_celcius': 111, 'climate': [{'air_temperature_celcius': 16}]}
# {'_id': ObjectId('628a4077c40eee0972358172'), 'datetime': '2021-04-13T04:26:30', 'confidence': 100, 'surface_temperature_celcius': 96, 'climate': [{'air_temperature_celcius': 16}]}
# {'_id': ObjectId('628a4077c40eee097235817f'), 'datetime': '2021-04-13T04:26:30', 'confidence': 100, 'surface_temperature_celcius': 90, 'climate': [{'air_temperature_celcius': 16}]}
# {'_id': ObjectId('628a4077c40eee097235818f'), 'datetime': '2021-04-12T05:28:10', 'confidence': 100, 'surface_temperature_celcius': 106, 'climate': [{'air_temperature_celcius': 14}]}
# {'_id': ObjectId('628a4077c40eee0972358198'), 'datetime': '2021-04-12T05:21:40', 'confidence': 100, 'surface_temperature_celcius': 98, 'climate': [{'air_temperature_celcius': 14}]}
# {'_id': ObjectId('628a4077c40eee09723581a8'), 'datetime': '2021-04-12T03:47:30', 'confidence': 100, 'surface_temperature_celcius': 106, 'climate': [{'air_temperature_celcius': 14}]}
# {'_id': ObjectId('628a4077c40eee09723581b4'), 'datetime': '2021-04-12T03:44:50', 'confidence': 100, 'surface_temperature_celcius': 98, 'climate': [{'air_temperature_celcius': 14}]}
# {'_id': ObjectId('628a4077c40eee09723581c8'), 'datetime': '2021-04-12T03:44:40', 'confidence': 100, 'surface_temperature_celcius': 111, 'climate': [{'air_temperature_celcius': 14}]}
# {'_id': ObjectId('628a4077c40eee09723581ed'), 'datetime': '2021-04-08T04:12:20', 'confidence': 100, 'surface_temperature_celcius': 94, 'climate': [{'air_temperature_celcius': 19}]}
# {'_id': ObjectId('628a4077c40eee0972358209'), 'datetime': '2021-04-07T12:51:00', 'confidence': 100, 'surface_temperature_celcius': 49, 'climate': [{'air_temperature_celcius': 21}]}
# {'_id': ObjectId('628a4077c40eee097235821c'), 'datetime': '2021-04-07T03:31:40', 'confidence': 100, 'surface_temperature_celcius': 89, 'climate': [{'air_temperature_celcius': 21}]}
# {'_id': ObjectId('628a4077c40eee0972358222'), 'datetime': '2021-04-07T03:27:10', 'confidence': 100, 'surface_temperature_celcius': 106, 'climate': [{'air_temperature_celcius': 21}]}
# {'_id': ObjectId('628a4077c40eee0972358227'), 'datetime': '2021-04-06T04:27:50', 'confidence': 100, 'surface_temperature_celcius': 95, 'climate': [{'air_temperature_celcius': 19}]}
# {'_id': ObjectId('628a4077c40eee0972358228'), 'datetime': '2021-04-06T04:27:50', 'confidence': 100, 'surface_temperature_celcius': 88, 'climate': [{'air_temperature_celcius': 19}]}
# {'_id': ObjectId('628a4077c40eee097235822c'), 'datetime': '2021-04-06T04:27:00', 'confidence': 100, 'surface_temperature_celcius': 97, 'climate': [{'air_temperature_celcius': 19}]}
# {'_id': ObjectId('628a4077c40eee097235822f'), 'datetime': '2021-04-06T04:27:00', 'confidence': 100, 'surface_temperature_celcius': 99, 'climate': [{'air_temperature_celcius': 19}]}
# {'_id': ObjectId('628a4077c40eee097235824c'), 'datetime': '2021-04-06T04:22:20', 'confidence': 100, 'surface_temperature_celcius': 103, 'climate': [{'air_temperature_celcius': 19}]}
# {'_id': ObjectId('628a4077c40eee097235825e'), 'datetime': '2021-04-06T04:21:00', 'confidence': 100, 'surface_temperature_celcius': 115, 'climate': [{'air_temperature_celcius': 19}]}
# {'_id': ObjectId('628a4077c40eee0972358260'), 'datetime': '2021-04-06T04:20:50', 'confidence': 100, 'surface_temperature_celcius': 95, 'climate': [{'air_temperature_celcius': 19}]}
# {'_id': ObjectId('628a4077c40eee0972358287'), 'datetime': '2021-04-06T04:20:40', 'confidence': 100, 'surface_temperature_celcius': 100, 'climate': [{'air_temperature_celcius': 19}]}
# {'_id': ObjectId('628a4077c40eee097235829a'), 'datetime': '2021-04-05T13:09:00', 'confidence': 100, 'surface_temperature_celcius': 58, 'climate': [{'air_temperature_celcius': 17}]}
# {'_id': ObjectId('628a4077c40eee097235829d'), 'datetime': '2021-04-05T13:08:40', 'confidence': 100, 'surface_temperature_celcius': 47, 'climate': [{'air_temperature_celcius': 17}]}
# {'_id': ObjectId('628a4077c40eee09723582a0'), 'datetime': '2021-04-05T13:04:20', 'confidence': 100, 'surface_temperature_celcius': 49, 'climate': [{'air_temperature_celcius': 17}]}
# {'_id': ObjectId('628a4077c40eee09723582a1'), 'datetime': '2021-04-05T13:03:20', 'confidence': 100, 'surface_temperature_celcius': 55, 'climate': [{'air_temperature_celcius': 17}]}
# {'_id': ObjectId('628a4077c40eee09723582a3'), 'datetime': '2021-04-05T13:03:00', 'confidence': 100, 'surface_temperature_celcius': 55, 'climate': [{'air_temperature_celcius': 17}]}
# {'_id': ObjectId('628a4077c40eee09723582c1'), 'datetime': '2021-04-05T03:39:10', 'confidence': 100, 'surface_temperature_celcius': 92, 'climate': [{'air_temperature_celcius': 17}]}
# {'_id': ObjectId('628a4077c40eee09723582cd'), 'datetime': '2021-04-04T15:30:40', 'confidence': 100, 'surface_temperature_celcius': 64, 'climate': [{'air_temperature_celcius': 16}]}
# {'_id': ObjectId('628a4077c40eee09723582d2'), 'datetime': '2021-04-04T04:40:00', 'confidence': 100, 'surface_temperature_celcius': 120, 'climate': [{'air_temperature_celcius': 16}]}
# {'_id': ObjectId('628a4077c40eee09723582db'), 'datetime': '2021-04-04T04:39:20', 'confidence': 100, 'surface_temperature_celcius': 107, 'climate': [{'air_temperature_celcius': 16}]}
# {'_id': ObjectId('628a4077c40eee09723582ec'), 'datetime': '2021-04-04T04:35:00', 'confidence': 100, 'surface_temperature_celcius': 95, 'climate': [{'air_temperature_celcius': 16}]}
# {'_id': ObjectId('628a4077c40eee09723582f8'), 'datetime': '2021-04-04T04:33:30', 'confidence': 100, 'surface_temperature_celcius': 113, 'climate': [{'air_temperature_celcius': 16}]}
# {'_id': ObjectId('628a4077c40eee097235830b'), 'datetime': '2021-04-04T04:32:50', 'confidence': 100, 'surface_temperature_celcius': 123, 'climate': [{'air_temperature_celcius': 16}]}
# {'_id': ObjectId('628a4077c40eee097235830d'), 'datetime': '2021-04-04T04:32:50', 'confidence': 100, 'surface_temperature_celcius': 118, 'climate': [{'air_temperature_celcius': 16}]}
# {'_id': ObjectId('628a4077c40eee0972358312'), 'datetime': '2021-04-04T04:32:40', 'confidence': 100, 'surface_temperature_celcius': 120, 'climate': [{'air_temperature_celcius': 16}]}
# {'_id': ObjectId('628a4077c40eee0972358318'), 'datetime': '2021-04-04T04:32:40', 'confidence': 100, 'surface_temperature_celcius': 101, 'climate': [{'air_temperature_celcius': 16}]}
# {'_id': ObjectId('628a4077c40eee097235831f'), 'datetime': '2021-04-04T04:32:40', 'confidence': 100, 'surface_temperature_celcius': 98, 'climate': [{'air_temperature_celcius': 16}]}
# {'_id': ObjectId('628a4077c40eee0972358326'), 'datetime': '2021-04-03T13:15:10', 'confidence': 100, 'surface_temperature_celcius': 62, 'climate': [{'air_temperature_celcius': 15}]}
# {'_id': ObjectId('628a4077c40eee0972358332'), 'datetime': '2021-04-03T03:53:50', 'confidence': 100, 'surface_temperature_celcius': 93, 'climate': [{'air_temperature_celcius': 15}]}
# {'_id': ObjectId('628a4077c40eee097235833a'), 'datetime': '2021-04-03T03:52:30', 'confidence': 100, 'surface_temperature_celcius': 90, 'climate': [{'air_temperature_celcius': 15}]}
# {'_id': ObjectId('628a4077c40eee097235833b'), 'datetime': '2021-04-03T03:52:20', 'confidence': 100, 'surface_temperature_celcius': 115, 'climate': [{'air_temperature_celcius': 15}]}
# {'_id': ObjectId('628a4077c40eee097235833f'), 'datetime': '2021-04-03T03:52:10', 'confidence': 100, 'surface_temperature_celcius': 98, 'climate': [{'air_temperature_celcius': 15}]}
# {'_id': ObjectId('628a4077c40eee0972358340'), 'datetime': '2021-04-03T03:52:10', 'confidence': 100, 'surface_temperature_celcius': 89, 'climate': [{'air_temperature_celcius': 15}]}
# {'_id': ObjectId('628a4077c40eee097235834c'), 'datetime': '2021-04-03T03:51:00', 'confidence': 100, 'surface_temperature_celcius': 103, 'climate': [{'air_temperature_celcius': 15}]}
# {'_id': ObjectId('628a4077c40eee09723583a7'), 'datetime': '2021-03-28T04:27:20', 'confidence': 100, 'surface_temperature_celcius': 107, 'climate': [{'air_temperature_celcius': 18}]}
# {'_id': ObjectId('628a4077c40eee09723583aa'), 'datetime': '2021-03-28T04:27:10', 'confidence': 100, 'surface_temperature_celcius': 108, 'climate': [{'air_temperature_celcius': 18}]}
# {'_id': ObjectId('628a4077c40eee09723583b2'), 'datetime': '2021-03-28T04:26:50', 'confidence': 100, 'surface_temperature_celcius': 90, 'climate': [{'air_temperature_celcius': 18}]}
# {'_id': ObjectId('628a4077c40eee09723583ce'), 'datetime': '2021-03-26T04:39:10', 'confidence': 100, 'surface_temperature_celcius': 89, 'climate': [{'air_temperature_celcius': 23}]}
# {'_id': ObjectId('628a4077c40eee09723583dc'), 'datetime': '2021-03-25T03:57:10', 'confidence': 100, 'surface_temperature_celcius': 111, 'climate': [{'air_temperature_celcius': 23}]}
# {'_id': ObjectId('628a4077c40eee09723583df'), 'datetime': '2021-03-25T03:56:40', 'confidence': 100, 'surface_temperature_celcius': 99, 'climate': [{'air_temperature_celcius': 23}]}
# {'_id': ObjectId('628a4077c40eee09723583f0'), 'datetime': '2021-03-19T04:32:50', 'confidence': 100, 'surface_temperature_celcius': 91, 'climate': [{'air_temperature_celcius': 24}]}
# {'_id': ObjectId('628a4077c40eee09723583f3'), 'datetime': '2021-03-19T04:32:40', 'confidence': 100, 'surface_temperature_celcius': 113, 'climate': [{'air_temperature_celcius': 24}]}
# {'_id': ObjectId('628a4077c40eee09723583f5'), 'datetime': '2021-03-19T04:32:40', 'confidence': 100, 'surface_temperature_celcius': 106, 'climate': [{'air_temperature_celcius': 24}]}
# {'_id': ObjectId('628a4077c40eee09723583fa'), 'datetime': '2021-03-18T03:50:50', 'confidence': 100, 'surface_temperature_celcius': 121, 'climate': [{'air_temperature_celcius': 21}]}
# {'_id': ObjectId('628a4077c40eee0972358417'), 'datetime': '2021-03-12T04:28:20', 'confidence': 100, 'surface_temperature_celcius': 99, 'climate': [{'air_temperature_celcius': 21}]}
# {'_id': ObjectId('628a4077c40eee097235841a'), 'datetime': '2021-03-10T04:48:40', 'confidence': 100, 'surface_temperature_celcius': 105, 'climate': [{'air_temperature_celcius': 19}]}
# {'_id': ObjectId('628a4077c40eee097235841b'), 'datetime': '2021-03-10T04:46:20', 'confidence': 100, 'surface_temperature_celcius': 109, 'climate': [{'air_temperature_celcius': 19}]}

# %% [markdown]
# ## e. Find the top 10 records with the highest surface temperature (°C).

# %%
results = hotspot_coll.aggregate([{"$sort":{"surface_temperature_celcius":-1}}, {"$limit":10}])

for x in results: 
    print(x)
# Out:
# {'_id': ObjectId('628a4077c40eee0972357e61'), 'latitude': -38.1665, 'longitude': 143.062, 'datetime': '2021-04-18T04:52:00', 'confidence': 100, 'date': datetime.datetime(2021, 4, 18, 0, 0), 'surface_temperature_celcius': 124}
# {'_id': ObjectId('628a4077c40eee097235830b'), 'latitude': -36.343, 'longitude': 142.1986, 'datetime': '2021-04-04T04:32:50', 'confidence': 100, 'date': datetime.datetime(2021, 4, 4, 0, 0), 'surface_temperature_celcius': 123}
# {'_id': ObjectId('628a4077c40eee0972357dd3'), 'latitude': -36.9318, 'longitude': 143.0907, 'datetime': '2021-05-01T04:14:20', 'confidence': 100, 'date': datetime.datetime(2021, 5, 1, 0, 0), 'surface_temperature_celcius': 122}
# {'_id': ObjectId('628a4077c40eee09723583fa'), 'latitude': -37.016999999999996, 'longitude': 148.1297, 'datetime': '2021-03-18T03:50:50', 'confidence': 100, 'date': datetime.datetime(2021, 3, 18, 0, 0), 'surface_temperature_celcius': 121}
# {'_id': ObjectId('628a4077c40eee0972357be5'), 'latitude': -34.9938, 'longitude': 141.876, 'datetime': '2021-05-13T04:40:20', 'confidence': 100, 'date': datetime.datetime(2021, 5, 13, 0, 0), 'surface_temperature_celcius': 120}
# {'_id': ObjectId('628a4077c40eee09723582d2'), 'latitude': -36.1057, 'longitude': 141.7608, 'datetime': '2021-04-04T04:40:00', 'confidence': 100, 'date': datetime.datetime(2021, 4, 4, 0, 0), 'surface_temperature_celcius': 120}
# {'_id': ObjectId('628a4077c40eee0972358312'), 'latitude': -36.3521, 'longitude': 142.2008, 'datetime': '2021-04-04T04:32:40', 'confidence': 100, 'date': datetime.datetime(2021, 4, 4, 0, 0), 'surface_temperature_celcius': 120}
# {'_id': ObjectId('628a4077c40eee097235807d'), 'latitude': -37.0745, 'longitude': 141.0692, 'datetime': '2021-04-13T04:28:10', 'confidence': 100, 'date': datetime.datetime(2021, 4, 13, 0, 0), 'surface_temperature_celcius': 120}
# {'_id': ObjectId('628a4077c40eee0972357efa'), 'latitude': -37.8326, 'longitude': 143.4999, 'datetime': '2021-04-18T04:44:50', 'confidence': 100, 'date': datetime.datetime(2021, 4, 18, 0, 0), 'surface_temperature_celcius': 120}
# {'_id': ObjectId('628a4077c40eee0972357d29'), 'latitude': -36.4057, 'longitude': 140.9806, 'datetime': '2021-05-04T04:44:50', 'confidence': 100, 'date': datetime.datetime(2021, 5, 4, 0, 0), 'surface_temperature_celcius': 119}

# %% [markdown]
# ## f. Find the number of fires each day. You are required to only display the total number of fires and the date in the output.

# %%
results = mydb.climate.aggregate([
    {
        "$lookup":{
            "from":"hotspot",
            "localField": "date",
            "foreignField": "date",
            "as":"hotspot"
        }
    },
   
    {
        "$project":
        {
            "_id":0, 
            "date":1, 
            "num_of_fire":{'$size':'$hotspot'}
            
        }
    }
    
])
for x in results:
    print(x)
# Out:
# {'date': datetime.datetime(2020, 12, 31, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 1, 2, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 1, 3, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 1, 4, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 1, 5, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 1, 6, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 1, 7, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 1, 8, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 1, 9, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 1, 10, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 1, 11, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 1, 12, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 1, 13, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 1, 14, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 1, 15, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 1, 16, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 1, 17, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 1, 18, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 1, 19, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 1, 20, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 1, 21, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 1, 22, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 1, 23, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 1, 24, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 1, 25, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 1, 26, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 1, 27, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 1, 28, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 1, 29, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 1, 30, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 1, 31, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 2, 1, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 2, 2, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 2, 3, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 2, 4, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 2, 5, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 2, 6, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 2, 7, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 2, 8, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 2, 9, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 2, 10, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 2, 11, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 2, 12, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 2, 13, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 2, 14, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 2, 15, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 2, 16, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 2, 17, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 2, 18, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 2, 19, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 2, 20, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 2, 21, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 2, 22, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 2, 23, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 2, 24, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 2, 25, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 2, 26, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 2, 27, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 2, 28, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 3, 1, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 3, 2, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 3, 3, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 3, 4, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 3, 5, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 3, 6, 0, 0), 'num_of_fire': 2}
# {'date': datetime.datetime(2021, 3, 7, 0, 0), 'num_of_fire': 1}
# {'date': datetime.datetime(2021, 3, 8, 0, 0), 'num_of_fire': 2}
# {'date': datetime.datetime(2021, 3, 9, 0, 0), 'num_of_fire': 3}
# {'date': datetime.datetime(2021, 3, 10, 0, 0), 'num_of_fire': 8}
# {'date': datetime.datetime(2021, 3, 11, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 3, 12, 0, 0), 'num_of_fire': 5}
# {'date': datetime.datetime(2021, 3, 13, 0, 0), 'num_of_fire': 2}
# {'date': datetime.datetime(2021, 3, 14, 0, 0), 'num_of_fire': 10}
# {'date': datetime.datetime(2021, 3, 15, 0, 0), 'num_of_fire': 7}
# {'date': datetime.datetime(2021, 3, 16, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 3, 17, 0, 0), 'num_of_fire': 6}
# {'date': datetime.datetime(2021, 3, 18, 0, 0), 'num_of_fire': 3}
# {'date': datetime.datetime(2021, 3, 19, 0, 0), 'num_of_fire': 21}
# {'date': datetime.datetime(2021, 3, 20, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 3, 21, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 3, 22, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 3, 23, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 3, 24, 0, 0), 'num_of_fire': 2}
# {'date': datetime.datetime(2021, 3, 25, 0, 0), 'num_of_fire': 13}
# {'date': datetime.datetime(2021, 3, 26, 0, 0), 'num_of_fire': 17}
# {'date': datetime.datetime(2021, 3, 27, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 3, 28, 0, 0), 'num_of_fire': 54}
# {'date': datetime.datetime(2021, 3, 29, 0, 0), 'num_of_fire': 1}
# {'date': datetime.datetime(2021, 3, 30, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 3, 31, 0, 0), 'num_of_fire': 22}
# {'date': datetime.datetime(2021, 4, 1, 0, 0), 'num_of_fire': 7}
# {'date': datetime.datetime(2021, 4, 2, 0, 0), 'num_of_fire': 5}
# {'date': datetime.datetime(2021, 4, 3, 0, 0), 'num_of_fire': 72}
# {'date': datetime.datetime(2021, 4, 4, 0, 0), 'num_of_fire': 89}
# {'date': datetime.datetime(2021, 4, 5, 0, 0), 'num_of_fire': 49}
# {'date': datetime.datetime(2021, 4, 6, 0, 0), 'num_of_fire': 118}
# {'date': datetime.datetime(2021, 4, 7, 0, 0), 'num_of_fire': 39}
# {'date': datetime.datetime(2021, 4, 8, 0, 0), 'num_of_fire': 20}
# {'date': datetime.datetime(2021, 4, 9, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 4, 10, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 4, 11, 0, 0), 'num_of_fire': 24}
# {'date': datetime.datetime(2021, 4, 12, 0, 0), 'num_of_fire': 69}
# {'date': datetime.datetime(2021, 4, 13, 0, 0), 'num_of_fire': 357}
# {'date': datetime.datetime(2021, 4, 14, 0, 0), 'num_of_fire': 18}
# {'date': datetime.datetime(2021, 4, 15, 0, 0), 'num_of_fire': 69}
# {'date': datetime.datetime(2021, 4, 16, 0, 0), 'num_of_fire': 18}
# {'date': datetime.datetime(2021, 4, 17, 0, 0), 'num_of_fire': 38}
# {'date': datetime.datetime(2021, 4, 18, 0, 0), 'num_of_fire': 325}
# {'date': datetime.datetime(2021, 4, 19, 0, 0), 'num_of_fire': 50}
# {'date': datetime.datetime(2021, 4, 20, 0, 0), 'num_of_fire': 31}
# {'date': datetime.datetime(2021, 4, 21, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 4, 22, 0, 0), 'num_of_fire': 2}
# {'date': datetime.datetime(2021, 4, 23, 0, 0), 'num_of_fire': 19}
# {'date': datetime.datetime(2021, 4, 24, 0, 0), 'num_of_fire': 8}
# {'date': datetime.datetime(2021, 4, 25, 0, 0), 'num_of_fire': 3}
# {'date': datetime.datetime(2021, 4, 26, 0, 0), 'num_of_fire': 1}
# {'date': datetime.datetime(2021, 4, 27, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 4, 28, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 4, 29, 0, 0), 'num_of_fire': 3}
# {'date': datetime.datetime(2021, 4, 30, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 5, 1, 0, 0), 'num_of_fire': 20}
# {'date': datetime.datetime(2021, 5, 2, 0, 0), 'num_of_fire': 10}
# {'date': datetime.datetime(2021, 5, 3, 0, 0), 'num_of_fire': 64}
# {'date': datetime.datetime(2021, 5, 4, 0, 0), 'num_of_fire': 135}
# {'date': datetime.datetime(2021, 5, 5, 0, 0), 'num_of_fire': 31}
# {'date': datetime.datetime(2021, 5, 6, 0, 0), 'num_of_fire': 17}
# {'date': datetime.datetime(2021, 5, 7, 0, 0), 'num_of_fire': 3}
# {'date': datetime.datetime(2021, 5, 8, 0, 0), 'num_of_fire': 24}
# {'date': datetime.datetime(2021, 5, 9, 0, 0), 'num_of_fire': 13}
# {'date': datetime.datetime(2021, 5, 10, 0, 0), 'num_of_fire': 114}
# {'date': datetime.datetime(2021, 5, 11, 0, 0), 'num_of_fire': 19}
# {'date': datetime.datetime(2021, 5, 12, 0, 0), 'num_of_fire': 10}
# {'date': datetime.datetime(2021, 5, 13, 0, 0), 'num_of_fire': 54}
# {'date': datetime.datetime(2021, 5, 14, 0, 0), 'num_of_fire': 1}
# {'date': datetime.datetime(2021, 5, 15, 0, 0), 'num_of_fire': 102}
# {'date': datetime.datetime(2021, 5, 16, 0, 0), 'num_of_fire': 3}
# {'date': datetime.datetime(2021, 5, 17, 0, 0), 'num_of_fire': 1}
# {'date': datetime.datetime(2021, 5, 18, 0, 0), 'num_of_fire': 7}
# {'date': datetime.datetime(2021, 5, 19, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 5, 20, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 5, 21, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 5, 22, 0, 0), 'num_of_fire': 33}
# {'date': datetime.datetime(2021, 5, 23, 0, 0), 'num_of_fire': 5}
# {'date': datetime.datetime(2021, 5, 24, 0, 0), 'num_of_fire': 3}
# {'date': datetime.datetime(2021, 5, 25, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 5, 26, 0, 0), 'num_of_fire': 4}
# {'date': datetime.datetime(2021, 5, 27, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 5, 28, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 5, 29, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 5, 30, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 5, 31, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 6, 1, 0, 0), 'num_of_fire': 2}
# {'date': datetime.datetime(2021, 6, 2, 0, 0), 'num_of_fire': 11}
# {'date': datetime.datetime(2021, 6, 3, 0, 0), 'num_of_fire': 2}
# {'date': datetime.datetime(2021, 6, 4, 0, 0), 'num_of_fire': 9}
# {'date': datetime.datetime(2021, 6, 5, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 6, 6, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 6, 7, 0, 0), 'num_of_fire': 14}
# {'date': datetime.datetime(2021, 6, 8, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 6, 9, 0, 0), 'num_of_fire': 3}
# {'date': datetime.datetime(2021, 6, 10, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 6, 11, 0, 0), 'num_of_fire': 2}
# {'date': datetime.datetime(2021, 6, 12, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 6, 13, 0, 0), 'num_of_fire': 1}
# {'date': datetime.datetime(2021, 6, 14, 0, 0), 'num_of_fire': 4}
# {'date': datetime.datetime(2021, 6, 15, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 6, 16, 0, 0), 'num_of_fire': 2}
# {'date': datetime.datetime(2021, 6, 17, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 6, 18, 0, 0), 'num_of_fire': 2}
# {'date': datetime.datetime(2021, 6, 19, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 6, 20, 0, 0), 'num_of_fire': 6}
# {'date': datetime.datetime(2021, 6, 21, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 6, 22, 0, 0), 'num_of_fire': 1}
# {'date': datetime.datetime(2021, 6, 23, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 6, 24, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 6, 25, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 6, 26, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 6, 27, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 6, 28, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 6, 29, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 6, 30, 0, 0), 'num_of_fire': 6}
# {'date': datetime.datetime(2021, 7, 1, 0, 0), 'num_of_fire': 4}
# {'date': datetime.datetime(2021, 7, 2, 0, 0), 'num_of_fire': 8}
# {'date': datetime.datetime(2021, 7, 3, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 7, 4, 0, 0), 'num_of_fire': 1}
# {'date': datetime.datetime(2021, 7, 5, 0, 0), 'num_of_fire': 1}
# {'date': datetime.datetime(2021, 7, 6, 0, 0), 'num_of_fire': 3}
# {'date': datetime.datetime(2021, 7, 7, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 7, 8, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 7, 9, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 7, 10, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 7, 11, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 7, 12, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 7, 13, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 7, 14, 0, 0), 'num_of_fire': 2}
# {'date': datetime.datetime(2021, 7, 15, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 7, 16, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 7, 17, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 7, 18, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 7, 19, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 7, 20, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 7, 21, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 7, 22, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 7, 23, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 7, 24, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 7, 25, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 7, 26, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 7, 27, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 7, 28, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 7, 29, 0, 0), 'num_of_fire': 2}
# {'date': datetime.datetime(2021, 7, 30, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 7, 31, 0, 0), 'num_of_fire': 2}
# {'date': datetime.datetime(2021, 8, 1, 0, 0), 'num_of_fire': 2}
# {'date': datetime.datetime(2021, 8, 2, 0, 0), 'num_of_fire': 2}
# {'date': datetime.datetime(2021, 8, 3, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 8, 4, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 8, 5, 0, 0), 'num_of_fire': 1}
# {'date': datetime.datetime(2021, 8, 6, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 8, 7, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 8, 8, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 8, 9, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 8, 10, 0, 0), 'num_of_fire': 1}
# {'date': datetime.datetime(2021, 8, 11, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 8, 12, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 8, 13, 0, 0), 'num_of_fire': 9}
# {'date': datetime.datetime(2021, 8, 14, 0, 0), 'num_of_fire': 5}
# {'date': datetime.datetime(2021, 8, 15, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 8, 16, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 8, 17, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 8, 18, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 8, 19, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 8, 20, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 8, 21, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 8, 22, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 8, 23, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 8, 24, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 8, 25, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 8, 26, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 8, 27, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 8, 28, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 8, 29, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 8, 30, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 8, 31, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 9, 1, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 9, 2, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 9, 3, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 9, 4, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 9, 5, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 9, 6, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 9, 7, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 9, 8, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 9, 9, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 9, 10, 0, 0), 'num_of_fire': 4}
# {'date': datetime.datetime(2021, 9, 11, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 9, 12, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 9, 13, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 9, 14, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 9, 15, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 9, 16, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 9, 17, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 9, 18, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 9, 19, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 9, 20, 0, 0), 'num_of_fire': 5}
# {'date': datetime.datetime(2021, 9, 21, 0, 0), 'num_of_fire': 2}
# {'date': datetime.datetime(2021, 9, 22, 0, 0), 'num_of_fire': 1}
# {'date': datetime.datetime(2021, 9, 23, 0, 0), 'num_of_fire': 23}
# {'date': datetime.datetime(2021, 9, 24, 0, 0), 'num_of_fire': 28}
# {'date': datetime.datetime(2021, 9, 25, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 9, 26, 0, 0), 'num_of_fire': 1}
# {'date': datetime.datetime(2021, 9, 27, 0, 0), 'num_of_fire': 7}
# {'date': datetime.datetime(2021, 9, 28, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 9, 29, 0, 0), 'num_of_fire': 2}
# {'date': datetime.datetime(2021, 9, 30, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 10, 1, 0, 0), 'num_of_fire': 8}
# {'date': datetime.datetime(2021, 10, 2, 0, 0), 'num_of_fire': 7}
# {'date': datetime.datetime(2021, 10, 3, 0, 0), 'num_of_fire': 18}
# {'date': datetime.datetime(2021, 10, 4, 0, 0), 'num_of_fire': 5}
# {'date': datetime.datetime(2021, 10, 5, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 10, 6, 0, 0), 'num_of_fire': 2}
# {'date': datetime.datetime(2021, 10, 7, 0, 0), 'num_of_fire': 1}
# {'date': datetime.datetime(2021, 10, 8, 0, 0), 'num_of_fire': 1}
# {'date': datetime.datetime(2021, 10, 9, 0, 0), 'num_of_fire': 1}
# {'date': datetime.datetime(2021, 10, 10, 0, 0), 'num_of_fire': 3}
# {'date': datetime.datetime(2021, 10, 11, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 10, 12, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 10, 13, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 10, 14, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 10, 15, 0, 0), 'num_of_fire': 3}
# {'date': datetime.datetime(2021, 10, 16, 0, 0), 'num_of_fire': 1}
# {'date': datetime.datetime(2021, 10, 17, 0, 0), 'num_of_fire': 5}
# {'date': datetime.datetime(2021, 10, 18, 0, 0), 'num_of_fire': 6}
# {'date': datetime.datetime(2021, 10, 19, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 10, 20, 0, 0), 'num_of_fire': 3}
# {'date': datetime.datetime(2021, 10, 21, 0, 0), 'num_of_fire': 4}
# {'date': datetime.datetime(2021, 10, 22, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 10, 23, 0, 0), 'num_of_fire': 1}
# {'date': datetime.datetime(2021, 10, 24, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 10, 25, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 10, 26, 0, 0), 'num_of_fire': 5}
# {'date': datetime.datetime(2021, 10, 27, 0, 0), 'num_of_fire': 5}
# {'date': datetime.datetime(2021, 10, 28, 0, 0), 'num_of_fire': 1}
# {'date': datetime.datetime(2021, 10, 29, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 10, 30, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 10, 31, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 11, 1, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 11, 2, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 11, 3, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 11, 4, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 11, 5, 0, 0), 'num_of_fire': 4}
# {'date': datetime.datetime(2021, 11, 6, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 11, 7, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 11, 8, 0, 0), 'num_of_fire': 2}
# {'date': datetime.datetime(2021, 11, 9, 0, 0), 'num_of_fire': 10}
# {'date': datetime.datetime(2021, 11, 10, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 11, 11, 0, 0), 'num_of_fire': 4}
# {'date': datetime.datetime(2021, 11, 12, 0, 0), 'num_of_fire': 5}
# {'date': datetime.datetime(2021, 11, 13, 0, 0), 'num_of_fire': 5}
# {'date': datetime.datetime(2021, 11, 14, 0, 0), 'num_of_fire': 3}
# {'date': datetime.datetime(2021, 11, 15, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 11, 16, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 11, 17, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 11, 18, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 11, 19, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 11, 20, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 11, 21, 0, 0), 'num_of_fire': 1}
# {'date': datetime.datetime(2021, 11, 22, 0, 0), 'num_of_fire': 2}
# {'date': datetime.datetime(2021, 11, 23, 0, 0), 'num_of_fire': 5}
# {'date': datetime.datetime(2021, 11, 24, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 11, 25, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 11, 26, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 11, 27, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 11, 28, 0, 0), 'num_of_fire': 1}
# {'date': datetime.datetime(2021, 11, 29, 0, 0), 'num_of_fire': 8}
# {'date': datetime.datetime(2021, 11, 30, 0, 0), 'num_of_fire': 31}
# {'date': datetime.datetime(2021, 12, 1, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 12, 2, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 12, 3, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 12, 4, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 12, 5, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 12, 6, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 12, 7, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 12, 8, 0, 0), 'num_of_fire': 5}
# {'date': datetime.datetime(2021, 12, 9, 0, 0), 'num_of_fire': 4}
# {'date': datetime.datetime(2021, 12, 10, 0, 0), 'num_of_fire': 2}
# {'date': datetime.datetime(2021, 12, 11, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 12, 12, 0, 0), 'num_of_fire': 1}
# {'date': datetime.datetime(2021, 12, 13, 0, 0), 'num_of_fire': 1}
# {'date': datetime.datetime(2021, 12, 14, 0, 0), 'num_of_fire': 1}
# {'date': datetime.datetime(2021, 12, 15, 0, 0), 'num_of_fire': 4}
# {'date': datetime.datetime(2021, 12, 16, 0, 0), 'num_of_fire': 15}
# {'date': datetime.datetime(2021, 12, 17, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 12, 18, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 12, 19, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 12, 20, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 12, 21, 0, 0), 'num_of_fire': 1}
# {'date': datetime.datetime(2021, 12, 22, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 12, 23, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 12, 24, 0, 0), 'num_of_fire': 1}
# {'date': datetime.datetime(2021, 12, 25, 0, 0), 'num_of_fire': 1}
# {'date': datetime.datetime(2021, 12, 26, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 12, 27, 0, 0), 'num_of_fire': 4}
# {'date': datetime.datetime(2021, 12, 28, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 12, 29, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 12, 30, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 12, 31, 0, 0), 'num_of_fire': 0}
# {'date': datetime.datetime(2021, 1, 1, 0, 0), 'num_of_fire': 0}

# %% [markdown]
# ## g. Find the records of fires where the confidence is below 70

# %%
mq = {"confidence":{"$lte": 70}}
results = hotspot_coll.find(mq,{"latitude":1,"longitude":1,"confidence":1,"surface_temperature_celcius":1}).sort("confidence")

for x in results:
    print(x)
# Out:
# {'_id': ObjectId('628a4077c40eee09723579db'), 'latitude': -37.986999999999995, 'longitude': 144.005, 'confidence': 50, 'surface_temperature_celcius': 38}
# {'_id': ObjectId('628a4077c40eee0972357a0d'), 'latitude': -37.749, 'longitude': 148.297, 'confidence': 50, 'surface_temperature_celcius': 42}
# {'_id': ObjectId('628a4077c40eee0972357a61'), 'latitude': -36.418, 'longitude': 141.596, 'confidence': 50, 'surface_temperature_celcius': 41}
# {'_id': ObjectId('628a4077c40eee0972357a78'), 'latitude': -37.466, 'longitude': 148.1, 'confidence': 50, 'surface_temperature_celcius': 29}
# {'_id': ObjectId('628a4077c40eee0972357aba'), 'latitude': -36.984, 'longitude': 148.25, 'confidence': 50, 'surface_temperature_celcius': 35}
# {'_id': ObjectId('628a4077c40eee0972357af5'), 'latitude': -37.885999999999996, 'longitude': 147.207, 'confidence': 50, 'surface_temperature_celcius': 28}
# {'_id': ObjectId('628a4077c40eee0972357af6'), 'latitude': -37.885999999999996, 'longitude': 147.207, 'confidence': 50, 'surface_temperature_celcius': 28}
# {'_id': ObjectId('628a4077c40eee0972357bde'), 'latitude': -36.353, 'longitude': 144.5977, 'confidence': 50, 'surface_temperature_celcius': 38}
# {'_id': ObjectId('628a4077c40eee0972357c03'), 'latitude': -35.708, 'longitude': 143.7987, 'confidence': 50, 'surface_temperature_celcius': 38}
# {'_id': ObjectId('628a4077c40eee0972357cbe'), 'latitude': -36.2756, 'longitude': 145.811, 'confidence': 50, 'surface_temperature_celcius': 39}
# {'_id': ObjectId('628a4077c40eee0972357d09'), 'latitude': -36.943000000000005, 'longitude': 141.863, 'confidence': 50, 'surface_temperature_celcius': 40}
# {'_id': ObjectId('628a4077c40eee0972357d20'), 'latitude': -36.8059, 'longitude': 142.9103, 'confidence': 50, 'surface_temperature_celcius': 38}
# {'_id': ObjectId('628a4077c40eee0972357d25'), 'latitude': -36.0959, 'longitude': 145.6233, 'confidence': 50, 'surface_temperature_celcius': 38}
# {'_id': ObjectId('628a4077c40eee0972357db7'), 'latitude': -36.3511, 'longitude': 146.3809, 'confidence': 50, 'surface_temperature_celcius': 38}
# {'_id': ObjectId('628a4077c40eee0972357e44'), 'latitude': -37.2166, 'longitude': 143.8674, 'confidence': 50, 'surface_temperature_celcius': 38}
# {'_id': ObjectId('628a4077c40eee0972357f02'), 'latitude': -37.9184, 'longitude': 142.5436, 'confidence': 50, 'surface_temperature_celcius': 42}
# {'_id': ObjectId('628a4077c40eee0972357fc1'), 'latitude': -36.7194, 'longitude': 143.5593, 'confidence': 50, 'surface_temperature_celcius': 38}
# {'_id': ObjectId('628a4077c40eee097235804c'), 'latitude': -37.8345, 'longitude': 142.447, 'confidence': 50, 'surface_temperature_celcius': 38}
# {'_id': ObjectId('628a4077c40eee0972358193'), 'latitude': -36.7038, 'longitude': 141.0498, 'confidence': 50, 'surface_temperature_celcius': 39}
# {'_id': ObjectId('628a4077c40eee09723581c1'), 'latitude': -37.0643, 'longitude': 141.8567, 'confidence': 50, 'surface_temperature_celcius': 40}
# {'_id': ObjectId('628a4077c40eee09723581dc'), 'latitude': -36.343, 'longitude': 143.3479, 'confidence': 50, 'surface_temperature_celcius': 40}
# {'_id': ObjectId('628a4077c40eee0972358233'), 'latitude': -36.0834, 'longitude': 146.5364, 'confidence': 50, 'surface_temperature_celcius': 53}
# {'_id': ObjectId('628a4077c40eee0972358262'), 'latitude': -37.3556, 'longitude': 146.1085, 'confidence': 50, 'surface_temperature_celcius': 47}
# {'_id': ObjectId('628a4077c40eee0972358278'), 'latitude': -35.1383, 'longitude': 141.8172, 'confidence': 50, 'surface_temperature_celcius': 53}
# {'_id': ObjectId('628a4077c40eee09723582b4'), 'latitude': -38.3553, 'longitude': 147.0231, 'confidence': 50, 'surface_temperature_celcius': 38}
# {'_id': ObjectId('628a4077c40eee09723582dd'), 'latitude': -36.6951, 'longitude': 145.424, 'confidence': 50, 'surface_temperature_celcius': 43}
# {'_id': ObjectId('628a4077c40eee0972358376'), 'latitude': -36.1002, 'longitude': 147.6494, 'confidence': 50, 'surface_temperature_celcius': 39}
# {'_id': ObjectId('628a4077c40eee09723579d6'), 'latitude': -37.623000000000005, 'longitude': 149.32299999999998, 'confidence': 51, 'surface_temperature_celcius': 38}
# {'_id': ObjectId('628a4077c40eee09723579e8'), 'latitude': -37.59, 'longitude': 149.31, 'confidence': 51, 'surface_temperature_celcius': 42}
# {'_id': ObjectId('628a4077c40eee0972357a1c'), 'latitude': -38.167, 'longitude': 143.841, 'confidence': 51, 'surface_temperature_celcius': 38}
# {'_id': ObjectId('628a4077c40eee0972357a23'), 'latitude': -36.943000000000005, 'longitude': 143.286, 'confidence': 51, 'surface_temperature_celcius': 29}
# {'_id': ObjectId('628a4077c40eee0972357b80'), 'latitude': -36.7159, 'longitude': 141.4716, 'confidence': 51, 'surface_temperature_celcius': 38}
# {'_id': ObjectId('628a4077c40eee0972357b81'), 'latitude': -36.5963, 'longitude': 144.0066, 'confidence': 51, 'surface_temperature_celcius': 38}
# {'_id': ObjectId('628a4077c40eee0972357bc1'), 'latitude': -37.2794, 'longitude': 143.5903, 'confidence': 51, 'surface_temperature_celcius': 44}
# {'_id': ObjectId('628a4077c40eee0972357c7e'), 'latitude': -36.3355, 'longitude': 144.5241, 'confidence': 51, 'surface_temperature_celcius': 38}
# {'_id': ObjectId('628a4077c40eee0972357ca6'), 'latitude': -36.6497, 'longitude': 142.8306, 'confidence': 51, 'surface_temperature_celcius': 38}
# {'_id': ObjectId('628a4077c40eee0972357cbd'), 'latitude': -36.0744, 'longitude': 146.688, 'confidence': 51, 'surface_temperature_celcius': 38}
# {'_id': ObjectId('628a4077c40eee0972357cdb'), 'latitude': -37.547, 'longitude': 142.9081, 'confidence': 51, 'surface_temperature_celcius': 42}
# {'_id': ObjectId('628a4077c40eee0972357d10'), 'latitude': -36.5642, 'longitude': 142.5943, 'confidence': 51, 'surface_temperature_celcius': 38}
# {'_id': ObjectId('628a4077c40eee0972357d37'), 'latitude': -36.0144, 'longitude': 141.7008, 'confidence': 51, 'surface_temperature_celcius': 38}
# {'_id': ObjectId('628a4077c40eee0972357db2'), 'latitude': -36.4969, 'longitude': 143.9552, 'confidence': 51, 'surface_temperature_celcius': 39}
# {'_id': ObjectId('628a4077c40eee0972357e2a'), 'latitude': -37.175, 'longitude': 148.9347, 'confidence': 51, 'surface_temperature_celcius': 40}
# {'_id': ObjectId('628a4077c40eee0972357f4a'), 'latitude': -36.7887, 'longitude': 143.4841, 'confidence': 51, 'surface_temperature_celcius': 38}
# {'_id': ObjectId('628a4077c40eee0972357f77'), 'latitude': -36.4466, 'longitude': 141.2471, 'confidence': 51, 'surface_temperature_celcius': 40}
# {'_id': ObjectId('628a4077c40eee097235800b'), 'latitude': -37.8937, 'longitude': 147.1785, 'confidence': 51, 'surface_temperature_celcius': 38}
# {'_id': ObjectId('628a4077c40eee0972358141'), 'latitude': -37.9359, 'longitude': 143.3468, 'confidence': 51, 'surface_temperature_celcius': 38}
# {'_id': ObjectId('628a4077c40eee0972358207'), 'latitude': -37.3359, 'longitude': 149.3816, 'confidence': 51, 'surface_temperature_celcius': 48}
# {'_id': ObjectId('628a4077c40eee097235824d'), 'latitude': -37.8177, 'longitude': 142.9168, 'confidence': 51, 'surface_temperature_celcius': 50}
# {'_id': ObjectId('628a4077c40eee0972358389'), 'latitude': -37.561, 'longitude': 143.24200000000002, 'confidence': 51, 'surface_temperature_celcius': 38}
# {'_id': ObjectId('628a4077c40eee097235838c'), 'latitude': -34.2568, 'longitude': 141.64, 'confidence': 51, 'surface_temperature_celcius': 42}
# {'_id': ObjectId('628a4077c40eee0972358406'), 'latitude': -37.001999999999995, 'longitude': 148.2055, 'confidence': 51, 'surface_temperature_celcius': 44}
# {'_id': ObjectId('628a4077c40eee09723579e6'), 'latitude': -37.635, 'longitude': 149.303, 'confidence': 52, 'surface_temperature_celcius': 47}
# {'_id': ObjectId('628a4077c40eee0972357a08'), 'latitude': -34.282, 'longitude': 142.121, 'confidence': 52, 'surface_temperature_celcius': 54}
# {'_id': ObjectId('628a4077c40eee0972357b1e'), 'latitude': -36.0279, 'longitude': 146.0244, 'confidence': 52, 'surface_temperature_celcius': 38}
# {'_id': ObjectId('628a4077c40eee0972357b4c'), 'latitude': -37.6198, 'longitude': 143.0357, 'confidence': 52, 'surface_temperature_celcius': 38}
# {'_id': ObjectId('628a4077c40eee0972357bac'), 'latitude': -36.5646, 'longitude': 142.3068, 'confidence': 52, 'surface_temperature_celcius': 48}
# {'_id': ObjectId('628a4077c40eee0972357be0'), 'latitude': -34.9917, 'longitude': 141.8885, 'confidence': 52, 'surface_temperature_celcius': 49}
# {'_id': ObjectId('628a4077c40eee0972357c82'), 'latitude': -37.3025, 'longitude': 143.4635, 'confidence': 52, 'surface_temperature_celcius': 39}
# {'_id': ObjectId('628a4077c40eee0972357c83'), 'latitude': -37.3009, 'longitude': 143.4777, 'confidence': 52, 'surface_temperature_celcius': 39}
# {'_id': ObjectId('628a4077c40eee0972357c9d'), 'latitude': -37.597, 'longitude': 143.0741, 'confidence': 52, 'surface_temperature_celcius': 38}
# {'_id': ObjectId('628a4077c40eee0972357ce4'), 'latitude': -36.2542, 'longitude': 143.6256, 'confidence': 52, 'surface_temperature_celcius': 38}
# {'_id': ObjectId('628a4077c40eee0972357d0e'), 'latitude': -36.5177, 'longitude': 144.5711, 'confidence': 52, 'surface_temperature_celcius': 40}
# {'_id': ObjectId('628a4077c40eee0972357d70'), 'latitude': -36.8261, 'longitude': 141.4747, 'confidence': 52, 'surface_temperature_celcius': 38}
# {'_id': ObjectId('628a4077c40eee0972357d94'), 'latitude': -36.1961, 'longitude': 141.6376, 'confidence': 52, 'surface_temperature_celcius': 38}
# {'_id': ObjectId('628a4077c40eee0972357e2b'), 'latitude': -38.0771, 'longitude': 144.2044, 'confidence': 52, 'surface_temperature_celcius': 38}
# {'_id': ObjectId('628a4077c40eee0972357e8e'), 'latitude': -36.1021, 'longitude': 146.6853, 'confidence': 52, 'surface_temperature_celcius': 42}
# {'_id': ObjectId('628a4077c40eee0972357efc'), 'latitude': -37.8375, 'longitude': 143.4153, 'confidence': 52, 'surface_temperature_celcius': 39}
# {'_id': ObjectId('628a4077c40eee0972357f32'), 'latitude': -36.742, 'longitude': 144.8955, 'confidence': 52, 'surface_temperature_celcius': 38}
# {'_id': ObjectId('628a4077c40eee0972357fcd'), 'latitude': -37.3723, 'longitude': 143.8406, 'confidence': 52, 'surface_temperature_celcius': 42}
# {'_id': ObjectId('628a4077c40eee0972357fee'), 'latitude': -36.3489, 'longitude': 145.3342, 'confidence': 52, 'surface_temperature_celcius': 38}
# {'_id': ObjectId('628a4077c40eee0972358049'), 'latitude': -37.7851, 'longitude': 141.4593, 'confidence': 52, 'surface_temperature_celcius': 38}
# {'_id': ObjectId('628a4077c40eee097235827c'), 'latitude': -36.4133, 'longitude': 141.0286, 'confidence': 52, 'surface_temperature_celcius': 47}
# {'_id': ObjectId('628a4077c40eee0972358298'), 'latitude': -38.0942, 'longitude': 146.9603, 'confidence': 52, 'surface_temperature_celcius': 39}
# {'_id': ObjectId('628a4077c40eee0972358350'), 'latitude': -37.313, 'longitude': 146.1561, 'confidence': 52, 'surface_temperature_celcius': 46}
# {'_id': ObjectId('628a4077c40eee097235835d'), 'latitude': -37.0484, 'longitude': 141.6245, 'confidence': 52, 'surface_temperature_celcius': 42}
# {'_id': ObjectId('628a4077c40eee0972358387'), 'latitude': -36.7134, 'longitude': 145.2151, 'confidence': 52, 'surface_temperature_celcius': 38}
# {'_id': ObjectId('628a4077c40eee0972358404'), 'latitude': -37.4075, 'longitude': 147.0233, 'confidence': 52, 'surface_temperature_celcius': 43}
# {'_id': ObjectId('628a4077c40eee0972358414'), 'latitude': -37.0316, 'longitude': 148.1519, 'confidence': 52, 'surface_temperature_celcius': 35}
# {'_id': ObjectId('628a4077c40eee09723579d3'), 'latitude': -37.63, 'longitude': 149.335, 'confidence': 53, 'surface_temperature_celcius': 57}
# {'_id': ObjectId('628a4077c40eee09723579da'), 'latitude': -37.903, 'longitude': 145.25, 'confidence': 53, 'surface_temperature_celcius': 44}
# {'_id': ObjectId('628a4077c40eee0972357a05'), 'latitude': -37.611, 'longitude': 149.27700000000002, 'confidence': 53, 'surface_temperature_celcius': 38}
# {'_id': ObjectId('628a4077c40eee0972357af7'), 'latitude': -37.062, 'longitude': 141.373, 'confidence': 53, 'surface_temperature_celcius': 29}
# {'_id': ObjectId('628a4077c40eee0972357af8'), 'latitude': -37.062, 'longitude': 141.373, 'confidence': 53, 'surface_temperature_celcius': 29}
# {'_id': ObjectId('628a4077c40eee0972357b09'), 'latitude': -37.8387, 'longitude': 144.6301, 'confidence': 53, 'surface_temperature_celcius': 39}
# {'_id': ObjectId('628a4077c40eee0972357b1a'), 'latitude': -36.5794, 'longitude': 142.5959, 'confidence': 53, 'surface_temperature_celcius': 39}
# {'_id': ObjectId('628a4077c40eee0972357b53'), 'latitude': -36.7842, 'longitude': 146.9658, 'confidence': 53, 'surface_temperature_celcius': 39}
# {'_id': ObjectId('628a4077c40eee0972357b71'), 'latitude': -36.1875, 'longitude': 143.5158, 'confidence': 53, 'surface_temperature_celcius': 39}
# {'_id': ObjectId('628a4077c40eee0972357bf3'), 'latitude': -34.9959, 'longitude': 141.8635, 'confidence': 53, 'surface_temperature_celcius': 49}
# {'_id': ObjectId('628a4077c40eee0972357bf4'), 'latitude': -34.9843, 'longitude': 141.8736, 'confidence': 53, 'surface_temperature_celcius': 48}
# {'_id': ObjectId('628a4077c40eee0972357c7b'), 'latitude': -37.2549, 'longitude': 142.7719, 'confidence': 53, 'surface_temperature_celcius': 38}
# {'_id': ObjectId('628a4077c40eee0972357cab'), 'latitude': -36.2761, 'longitude': 145.8256, 'confidence': 53, 'surface_temperature_celcius': 43}
# {'_id': ObjectId('628a4077c40eee0972357cea'), 'latitude': -36.3596, 'longitude': 141.0646, 'confidence': 53, 'surface_temperature_celcius': 38}
# {'_id': ObjectId('628a4077c40eee0972357d2e'), 'latitude': -36.3268, 'longitude': 142.3643, 'confidence': 53, 'surface_temperature_celcius': 38}
# {'_id': ObjectId('628a4077c40eee0972357d6a'), 'latitude': -37.6456, 'longitude': 142.6646, 'confidence': 53, 'surface_temperature_celcius': 39}
# {'_id': ObjectId('628a4077c40eee0972357faa'), 'latitude': -37.7504, 'longitude': 142.1373, 'confidence': 53, 'surface_temperature_celcius': 39}
# {'_id': ObjectId('628a4077c40eee09723580cb'), 'latitude': -37.7982, 'longitude': 142.2386, 'confidence': 53, 'surface_temperature_celcius': 41}
# {'_id': ObjectId('628a4077c40eee097235814a'), 'latitude': -37.9422, 'longitude': 143.6199, 'confidence': 53, 'surface_temperature_celcius': 39}
# {'_id': ObjectId('628a4077c40eee09723581d2'), 'latitude': -36.3499, 'longitude': 146.1402, 'confidence': 53, 'surface_temperature_celcius': 41}
# {'_id': ObjectId('628a4077c40eee0972358302'), 'latitude': -36.1439, 'longitude': 145.832, 'confidence': 53, 'surface_temperature_celcius': 50}
# {'_id': ObjectId('628a4077c40eee0972358313'), 'latitude': -36.3539, 'longitude': 142.1894, 'confidence': 53, 'surface_temperature_celcius': 53}
# {'_id': ObjectId('628a4077c40eee09723583a0'), 'latitude': -37.6195, 'longitude': 143.4212, 'confidence': 53, 'surface_temperature_celcius': 46}
# {'_id': ObjectId('628a4077c40eee09723583ed'), 'latitude': -37.9184, 'longitude': 143.4745, 'confidence': 53, 'surface_temperature_celcius': 55}
# {'_id': ObjectId('628a4077c40eee0972357a77'), 'latitude': -37.227, 'longitude': 141.14600000000002, 'confidence': 54, 'surface_temperature_celcius': 31}
# {'_id': ObjectId('628a4077c40eee0972357ad5'), 'latitude': -34.848, 'longitude': 141.5002, 'confidence': 54, 'surface_temperature_celcius': 41}
# {'_id': ObjectId('628a4077c40eee0972357ae1'), 'latitude': -37.491, 'longitude': 141.936, 'confidence': 54, 'surface_temperature_celcius': 40}
# {'_id': ObjectId('628a4077c40eee0972357b2b'), 'latitude': -36.4422, 'longitude': 141.42700000000002, 'confidence': 54, 'surface_temperature_celcius': 39}
# {'_id': ObjectId('628a4077c40eee0972357c10'), 'latitude': -36.7321, 'longitude': 143.1978, 'confidence': 54, 'surface_temperature_celcius': 46}
# {'_id': ObjectId('628a4077c40eee0972357c22'), 'latitude': -35.4173, 'longitude': 143.2041, 'confidence': 54, 'surface_temperature_celcius': 39}
# {'_id': ObjectId('628a4077c40eee0972357c25'), 'latitude': -36.3909, 'longitude': 141.1843, 'confidence': 54, 'surface_temperature_celcius': 39}
# {'_id': ObjectId('628a4077c40eee0972357c92'), 'latitude': -37.459, 'longitude': 142.9198, 'confidence': 54, 'surface_temperature_celcius': 39}
# {'_id': ObjectId('628a4077c40eee0972357cf5'), 'latitude': -36.2966, 'longitude': 141.1662, 'confidence': 54, 'surface_temperature_celcius': 39}
# {'_id': ObjectId('628a4077c40eee0972357d4b'), 'latitude': -36.3278, 'longitude': 141.082, 'confidence': 54, 'surface_temperature_celcius': 39}
# {'_id': ObjectId('628a4077c40eee0972357d5c'), 'latitude': -37.0434, 'longitude': 142.001, 'confidence': 54, 'surface_temperature_celcius': 41}
# {'_id': ObjectId('628a4077c40eee0972357d69'), 'latitude': -36.055, 'longitude': 144.605, 'confidence': 54, 'surface_temperature_celcius': 39}
# {'_id': ObjectId('628a4077c40eee0972357d86'), 'latitude': -36.3051, 'longitude': 143.1445, 'confidence': 54, 'surface_temperature_celcius': 39}
# {'_id': ObjectId('628a4077c40eee0972357de2'), 'latitude': -36.7063, 'longitude': 142.0025, 'confidence': 54, 'surface_temperature_celcius': 39}
# {'_id': ObjectId('628a4077c40eee0972357e1e'), 'latitude': -36.6363, 'longitude': 144.3033, 'confidence': 54, 'surface_temperature_celcius': 40}
# {'_id': ObjectId('628a4077c40eee0972357eaf'), 'latitude': -37.8084, 'longitude': 143.1985, 'confidence': 54, 'surface_temperature_celcius': 46}
# {'_id': ObjectId('628a4077c40eee0972357f2a'), 'latitude': -37.4984, 'longitude': 142.0686, 'confidence': 54, 'surface_temperature_celcius': 40}
# {'_id': ObjectId('628a4077c40eee0972357f35'), 'latitude': -36.9139, 'longitude': 143.9765, 'confidence': 54, 'surface_temperature_celcius': 42}
# {'_id': ObjectId('628a4077c40eee0972357f8c'), 'latitude': -35.9498, 'longitude': 145.6229, 'confidence': 54, 'surface_temperature_celcius': 41}
# {'_id': ObjectId('628a4077c40eee0972358164'), 'latitude': -35.7608, 'longitude': 143.3545, 'confidence': 54, 'surface_temperature_celcius': 47}
# {'_id': ObjectId('628a4077c40eee0972358192'), 'latitude': -36.7453, 'longitude': 141.4578, 'confidence': 54, 'surface_temperature_celcius': 39}
# {'_id': ObjectId('628a4077c40eee09723582f1'), 'latitude': -38.4879, 'longitude': 143.9971, 'confidence': 54, 'surface_temperature_celcius': 40}
# {'_id': ObjectId('628a4077c40eee0972358309'), 'latitude': -36.7009, 'longitude': 141.541, 'confidence': 54, 'surface_temperature_celcius': 49}
# {'_id': ObjectId('628a4077c40eee0972358420'), 'latitude': -37.2197, 'longitude': 147.9621, 'confidence': 54, 'surface_temperature_celcius': 43}
# {'_id': ObjectId('628a4077c40eee0972358423'), 'latitude': -37.7171, 'longitude': 147.5866, 'confidence': 54, 'surface_temperature_celcius': 44}
# {'_id': ObjectId('628a4077c40eee0972357b0e'), 'latitude': -36.3769, 'longitude': 144.7505, 'confidence': 55, 'surface_temperature_celcius': 39}
# {'_id': ObjectId('628a4077c40eee0972357b17'), 'latitude': -36.1858, 'longitude': 143.885, 'confidence': 55, 'surface_temperature_celcius': 39}
# {'_id': ObjectId('628a4077c40eee0972357b6d'), 'latitude': -37.164, 'longitude': 148.915, 'confidence': 55, 'surface_temperature_celcius': 42}
# {'_id': ObjectId('628a4077c40eee0972357b7e'), 'latitude': -37.2622, 'longitude': 144.3704, 'confidence': 55, 'surface_temperature_celcius': 39}
# {'_id': ObjectId('628a4077c40eee0972357b8d'), 'latitude': -36.6217, 'longitude': 142.0944, 'confidence': 55, 'surface_temperature_celcius': 39}
# {'_id': ObjectId('628a4077c40eee0972357c0a'), 'latitude': -36.591, 'longitude': 141.7194, 'confidence': 55, 'surface_temperature_celcius': 40}
# {'_id': ObjectId('628a4077c40eee0972357c35'), 'latitude': -36.2359, 'longitude': 141.3007, 'confidence': 55, 'surface_temperature_celcius': 41}
# {'_id': ObjectId('628a4077c40eee0972357c76'), 'latitude': -36.5886, 'longitude': 142.8549, 'confidence': 55, 'surface_temperature_celcius': 39}
# {'_id': ObjectId('628a4077c40eee0972357c77'), 'latitude': -36.9748, 'longitude': 143.9369, 'confidence': 55, 'surface_temperature_celcius': 39}
# {'_id': ObjectId('628a4077c40eee0972357cac'), 'latitude': -38.3849, 'longitude': 146.6745, 'confidence': 55, 'surface_temperature_celcius': 39}
# {'_id': ObjectId('628a4077c40eee0972357d2f'), 'latitude': -36.766999999999996, 'longitude': 142.6811, 'confidence': 55, 'surface_temperature_celcius': 39}
# {'_id': ObjectId('628a4077c40eee0972357d32'), 'latitude': -36.3489, 'longitude': 141.4916, 'confidence': 55, 'surface_temperature_celcius': 39}
# {'_id': ObjectId('628a4077c40eee0972357dba'), 'latitude': -36.2476, 'longitude': 147.5281, 'confidence': 55, 'surface_temperature_celcius': 39}
# {'_id': ObjectId('628a4077c40eee0972357dcc'), 'latitude': -36.2929, 'longitude': 142.9282, 'confidence': 55, 'surface_temperature_celcius': 39}
# {'_id': ObjectId('628a4077c40eee0972357dec'), 'latitude': -37.2142, 'longitude': 148.822, 'confidence': 55, 'surface_temperature_celcius': 39}
# {'_id': ObjectId('628a4077c40eee0972357e65'), 'latitude': -37.579, 'longitude': 144.1483, 'confidence': 55, 'surface_temperature_celcius': 39}
# {'_id': ObjectId('628a4077c40eee0972357faf'), 'latitude': -37.9378, 'longitude': 142.541, 'confidence': 55, 'surface_temperature_celcius': 39}
# {'_id': ObjectId('628a4077c40eee0972357fbf'), 'latitude': -37.2904, 'longitude': 143.9209, 'confidence': 55, 'surface_temperature_celcius': 39}
# {'_id': ObjectId('628a4077c40eee0972357fce'), 'latitude': -36.7001, 'longitude': 141.7567, 'confidence': 55, 'surface_temperature_celcius': 39}
# {'_id': ObjectId('628a4077c40eee09723581de'), 'latitude': -36.4606, 'longitude': 141.0562, 'confidence': 55, 'surface_temperature_celcius': 39}
# {'_id': ObjectId('628a4077c40eee0972358310'), 'latitude': -36.4611, 'longitude': 143.14600000000002, 'confidence': 55, 'surface_temperature_celcius': 48}
# {'_id': ObjectId('628a4077c40eee09723583c3'), 'latitude': -34.342, 'longitude': 141.6548, 'confidence': 55, 'surface_temperature_celcius': 54}
# {'_id': ObjectId('628a4077c40eee09723583e3'), 'latitude': -37.1684, 'longitude': 142.8183, 'confidence': 55, 'surface_temperature_celcius': 48}
# {'_id': ObjectId('628a4077c40eee097235841f'), 'latitude': -36.2544, 'longitude': 148.0353, 'confidence': 55, 'surface_temperature_celcius': 42}
# {'_id': ObjectId('628a4077c40eee09723579e5'), 'latitude': -36.291, 'longitude': 146.159, 'confidence': 56, 'surface_temperature_celcius': 40}
# {'_id': ObjectId('628a4077c40eee0972357a20'), 'latitude': -38.912, 'longitude': 146.27200000000002, 'confidence': 56, 'surface_temperature_celcius': 48}
# {'_id': ObjectId('628a4077c40eee0972357aac'), 'latitude': -38.495, 'longitude': 146.944, 'confidence': 56, 'surface_temperature_celcius': 53}
# {'_id': ObjectId('628a4077c40eee0972357aaf'), 'latitude': -37.559, 'longitude': 148.037, 'confidence': 56, 'surface_temperature_celcius': 41}
# {'_id': ObjectId('628a4077c40eee0972357ac1'), 'latitude': -36.995, 'longitude': 148.268, 'confidence': 56, 'surface_temperature_celcius': 37}
# {'_id': ObjectId('628a4077c40eee0972357ad0'), 'latitude': -37.4421, 'longitude': 148.259, 'confidence': 56, 'surface_temperature_celcius': 39}
# {'_id': ObjectId('628a4077c40eee0972357b42'), 'latitude': -36.575, 'longitude': 146.6668, 'confidence': 56, 'surface_temperature_celcius': 40}
# {'_id': ObjectId('628a4077c40eee0972357b72'), 'latitude': -36.1887, 'longitude': 143.4722, 'confidence': 56, 'surface_temperature_celcius': 39}
# {'_id': ObjectId('628a4077c40eee0972357b8f'), 'latitude': -36.8241, 'longitude': 145.1274, 'confidence': 56, 'surface_temperature_celcius': 39}
# {'_id': ObjectId('628a4077c40eee0972357ba9'), 'latitude': -36.4226, 'longitude': 143.0946, 'confidence': 56, 'surface_temperature_celcius': 39}
# {'_id': ObjectId('628a4077c40eee0972357be4'), 'latitude': -36.3883, 'longitude': 143.7526, 'confidence': 56, 'surface_temperature_celcius': 39}
# {'_id': ObjectId('628a4077c40eee0972357c48'), 'latitude': -37.5263, 'longitude': 143.0882, 'confidence': 56, 'surface_temperature_celcius': 53}
# {'_id': ObjectId('628a4077c40eee0972357c4d'), 'latitude': -37.7461, 'longitude': 142.7369, 'confidence': 56, 'surface_temperature_celcius': 39}
# {'_id': ObjectId('628a4077c40eee0972357cf1'), 'latitude': -37.785, 'longitude': 143.092, 'confidence': 56, 'surface_temperature_celcius': 41}
# {'_id': ObjectId('628a4077c40eee0972357d40'), 'latitude': -36.2218, 'longitude': 141.3385, 'confidence': 56, 'surface_temperature_celcius': 39}
# {'_id': ObjectId('628a4077c40eee0972357d72'), 'latitude': -36.228, 'longitude': 144.6721, 'confidence': 56, 'surface_temperature_celcius': 39}
# {'_id': ObjectId('628a4077c40eee0972357db8'), 'latitude': -36.7501, 'longitude': 142.8867, 'confidence': 56, 'surface_temperature_celcius': 49}
# {'_id': ObjectId('628a4077c40eee0972357de0'), 'latitude': -36.5511, 'longitude': 146.7819, 'confidence': 56, 'surface_temperature_celcius': 34}
# {'_id': ObjectId('628a4077c40eee0972357eb4'), 'latitude': -36.4147, 'longitude': 141.0669, 'confidence': 56, 'surface_temperature_celcius': 39}
# {'_id': ObjectId('628a4077c40eee0972357ed2'), 'latitude': -37.9373, 'longitude': 146.0744, 'confidence': 56, 'surface_temperature_celcius': 39}
# {'_id': ObjectId('628a4077c40eee0972357ed4'), 'latitude': -38.2234, 'longitude': 143.9549, 'confidence': 56, 'surface_temperature_celcius': 39}
# {'_id': ObjectId('628a4077c40eee0972357ed5'), 'latitude': -38.1539, 'longitude': 144.1343, 'confidence': 56, 'surface_temperature_celcius': 44}
# {'_id': ObjectId('628a4077c40eee0972357f62'), 'latitude': -36.7564, 'longitude': 142.343, 'confidence': 56, 'surface_temperature_celcius': 41}
# {'_id': ObjectId('628a4077c40eee0972357fa1'), 'latitude': -37.0685, 'longitude': 145.35399999999998, 'confidence': 56, 'surface_temperature_celcius': 39}
# {'_id': ObjectId('628a4077c40eee09723581c7'), 'latitude': -36.6776, 'longitude': 141.0877, 'confidence': 56, 'surface_temperature_celcius': 44}
# {'_id': ObjectId('628a4077c40eee09723581d6'), 'latitude': -36.4439, 'longitude': 145.8846, 'confidence': 56, 'surface_temperature_celcius': 39}
# {'_id': ObjectId('628a4077c40eee09723581ec'), 'latitude': -37.4368, 'longitude': 149.1191, 'confidence': 56, 'surface_temperature_celcius': 52}
# {'_id': ObjectId('628a4077c40eee0972358351'), 'latitude': -38.0226, 'longitude': 143.6739, 'confidence': 56, 'surface_temperature_celcius': 39}
# {'_id': ObjectId('628a4077c40eee0972358356'), 'latitude': -37.8089, 'longitude': 145.9555, 'confidence': 56, 'surface_temperature_celcius': 41}
# {'_id': ObjectId('628a4077c40eee097235838a'), 'latitude': -37.982, 'longitude': 143.6422, 'confidence': 56, 'surface_temperature_celcius': 42}
# {'_id': ObjectId('628a4077c40eee0972358413'), 'latitude': -37.0286, 'longitude': 148.155, 'confidence': 56, 'surface_temperature_celcius': 42}
# {'_id': ObjectId('628a4077c40eee0972357aee'), 'latitude': -37.8067, 'longitude': 141.7598, 'confidence': 57, 'surface_temperature_celcius': 40}
# {'_id': ObjectId('628a4077c40eee0972357b9f'), 'latitude': -35.6785, 'longitude': 143.5077, 'confidence': 57, 'surface_temperature_celcius': 39}
# {'_id': ObjectId('628a4077c40eee0972357c02'), 'latitude': -36.8399, 'longitude': 142.6291, 'confidence': 57, 'surface_temperature_celcius': 39}
# {'_id': ObjectId('628a4077c40eee0972357c45'), 'latitude': -37.3317, 'longitude': 143.822, 'confidence': 57, 'surface_temperature_celcius': 41}
# {'_id': ObjectId('628a4077c40eee0972357c46'), 'latitude': -36.6329, 'longitude': 142.9903, 'confidence': 57, 'surface_temperature_celcius': 43}
# {'_id': ObjectId('628a4077c40eee0972357c8a'), 'latitude': -36.2341, 'longitude': 141.3188, 'confidence': 57, 'surface_temperature_celcius': 41}
# {'_id': ObjectId('628a4077c40eee0972357ca3'), 'latitude': -36.6519, 'longitude': 142.8362, 'confidence': 57, 'surface_temperature_celcius': 39}
# {'_id': ObjectId('628a4077c40eee0972357cd2'), 'latitude': -36.2961, 'longitude': 144.861, 'confidence': 57, 'surface_temperature_celcius': 39}
# {'_id': ObjectId('628a4077c40eee0972357ce2'), 'latitude': -35.9839, 'longitude': 143.6719, 'confidence': 57, 'surface_temperature_celcius': 47}
# {'_id': ObjectId('628a4077c40eee0972357d6b'), 'latitude': -37.5334, 'longitude': 143.0587, 'confidence': 57, 'surface_temperature_celcius': 41}
# {'_id': ObjectId('628a4077c40eee0972357d85'), 'latitude': -36.3753, 'longitude': 146.6914, 'confidence': 57, 'surface_temperature_celcius': 40}
# {'_id': ObjectId('628a4077c40eee0972357e35'), 'latitude': -35.9326, 'longitude': 143.9772, 'confidence': 57, 'surface_temperature_celcius': 42}
# {'_id': ObjectId('628a4077c40eee0972357e45'), 'latitude': -36.9733, 'longitude': 146.0788, 'confidence': 57, 'surface_temperature_celcius': 40}
# {'_id': ObjectId('628a4077c40eee0972357e80'), 'latitude': -36.925, 'longitude': 143.9798, 'confidence': 57, 'surface_temperature_celcius': 41}
# {'_id': ObjectId('628a4077c40eee0972357ea1'), 'latitude': -37.4903, 'longitude': 143.5786, 'confidence': 57, 'surface_temperature_celcius': 40}
# {'_id': ObjectId('628a4077c40eee0972357efd'), 'latitude': -37.8635, 'longitude': 143.1986, 'confidence': 57, 'surface_temperature_celcius': 39}
# {'_id': ObjectId('628a4077c40eee0972357f0d'), 'latitude': -37.7129, 'longitude': 143.0307, 'confidence': 57, 'surface_temperature_celcius': 39}
# {'_id': ObjectId('628a4077c40eee0972357f14'), 'latitude': -37.6345, 'longitude': 143.1335, 'confidence': 57, 'surface_temperature_celcius': 39}
# {'_id': ObjectId('628a4077c40eee0972358046'), 'latitude': -38.0505, 'longitude': 142.4791, 'confidence': 57, 'surface_temperature_celcius': 40}
# {'_id': ObjectId('628a4077c40eee0972358079'), 'latitude': -38.0643, 'longitude': 143.6616, 'confidence': 57, 'surface_temperature_celcius': 43}
# {'_id': ObjectId('628a4077c40eee0972358127'), 'latitude': -37.5389, 'longitude': 143.1632, 'confidence': 57, 'surface_temperature_celcius': 53}
# {'_id': ObjectId('628a4077c40eee0972358158'), 'latitude': -38.2093, 'longitude': 143.9237, 'confidence': 57, 'surface_temperature_celcius': 40}
# {'_id': ObjectId('628a4077c40eee097235818d'), 'latitude': -35.4407, 'longitude': 142.3644, 'confidence': 57, 'surface_temperature_celcius': 35}
# {'_id': ObjectId('628a4077c40eee09723581b8'), 'latitude': -36.9142, 'longitude': 141.3013, 'confidence': 57, 'surface_temperature_celcius': 40}
# {'_id': ObjectId('628a4077c40eee09723581d7'), 'latitude': -36.0818, 'longitude': 146.5461, 'confidence': 57, 'surface_temperature_celcius': 44}
# {'_id': ObjectId('628a4077c40eee0972358286'), 'latitude': -36.0799, 'longitude': 146.529, 'confidence': 57, 'surface_temperature_celcius': 44}
# {'_id': ObjectId('628a4077c40eee097235836a'), 'latitude': -34.2614, 'longitude': 141.6412, 'confidence': 57, 'surface_temperature_celcius': 43}
# {'_id': ObjectId('628a4077c40eee0972358375'), 'latitude': -36.5245, 'longitude': 143.1556, 'confidence': 57, 'surface_temperature_celcius': 43}
# {'_id': ObjectId('628a4077c40eee09723583e1'), 'latitude': -37.9022, 'longitude': 143.4607, 'confidence': 57, 'surface_temperature_celcius': 57}
# {'_id': ObjectId('628a4077c40eee0972357a1f'), 'latitude': -37.864000000000004, 'longitude': 144.174, 'confidence': 58, 'surface_temperature_celcius': 41}
# {'_id': ObjectId('628a4077c40eee0972357a53'), 'latitude': -37.586999999999996, 'longitude': 142.47899999999998, 'confidence': 58, 'surface_temperature_celcius': 41}
# {'_id': ObjectId('628a4077c40eee0972357aa3'), 'latitude': -37.397, 'longitude': 148.121, 'confidence': 58, 'surface_temperature_celcius': 58}
# {'_id': ObjectId('628a4077c40eee0972357ab0'), 'latitude': -37.379, 'longitude': 148.126, 'confidence': 58, 'surface_temperature_celcius': 82}
# {'_id': ObjectId('628a4077c40eee0972357ad4'), 'latitude': -37.7836, 'longitude': 143.9688, 'confidence': 58, 'surface_temperature_celcius': 40}
# {'_id': ObjectId('628a4077c40eee0972357b27'), 'latitude': -37.4661, 'longitude': 143.2419, 'confidence': 58, 'surface_temperature_celcius': 40}
# {'_id': ObjectId('628a4077c40eee0972357b4e'), 'latitude': -37.4857, 'longitude': 143.5322, 'confidence': 58, 'surface_temperature_celcius': 40}
# {'_id': ObjectId('628a4077c40eee0972357b60'), 'latitude': -37.7379, 'longitude': 143.1706, 'confidence': 58, 'surface_temperature_celcius': 40}
# {'_id': ObjectId('628a4077c40eee0972357c2b'), 'latitude': -36.4713, 'longitude': 144.4747, 'confidence': 58, 'surface_temperature_celcius': 40}
# {'_id': ObjectId('628a4077c40eee0972357c80'), 'latitude': -36.4944, 'longitude': 141.8992, 'confidence': 58, 'surface_temperature_celcius': 40}
# {'_id': ObjectId('628a4077c40eee0972357ca4'), 'latitude': -36.2635, 'longitude': 141.1145, 'confidence': 58, 'surface_temperature_celcius': 40}
# {'_id': ObjectId('628a4077c40eee0972357cdc'), 'latitude': -36.4251, 'longitude': 142.2216, 'confidence': 58, 'surface_temperature_celcius': 40}
# {'_id': ObjectId('628a4077c40eee0972357d2a'), 'latitude': -36.3815, 'longitude': 143.8529, 'confidence': 58, 'surface_temperature_celcius': 45}
# {'_id': ObjectId('628a4077c40eee0972357d9f'), 'latitude': -35.4619, 'longitude': 143.5251, 'confidence': 58, 'surface_temperature_celcius': 40}
# {'_id': ObjectId('628a4077c40eee0972357dc2'), 'latitude': -38.1913, 'longitude': 147.0894, 'confidence': 58, 'surface_temperature_celcius': 40}
# {'_id': ObjectId('628a4077c40eee0972357df8'), 'latitude': -36.4188, 'longitude': 141.0484, 'confidence': 58, 'surface_temperature_celcius': 40}
# {'_id': ObjectId('628a4077c40eee0972357e3d'), 'latitude': -37.6841, 'longitude': 147.5667, 'confidence': 58, 'surface_temperature_celcius': 40}
# {'_id': ObjectId('628a4077c40eee0972357e5b'), 'latitude': -37.7893, 'longitude': 142.7953, 'confidence': 58, 'surface_temperature_celcius': 40}
# {'_id': ObjectId('628a4077c40eee0972357f05'), 'latitude': -37.5816, 'longitude': 144.1369, 'confidence': 58, 'surface_temperature_celcius': 40}
# {'_id': ObjectId('628a4077c40eee0972357f3b'), 'latitude': -36.9203, 'longitude': 143.4581, 'confidence': 58, 'surface_temperature_celcius': 40}
# {'_id': ObjectId('628a4077c40eee0972357f7a'), 'latitude': -36.2692, 'longitude': 141.0705, 'confidence': 58, 'surface_temperature_celcius': 40}
# {'_id': ObjectId('628a4077c40eee0972357f8f'), 'latitude': -37.6069, 'longitude': 141.4724, 'confidence': 58, 'surface_temperature_celcius': 40}
# {'_id': ObjectId('628a4077c40eee0972357fa6'), 'latitude': -36.4437, 'longitude': 141.5916, 'confidence': 58, 'surface_temperature_celcius': 45}
# {'_id': ObjectId('628a4077c40eee0972357fb0'), 'latitude': -36.0434, 'longitude': 143.1899, 'confidence': 58, 'surface_temperature_celcius': 40}
# {'_id': ObjectId('628a4077c40eee0972357fc0'), 'latitude': -37.0459, 'longitude': 142.7207, 'confidence': 58, 'surface_temperature_celcius': 40}
# {'_id': ObjectId('628a4077c40eee09723580c5'), 'latitude': -38.26, 'longitude': 143.9602, 'confidence': 58, 'surface_temperature_celcius': 40}
# {'_id': ObjectId('628a4077c40eee0972358185'), 'latitude': -35.2432, 'longitude': 143.4496, 'confidence': 58, 'surface_temperature_celcius': 44}
# {'_id': ObjectId('628a4077c40eee09723581f0'), 'latitude': -37.9408, 'longitude': 146.0611, 'confidence': 58, 'surface_temperature_celcius': 47}
# {'_id': ObjectId('628a4077c40eee097235825d'), 'latitude': -37.3072, 'longitude': 147.5003, 'confidence': 58, 'surface_temperature_celcius': 46}
# {'_id': ObjectId('628a4077c40eee097235826f'), 'latitude': -37.7212, 'longitude': 145.9754, 'confidence': 58, 'surface_temperature_celcius': 52}
# {'_id': ObjectId('628a4077c40eee0972358374'), 'latitude': -36.2044, 'longitude': 145.7706, 'confidence': 58, 'surface_temperature_celcius': 51}
# {'_id': ObjectId('628a4077c40eee09723583e5'), 'latitude': -37.9164, 'longitude': 143.4866, 'confidence': 58, 'surface_temperature_celcius': 54}
# {'_id': ObjectId('628a4077c40eee09723579cb'), 'latitude': -37.644, 'longitude': 149.346, 'confidence': 59, 'surface_temperature_celcius': 55}
# {'_id': ObjectId('628a4077c40eee0972357a69'), 'latitude': -37.227, 'longitude': 141.151, 'confidence': 59, 'surface_temperature_celcius': 35}
# {'_id': ObjectId('628a4077c40eee0972357a79'), 'latitude': -37.475, 'longitude': 148.134, 'confidence': 59, 'surface_temperature_celcius': 40}
# {'_id': ObjectId('628a4077c40eee0972357a9d'), 'latitude': -37.375, 'longitude': 148.063, 'confidence': 59, 'surface_temperature_celcius': 35}
# {'_id': ObjectId('628a4077c40eee0972357adf'), 'latitude': -37.8519, 'longitude': 147.2555, 'confidence': 59, 'surface_temperature_celcius': 40}
# {'_id': ObjectId('628a4077c40eee0972357b2c'), 'latitude': -36.251, 'longitude': 142.5651, 'confidence': 59, 'surface_temperature_celcius': 40}
# {'_id': ObjectId('628a4077c40eee0972357b41'), 'latitude': -36.6859, 'longitude': 146.8907, 'confidence': 59, 'surface_temperature_celcius': 40}
# {'_id': ObjectId('628a4077c40eee0972357b4a'), 'latitude': -36.7889, 'longitude': 146.6495, 'confidence': 59, 'surface_temperature_celcius': 49}
# {'_id': ObjectId('628a4077c40eee0972357b76'), 'latitude': -36.3987, 'longitude': 142.6332, 'confidence': 59, 'surface_temperature_celcius': 40}
# {'_id': ObjectId('628a4077c40eee0972357bbd'), 'latitude': -36.6463, 'longitude': 144.7594, 'confidence': 59, 'surface_temperature_celcius': 41}
# {'_id': ObjectId('628a4077c40eee0972357c09'), 'latitude': -36.304, 'longitude': 143.7445, 'confidence': 59, 'surface_temperature_celcius': 40}
# {'_id': ObjectId('628a4077c40eee0972357c44'), 'latitude': -37.4574, 'longitude': 142.9354, 'confidence': 59, 'surface_temperature_celcius': 40}
# {'_id': ObjectId('628a4077c40eee0972357ca8'), 'latitude': -36.2748, 'longitude': 145.7718, 'confidence': 59, 'surface_temperature_celcius': 40}
# {'_id': ObjectId('628a4077c40eee0972357caf'), 'latitude': -36.4001, 'longitude': 143.1512, 'confidence': 59, 'surface_temperature_celcius': 40}
# {'_id': ObjectId('628a4077c40eee0972357cc7'), 'latitude': -36.1214, 'longitude': 143.7078, 'confidence': 59, 'surface_temperature_celcius': 40}
# {'_id': ObjectId('628a4077c40eee0972357ccd'), 'latitude': -36.3011, 'longitude': 141.5705, 'confidence': 59, 'surface_temperature_celcius': 40}
# {'_id': ObjectId('628a4077c40eee0972357ce0'), 'latitude': -37.5406, 'longitude': 142.9301, 'confidence': 59, 'surface_temperature_celcius': 46}
# {'_id': ObjectId('628a4077c40eee0972357cfe'), 'latitude': -36.7063, 'longitude': 141.8673, 'confidence': 59, 'surface_temperature_celcius': 40}
# {'_id': ObjectId('628a4077c40eee0972357d1c'), 'latitude': -37.6953, 'longitude': 143.0704, 'confidence': 59, 'surface_temperature_celcius': 40}
# {'_id': ObjectId('628a4077c40eee0972357d2d'), 'latitude': -36.3711, 'longitude': 145.8311, 'confidence': 59, 'surface_temperature_celcius': 40}
# {'_id': ObjectId('628a4077c40eee0972357d5a'), 'latitude': -36.4399, 'longitude': 141.0914, 'confidence': 59, 'surface_temperature_celcius': 40}
# {'_id': ObjectId('628a4077c40eee0972357d99'), 'latitude': -36.1603, 'longitude': 141.2905, 'confidence': 59, 'surface_temperature_celcius': 40}
# {'_id': ObjectId('628a4077c40eee0972357ddf'), 'latitude': -36.3235, 'longitude': 145.8568, 'confidence': 59, 'surface_temperature_celcius': 51}
# {'_id': ObjectId('628a4077c40eee0972357df6'), 'latitude': -36.8679, 'longitude': 142.7328, 'confidence': 59, 'surface_temperature_celcius': 40}
# {'_id': ObjectId('628a4077c40eee0972357e02'), 'latitude': -38.4685, 'longitude': 146.673, 'confidence': 59, 'surface_temperature_celcius': 40}
# {'_id': ObjectId('628a4077c40eee0972357e7d'), 'latitude': -35.7866, 'longitude': 143.4796, 'confidence': 59, 'surface_temperature_celcius': 46}
# {'_id': ObjectId('628a4077c40eee0972357e81'), 'latitude': -37.9049, 'longitude': 142.8528, 'confidence': 59, 'surface_temperature_celcius': 47}
# {'_id': ObjectId('628a4077c40eee0972357e8b'), 'latitude': -37.6868, 'longitude': 142.3949, 'confidence': 59, 'surface_temperature_celcius': 40}
# {'_id': ObjectId('628a4077c40eee0972357eec'), 'latitude': -37.9718, 'longitude': 143.2609, 'confidence': 59, 'surface_temperature_celcius': 40}
# {'_id': ObjectId('628a4077c40eee0972357f79'), 'latitude': -36.2517, 'longitude': 141.8756, 'confidence': 59, 'surface_temperature_celcius': 43}
# {'_id': ObjectId('628a4077c40eee0972358003'), 'latitude': -37.1228, 'longitude': 141.7389, 'confidence': 59, 'surface_temperature_celcius': 41}
# {'_id': ObjectId('628a4077c40eee0972358043'), 'latitude': -37.7576, 'longitude': 142.465, 'confidence': 59, 'surface_temperature_celcius': 40}
# {'_id': ObjectId('628a4077c40eee0972358066'), 'latitude': -37.6857, 'longitude': 142.8532, 'confidence': 59, 'surface_temperature_celcius': 40}
# {'_id': ObjectId('628a4077c40eee0972358126'), 'latitude': -37.5077, 'longitude': 143.2495, 'confidence': 59, 'surface_temperature_celcius': 40}
# {'_id': ObjectId('628a4077c40eee0972358135'), 'latitude': -37.5837, 'longitude': 144.1565, 'confidence': 59, 'surface_temperature_celcius': 40}
# {'_id': ObjectId('628a4077c40eee097235819e'), 'latitude': -36.9179, 'longitude': 141.3095, 'confidence': 59, 'surface_temperature_celcius': 40}
# {'_id': ObjectId('628a4077c40eee09723581bf'), 'latitude': -37.3586, 'longitude': 142.9087, 'confidence': 59, 'surface_temperature_celcius': 40}
# {'_id': ObjectId('628a4077c40eee09723581cc'), 'latitude': -37.3656, 'longitude': 143.8206, 'confidence': 59, 'surface_temperature_celcius': 40}
# {'_id': ObjectId('628a4077c40eee09723581f1'), 'latitude': -37.6994, 'longitude': 146.2162, 'confidence': 59, 'surface_temperature_celcius': 40}
# {'_id': ObjectId('628a4077c40eee0972358267'), 'latitude': -37.6806, 'longitude': 143.2676, 'confidence': 59, 'surface_temperature_celcius': 51}
# {'_id': ObjectId('628a4077c40eee0972358270'), 'latitude': -38.3343, 'longitude': 143.8644, 'confidence': 59, 'surface_temperature_celcius': 43}
# {'_id': ObjectId('628a4077c40eee097235828d'), 'latitude': -37.1929, 'longitude': 143.8132, 'confidence': 59, 'surface_temperature_celcius': 45}
# {'_id': ObjectId('628a4077c40eee09723582bd'), 'latitude': -38.0383, 'longitude': 144.4307, 'confidence': 59, 'surface_temperature_celcius': 40}
# {'_id': ObjectId('628a4077c40eee09723583ea'), 'latitude': -37.4023, 'longitude': 147.0394, 'confidence': 59, 'surface_temperature_celcius': 56}
# {'_id': ObjectId('628a4077c40eee09723579d0'), 'latitude': -38.046, 'longitude': 144.201, 'confidence': 60, 'surface_temperature_celcius': 48}
# {'_id': ObjectId('628a4077c40eee09723579fc'), 'latitude': -37.637, 'longitude': 146.28799999999998, 'confidence': 60, 'surface_temperature_celcius': 42}
# {'_id': ObjectId('628a4077c40eee0972357a31'), 'latitude': -36.538000000000004, 'longitude': 141.129, 'confidence': 60, 'surface_temperature_celcius': 43}
# {'_id': ObjectId('628a4077c40eee0972357b3d'), 'latitude': -36.3334, 'longitude': 141.1515, 'confidence': 60, 'surface_temperature_celcius': 41}
# {'_id': ObjectId('628a4077c40eee0972357b89'), 'latitude': -36.4216, 'longitude': 141.2799, 'confidence': 60, 'surface_temperature_celcius': 40}
# {'_id': ObjectId('628a4077c40eee0972357bb6'), 'latitude': -36.6483, 'longitude': 142.4878, 'confidence': 60, 'surface_temperature_celcius': 41}
# {'_id': ObjectId('628a4077c40eee0972357c57'), 'latitude': -38.294000000000004, 'longitude': 143.7227, 'confidence': 60, 'surface_temperature_celcius': 41}
# {'_id': ObjectId('628a4077c40eee0972357c5e'), 'latitude': -37.959, 'longitude': 143.5497, 'confidence': 60, 'surface_temperature_celcius': 40}
# {'_id': ObjectId('628a4077c40eee0972357c8e'), 'latitude': -35.7421, 'longitude': 142.5634, 'confidence': 60, 'surface_temperature_celcius': 40}
# {'_id': ObjectId('628a4077c40eee0972357c91'), 'latitude': -37.4304, 'longitude': 143.1275, 'confidence': 60, 'surface_temperature_celcius': 47}
# {'_id': ObjectId('628a4077c40eee0972357ca1'), 'latitude': -36.2685, 'longitude': 141.0912, 'confidence': 60, 'surface_temperature_celcius': 40}
# {'_id': ObjectId('628a4077c40eee0972357ca7'), 'latitude': -36.0841, 'longitude': 141.1426, 'confidence': 60, 'surface_temperature_celcius': 40}
# {'_id': ObjectId('628a4077c40eee0972357cfa'), 'latitude': -36.5489, 'longitude': 143.1093, 'confidence': 60, 'surface_temperature_celcius': 40}
# {'_id': ObjectId('628a4077c40eee0972357cfd'), 'latitude': -36.4195, 'longitude': 141.2093, 'confidence': 60, 'surface_temperature_celcius': 42}
# {'_id': ObjectId('628a4077c40eee0972357d3c'), 'latitude': -36.7544, 'longitude': 141.5341, 'confidence': 60, 'surface_temperature_celcius': 40}
# {'_id': ObjectId('628a4077c40eee0972357d5e'), 'latitude': -36.0399, 'longitude': 143.6437, 'confidence': 60, 'surface_temperature_celcius': 40}
# {'_id': ObjectId('628a4077c40eee0972357e03'), 'latitude': -36.8922, 'longitude': 145.1252, 'confidence': 60, 'surface_temperature_celcius': 40}
# {'_id': ObjectId('628a4077c40eee0972357e25'), 'latitude': -37.4385, 'longitude': 143.6244, 'confidence': 60, 'surface_temperature_celcius': 44}
# {'_id': ObjectId('628a4077c40eee0972357e37'), 'latitude': -36.2724, 'longitude': 146.4168, 'confidence': 60, 'surface_temperature_celcius': 44}
# {'_id': ObjectId('628a4077c40eee0972357f1d'), 'latitude': -37.5243, 'longitude': 143.0437, 'confidence': 60, 'surface_temperature_celcius': 40}
# {'_id': ObjectId('628a4077c40eee0972357f8b'), 'latitude': -34.8634, 'longitude': 143.1811, 'confidence': 60, 'surface_temperature_celcius': 43}
# {'_id': ObjectId('628a4077c40eee0972358095'), 'latitude': -37.7836, 'longitude': 141.4711, 'confidence': 60, 'surface_temperature_celcius': 40}
# {'_id': ObjectId('628a4077c40eee0972358195'), 'latitude': -37.7578, 'longitude': 142.227, 'confidence': 60, 'surface_temperature_celcius': 40}
# {'_id': ObjectId('628a4077c40eee09723581b2'), 'latitude': -36.6803, 'longitude': 141.0957, 'confidence': 60, 'surface_temperature_celcius': 44}
# {'_id': ObjectId('628a4077c40eee09723581c0'), 'latitude': -36.9524, 'longitude': 143.7501, 'confidence': 60, 'surface_temperature_celcius': 40}
# {'_id': ObjectId('628a4077c40eee09723581e6'), 'latitude': -36.0787, 'longitude': 146.5728, 'confidence': 60, 'surface_temperature_celcius': 40}
# {'_id': ObjectId('628a4077c40eee097235821e'), 'latitude': -37.7974, 'longitude': 148.5498, 'confidence': 60, 'surface_temperature_celcius': 53}
# {'_id': ObjectId('628a4077c40eee097235828a'), 'latitude': -36.8632, 'longitude': 142.5802, 'confidence': 60, 'surface_temperature_celcius': 60}
# {'_id': ObjectId('628a4077c40eee097235831e'), 'latitude': -38.1177, 'longitude': 143.6409, 'confidence': 60, 'surface_temperature_celcius': 40}
# {'_id': ObjectId('628a4077c40eee097235836b'), 'latitude': -36.3872, 'longitude': 145.3858, 'confidence': 60, 'surface_temperature_celcius': 40}
# {'_id': ObjectId('628a4077c40eee097235836f'), 'latitude': -37.324, 'longitude': 146.1647, 'confidence': 60, 'surface_temperature_celcius': 46}
# {'_id': ObjectId('628a4077c40eee09723583d1'), 'latitude': -37.8469, 'longitude': 143.5343, 'confidence': 60, 'surface_temperature_celcius': 50}
# {'_id': ObjectId('628a4077c40eee09723583eb'), 'latitude': -37.4336, 'longitude': 147.0534, 'confidence': 60, 'surface_temperature_celcius': 51}
# {'_id': ObjectId('628a4077c40eee09723583f8'), 'latitude': -37.3942, 'longitude': 147.0455, 'confidence': 60, 'surface_temperature_celcius': 44}
# {'_id': ObjectId('628a4077c40eee09723579ed'), 'latitude': -37.38, 'longitude': 149.334, 'confidence': 61, 'surface_temperature_celcius': 31}
# {'_id': ObjectId('628a4077c40eee0972357aa9'), 'latitude': -37.562, 'longitude': 148.05, 'confidence': 61, 'surface_temperature_celcius': 72}
# {'_id': ObjectId('628a4077c40eee0972357abc'), 'latitude': -37.347, 'longitude': 148.019, 'confidence': 61, 'surface_temperature_celcius': 36}
# {'_id': ObjectId('628a4077c40eee0972357ad1'), 'latitude': -38.0173, 'longitude': 144.0571, 'confidence': 61, 'surface_temperature_celcius': 41}
# {'_id': ObjectId('628a4077c40eee0972357ad3'), 'latitude': -37.443000000000005, 'longitude': 147.3064, 'confidence': 61, 'surface_temperature_celcius': 41}
# {'_id': ObjectId('628a4077c40eee0972357ae9'), 'latitude': -38.5233, 'longitude': 143.433, 'confidence': 61, 'surface_temperature_celcius': 41}
# {'_id': ObjectId('628a4077c40eee0972357af9'), 'latitude': -36.779, 'longitude': 146.108, 'confidence': 61, 'surface_temperature_celcius': 32}
# {'_id': ObjectId('628a4077c40eee0972357afa'), 'latitude': -36.779, 'longitude': 146.108, 'confidence': 61, 'surface_temperature_celcius': 32}
# {'_id': ObjectId('628a4077c40eee0972357b0c'), 'latitude': -36.2669, 'longitude': 143.1906, 'confidence': 61, 'surface_temperature_celcius': 45}
# {'_id': ObjectId('628a4077c40eee0972357b1d'), 'latitude': -36.2229, 'longitude': 143.4245, 'confidence': 61, 'surface_temperature_celcius': 41}
# {'_id': ObjectId('628a4077c40eee0972357b40'), 'latitude': -37.0585, 'longitude': 143.8589, 'confidence': 61, 'surface_temperature_celcius': 41}
# ...
# {'_id': ObjectId('628a4077c40eee0972357b7f'), 'latitude': -36.3111, 'longitude': 143.7704, 'confidence': 69, 'surface_temperature_celcius': 44}
# {'_id': ObjectId('628a4077c40eee0972357ba7'), 'latitude': -36.3971, 'longitude': 142.6444, 'confidence': 69, 'surface_temperature_celcius': 44}
# {'_id': ObjectId('628a4077c40eee0972357bbb'), 'latitude': -36.3119, 'longitude': 146.4371, 'confidence': 69, 'surface_temperature_celcius': 44}
# {'_id': ObjectId('628a4077c40eee0972357bcb'), 'latitude': -36.0411, 'longitude': 141.7071, 'confidence': 69, 'surface_temperature_celcius': 44}
# {'_id': ObjectId('628a4077c40eee0972357bcd'), 'latitude': -35.9903, 'longitude': 142.2708, 'confidence': 69, 'surface_temperature_celcius': 45}
# {'_id': ObjectId('628a4077c40eee0972357bdf'), 'latitude': -36.4489, 'longitude': 144.1445, 'confidence': 69, 'surface_temperature_celcius': 45}
# {'_id': ObjectId('628a4077c40eee0972357be1'), 'latitude': -36.4032, 'longitude': 144.0604, 'confidence': 69, 'surface_temperature_celcius': 45}
# {'_id': ObjectId('628a4077c40eee0972357c3d'), 'latitude': -36.9731, 'longitude': 143.9437, 'confidence': 69, 'surface_temperature_celcius': 44}
# {'_id': ObjectId('628a4077c40eee0972357c81'), 'latitude': -37.1749, 'longitude': 143.9573, 'confidence': 69, 'surface_temperature_celcius': 44}
# {'_id': ObjectId('628a4077c40eee0972357c9a'), 'latitude': -37.5673, 'longitude': 143.0535, 'confidence': 69, 'surface_temperature_celcius': 44}
# {'_id': ObjectId('628a4077c40eee0972357cb7'), 'latitude': -36.4226, 'longitude': 141.6752, 'confidence': 69, 'surface_temperature_celcius': 45}
# {'_id': ObjectId('628a4077c40eee0972357cc4'), 'latitude': -38.4068, 'longitude': 147.0682, 'confidence': 69, 'surface_temperature_celcius': 44}
# {'_id': ObjectId('628a4077c40eee0972357d12'), 'latitude': -37.032, 'longitude': 143.4464, 'confidence': 69, 'surface_temperature_celcius': 44}
# {'_id': ObjectId('628a4077c40eee0972357da3'), 'latitude': -36.2549, 'longitude': 141.9908, 'confidence': 69, 'surface_temperature_celcius': 44}
# {'_id': ObjectId('628a4077c40eee0972357e12'), 'latitude': -37.7087, 'longitude': 145.5499, 'confidence': 69, 'surface_temperature_celcius': 45}
# {'_id': ObjectId('628a4077c40eee0972357e52'), 'latitude': -36.9654, 'longitude': 140.981, 'confidence': 69, 'surface_temperature_celcius': 44}
# {'_id': ObjectId('628a4077c40eee0972357e58'), 'latitude': -37.4022, 'longitude': 143.2016, 'confidence': 69, 'surface_temperature_celcius': 45}
# {'_id': ObjectId('628a4077c40eee0972357e5a'), 'latitude': -36.4469, 'longitude': 142.4565, 'confidence': 69, 'surface_temperature_celcius': 45}
# {'_id': ObjectId('628a4077c40eee0972357e5c'), 'latitude': -37.0135, 'longitude': 143.5822, 'confidence': 69, 'surface_temperature_celcius': 44}
# {'_id': ObjectId('628a4077c40eee0972357e95'), 'latitude': -37.4322, 'longitude': 143.1602, 'confidence': 69, 'surface_temperature_celcius': 45}
# {'_id': ObjectId('628a4077c40eee0972357e9f'), 'latitude': -36.6704, 'longitude': 141.3197, 'confidence': 69, 'surface_temperature_celcius': 45}
# {'_id': ObjectId('628a4077c40eee0972357eb9'), 'latitude': -38.1748, 'longitude': 143.0552, 'confidence': 69, 'surface_temperature_celcius': 44}
# {'_id': ObjectId('628a4077c40eee0972357edc'), 'latitude': -38.0898, 'longitude': 143.7394, 'confidence': 69, 'surface_temperature_celcius': 47}
# {'_id': ObjectId('628a4077c40eee0972357ee5'), 'latitude': -38.0907, 'longitude': 143.2362, 'confidence': 69, 'surface_temperature_celcius': 45}
# {'_id': ObjectId('628a4077c40eee0972357ef2'), 'latitude': -37.9318, 'longitude': 143.2083, 'confidence': 69, 'surface_temperature_celcius': 44}
# {'_id': ObjectId('628a4077c40eee0972357f1f'), 'latitude': -37.3544, 'longitude': 143.9291, 'confidence': 69, 'surface_temperature_celcius': 44}
# {'_id': ObjectId('628a4077c40eee0972357f29'), 'latitude': -37.4007, 'longitude': 142.7674, 'confidence': 69, 'surface_temperature_celcius': 44}
# {'_id': ObjectId('628a4077c40eee0972357f6b'), 'latitude': -35.9082, 'longitude': 145.3761, 'confidence': 69, 'surface_temperature_celcius': 44}
# {'_id': ObjectId('628a4077c40eee0972357fd4'), 'latitude': -36.6589, 'longitude': 141.2755, 'confidence': 69, 'surface_temperature_celcius': 48}
# {'_id': ObjectId('628a4077c40eee0972357fdf'), 'latitude': -36.798, 'longitude': 142.4482, 'confidence': 69, 'surface_temperature_celcius': 44}
# {'_id': ObjectId('628a4077c40eee0972358039'), 'latitude': -37.1009, 'longitude': 141.9666, 'confidence': 69, 'surface_temperature_celcius': 45}
# {'_id': ObjectId('628a4077c40eee097235803b'), 'latitude': -36.9211, 'longitude': 143.6017, 'confidence': 69, 'surface_temperature_celcius': 44}
# {'_id': ObjectId('628a4077c40eee0972358059'), 'latitude': -36.8573, 'longitude': 143.5278, 'confidence': 69, 'surface_temperature_celcius': 45}
# {'_id': ObjectId('628a4077c40eee0972358068'), 'latitude': -37.2709, 'longitude': 143.9659, 'confidence': 69, 'surface_temperature_celcius': 45}
# {'_id': ObjectId('628a4077c40eee0972358069'), 'latitude': -37.5632, 'longitude': 142.2864, 'confidence': 69, 'surface_temperature_celcius': 45}
# {'_id': ObjectId('628a4077c40eee0972358082'), 'latitude': -37.0667, 'longitude': 143.0582, 'confidence': 69, 'surface_temperature_celcius': 44}
# {'_id': ObjectId('628a4077c40eee097235809e'), 'latitude': -36.778, 'longitude': 145.1635, 'confidence': 69, 'surface_temperature_celcius': 45}
# {'_id': ObjectId('628a4077c40eee09723580a2'), 'latitude': -37.6008, 'longitude': 143.0558, 'confidence': 69, 'surface_temperature_celcius': 44}
# {'_id': ObjectId('628a4077c40eee09723580f2'), 'latitude': -36.4392, 'longitude': 144.2111, 'confidence': 69, 'surface_temperature_celcius': 44}
# {'_id': ObjectId('628a4077c40eee097235813d'), 'latitude': -37.8131, 'longitude': 143.1175, 'confidence': 69, 'surface_temperature_celcius': 45}
# {'_id': ObjectId('628a4077c40eee09723581ac'), 'latitude': -36.6188, 'longitude': 144.0402, 'confidence': 69, 'surface_temperature_celcius': 44}
# {'_id': ObjectId('628a4077c40eee09723581ad'), 'latitude': -37.4047, 'longitude': 143.6615, 'confidence': 69, 'surface_temperature_celcius': 45}
# {'_id': ObjectId('628a4077c40eee0972358285'), 'latitude': -36.0765, 'longitude': 146.4896, 'confidence': 69, 'surface_temperature_celcius': 46}
# {'_id': ObjectId('628a4077c40eee09723582c3'), 'latitude': -36.9354, 'longitude': 142.5807, 'confidence': 69, 'surface_temperature_celcius': 45}
# {'_id': ObjectId('628a4077c40eee09723582c9'), 'latitude': -37.6339, 'longitude': 143.4108, 'confidence': 69, 'surface_temperature_celcius': 46}
# {'_id': ObjectId('628a4077c40eee09723582f9'), 'latitude': -36.4918, 'longitude': 142.2465, 'confidence': 69, 'surface_temperature_celcius': 54}
# {'_id': ObjectId('628a4077c40eee0972358334'), 'latitude': -37.8668, 'longitude': 143.0472, 'confidence': 69, 'surface_temperature_celcius': 44}
# {'_id': ObjectId('628a4077c40eee0972358359'), 'latitude': -37.7836, 'longitude': 142.9437, 'confidence': 69, 'surface_temperature_celcius': 44}
# {'_id': ObjectId('628a4077c40eee097235838d'), 'latitude': -34.2648, 'longitude': 141.6325, 'confidence': 69, 'surface_temperature_celcius': 51}
# {'_id': ObjectId('628a4077c40eee09723583bd'), 'latitude': -36.4422, 'longitude': 141.4172, 'confidence': 69, 'surface_temperature_celcius': 46}
# {'_id': ObjectId('628a4077c40eee0972357a12'), 'latitude': -34.965, 'longitude': 142.031, 'confidence': 70, 'surface_temperature_celcius': 55}
# {'_id': ObjectId('628a4077c40eee0972357a87'), 'latitude': -37.45, 'longitude': 148.097, 'confidence': 70, 'surface_temperature_celcius': 37}
# {'_id': ObjectId('628a4077c40eee0972357a98'), 'latitude': -37.434, 'longitude': 148.091, 'confidence': 70, 'surface_temperature_celcius': 52}
# {'_id': ObjectId('628a4077c40eee0972357aad'), 'latitude': -37.497, 'longitude': 147.266, 'confidence': 70, 'surface_temperature_celcius': 37}
# {'_id': ObjectId('628a4077c40eee0972357ac0'), 'latitude': -36.996, 'longitude': 148.22799999999998, 'confidence': 70, 'surface_temperature_celcius': 40}
# {'_id': ObjectId('628a4077c40eee0972357b08'), 'latitude': -36.7179, 'longitude': 142.2536, 'confidence': 70, 'surface_temperature_celcius': 45}
# {'_id': ObjectId('628a4077c40eee0972357b2d'), 'latitude': -37.5865, 'longitude': 143.0246, 'confidence': 70, 'surface_temperature_celcius': 45}
# {'_id': ObjectId('628a4077c40eee0972357b30'), 'latitude': -36.6296, 'longitude': 142.5191, 'confidence': 70, 'surface_temperature_celcius': 45}
# {'_id': ObjectId('628a4077c40eee0972357b31'), 'latitude': -36.0005, 'longitude': 143.1847, 'confidence': 70, 'surface_temperature_celcius': 45}
# {'_id': ObjectId('628a4077c40eee0972357b58'), 'latitude': -36.7783, 'longitude': 146.6449, 'confidence': 70, 'surface_temperature_celcius': 56}
# {'_id': ObjectId('628a4077c40eee0972357ba4'), 'latitude': -36.301, 'longitude': 143.2349, 'confidence': 70, 'surface_temperature_celcius': 45}
# {'_id': ObjectId('628a4077c40eee0972357bae'), 'latitude': -36.3073, 'longitude': 144.2678, 'confidence': 70, 'surface_temperature_celcius': 45}
# {'_id': ObjectId('628a4077c40eee0972357bb2'), 'latitude': -36.7536, 'longitude': 141.6092, 'confidence': 70, 'surface_temperature_celcius': 45}
# {'_id': ObjectId('628a4077c40eee0972357bb8'), 'latitude': -36.4617, 'longitude': 144.6381, 'confidence': 70, 'surface_temperature_celcius': 48}
# {'_id': ObjectId('628a4077c40eee0972357bcf'), 'latitude': -36.1631, 'longitude': 143.3475, 'confidence': 70, 'surface_temperature_celcius': 45}
# {'_id': ObjectId('628a4077c40eee0972357c13'), 'latitude': -36.358000000000004, 'longitude': 144.4905, 'confidence': 70, 'surface_temperature_celcius': 45}
# {'_id': ObjectId('628a4077c40eee0972357c24'), 'latitude': -36.3493, 'longitude': 141.5238, 'confidence': 70, 'surface_temperature_celcius': 45}
# {'_id': ObjectId('628a4077c40eee0972357c2c'), 'latitude': -38.5657, 'longitude': 146.438, 'confidence': 70, 'surface_temperature_celcius': 45}
# {'_id': ObjectId('628a4077c40eee0972357cb2'), 'latitude': -36.3012, 'longitude': 141.16299999999998, 'confidence': 70, 'surface_temperature_celcius': 45}
# {'_id': ObjectId('628a4077c40eee0972357cc5'), 'latitude': -36.5134, 'longitude': 142.4682, 'confidence': 70, 'surface_temperature_celcius': 53}
# {'_id': ObjectId('628a4077c40eee0972357cd8'), 'latitude': -37.7772, 'longitude': 143.1222, 'confidence': 70, 'surface_temperature_celcius': 45}
# {'_id': ObjectId('628a4077c40eee0972357d64'), 'latitude': -36.7038, 'longitude': 141.8813, 'confidence': 70, 'surface_temperature_celcius': 45}
# {'_id': ObjectId('628a4077c40eee0972357da4'), 'latitude': -36.2531, 'longitude': 142.0113, 'confidence': 70, 'surface_temperature_celcius': 45}
# {'_id': ObjectId('628a4077c40eee0972357dc8'), 'latitude': -37.4786, 'longitude': 141.4578, 'confidence': 70, 'surface_temperature_celcius': 45}
# {'_id': ObjectId('628a4077c40eee0972357dd2'), 'latitude': -36.9303, 'longitude': 143.1034, 'confidence': 70, 'surface_temperature_celcius': 72}
# {'_id': ObjectId('628a4077c40eee0972357de4'), 'latitude': -36.1926, 'longitude': 146.3074, 'confidence': 70, 'surface_temperature_celcius': 45}
# {'_id': ObjectId('628a4077c40eee0972357df7'), 'latitude': -36.8081, 'longitude': 142.8665, 'confidence': 70, 'surface_temperature_celcius': 45}
# {'_id': ObjectId('628a4077c40eee0972357e57'), 'latitude': -36.5223, 'longitude': 144.5934, 'confidence': 70, 'surface_temperature_celcius': 45}
# {'_id': ObjectId('628a4077c40eee0972357e7a'), 'latitude': -37.7194, 'longitude': 143.3497, 'confidence': 70, 'surface_temperature_celcius': 45}
# {'_id': ObjectId('628a4077c40eee0972357eb8'), 'latitude': -36.8689, 'longitude': 141.9507, 'confidence': 70, 'surface_temperature_celcius': 45}
# {'_id': ObjectId('628a4077c40eee0972357ec4'), 'latitude': -36.801, 'longitude': 144.0114, 'confidence': 70, 'surface_temperature_celcius': 45}
# {'_id': ObjectId('628a4077c40eee0972357edb'), 'latitude': -38.1219, 'longitude': 143.7495, 'confidence': 70, 'surface_temperature_celcius': 51}
# {'_id': ObjectId('628a4077c40eee0972357f36'), 'latitude': -36.923, 'longitude': 143.8106, 'confidence': 70, 'surface_temperature_celcius': 45}
# {'_id': ObjectId('628a4077c40eee0972357f81'), 'latitude': -37.2627, 'longitude': 141.8114, 'confidence': 70, 'surface_temperature_celcius': 45}
# {'_id': ObjectId('628a4077c40eee0972357f8a'), 'latitude': -36.9038, 'longitude': 141.0661, 'confidence': 70, 'surface_temperature_celcius': 51}
# {'_id': ObjectId('628a4077c40eee0972357f9d'), 'latitude': -36.7239, 'longitude': 141.0154, 'confidence': 70, 'surface_temperature_celcius': 45}
# {'_id': ObjectId('628a4077c40eee0972357fe6'), 'latitude': -36.7445, 'longitude': 143.3254, 'confidence': 70, 'surface_temperature_celcius': 45}
# {'_id': ObjectId('628a4077c40eee0972357ff6'), 'latitude': -36.1484, 'longitude': 141.3879, 'confidence': 70, 'surface_temperature_celcius': 48}
# {'_id': ObjectId('628a4077c40eee097235802c'), 'latitude': -36.5414, 'longitude': 145.4159, 'confidence': 70, 'surface_temperature_celcius': 45}
# {'_id': ObjectId('628a4077c40eee097235804f'), 'latitude': -37.7871, 'longitude': 142.718, 'confidence': 70, 'surface_temperature_celcius': 45}
# {'_id': ObjectId('628a4077c40eee097235808c'), 'latitude': -36.5548, 'longitude': 142.5237, 'confidence': 70, 'surface_temperature_celcius': 45}
# {'_id': ObjectId('628a4077c40eee09723580c8'), 'latitude': -37.8849, 'longitude': 143.3162, 'confidence': 70, 'surface_temperature_celcius': 45}
# {'_id': ObjectId('628a4077c40eee09723580e6'), 'latitude': -36.1574, 'longitude': 144.3672, 'confidence': 70, 'surface_temperature_celcius': 45}
# {'_id': ObjectId('628a4077c40eee0972358106'), 'latitude': -36.5418, 'longitude': 144.666, 'confidence': 70, 'surface_temperature_celcius': 45}
# {'_id': ObjectId('628a4077c40eee097235813c'), 'latitude': -37.7943, 'longitude': 143.0545, 'confidence': 70, 'surface_temperature_celcius': 45}
# {'_id': ObjectId('628a4077c40eee0972358157'), 'latitude': -36.4045, 'longitude': 142.0918, 'confidence': 70, 'surface_temperature_celcius': 46}
# {'_id': ObjectId('628a4077c40eee0972358194'), 'latitude': -37.4785, 'longitude': 142.6307, 'confidence': 70, 'surface_temperature_celcius': 45}
# {'_id': ObjectId('628a4077c40eee097235819a'), 'latitude': -36.7318, 'longitude': 141.4603, 'confidence': 70, 'surface_temperature_celcius': 45}
# {'_id': ObjectId('628a4077c40eee09723581a7'), 'latitude': -36.6348, 'longitude': 142.4985, 'confidence': 70, 'surface_temperature_celcius': 45}
# {'_id': ObjectId('628a4077c40eee0972358258'), 'latitude': -37.9483, 'longitude': 145.3937, 'confidence': 70, 'surface_temperature_celcius': 51}
# {'_id': ObjectId('628a4077c40eee09723582a5'), 'latitude': -38.3483, 'longitude': 147.0446, 'confidence': 70, 'surface_temperature_celcius': 37}
# {'_id': ObjectId('628a4077c40eee09723582b3'), 'latitude': -36.9373, 'longitude': 142.5327, 'confidence': 70, 'surface_temperature_celcius': 45}
# {'_id': ObjectId('628a4077c40eee09723582d9'), 'latitude': -38.1868, 'longitude': 143.0938, 'confidence': 70, 'surface_temperature_celcius': 45}
# {'_id': ObjectId('628a4077c40eee09723582e2'), 'latitude': -37.4465, 'longitude': 143.5163, 'confidence': 70, 'surface_temperature_celcius': 50}
# {'_id': ObjectId('628a4077c40eee09723582ee'), 'latitude': -36.8848, 'longitude': 142.1523, 'confidence': 70, 'surface_temperature_celcius': 51}
# {'_id': ObjectId('628a4077c40eee097235830a'), 'latitude': -36.4604, 'longitude': 142.1623, 'confidence': 70, 'surface_temperature_celcius': 48}
# {'_id': ObjectId('628a4077c40eee0972358358'), 'latitude': -37.7583, 'longitude': 143.41, 'confidence': 70, 'surface_temperature_celcius': 45}
# {'_id': ObjectId('628a4077c40eee0972358371'), 'latitude': -36.2721, 'longitude': 146.847, 'confidence': 70, 'surface_temperature_celcius': 45}
# {'_id': ObjectId('628a4077c40eee0972358382'), 'latitude': -36.0362, 'longitude': 145.7984, 'confidence': 70, 'surface_temperature_celcius': 45}
# {'_id': ObjectId('628a4077c40eee0972358396'), 'latitude': -36.9576, 'longitude': 141.5387, 'confidence': 70, 'surface_temperature_celcius': 45}
# {'_id': ObjectId('628a4077c40eee0972358408'), 'latitude': -37.4098, 'longitude': 147.0489, 'confidence': 70, 'surface_temperature_celcius': 45}

# %% [markdown]
# ## h. Find the average surface temperature (°C) for each day. You are required to only display average surface temperature (°C) and the date in the output.

# %%
results = mydb.climate.aggregate([
    {
        "$lookup":{
            "from":"hotspot",
            "localField": "date",
            "foreignField": "date",
            "as":"hotspot"
        }
    },
    {
        "$project":
        {
            "_id":0, 
            "date":1, 
            'AvgTemp': { '$avg': "$hotspot.surface_temperature_celcius"}}
            
        }    
])

for x in results: 
    print(x)
# Out:
# {'date': datetime.datetime(2020, 12, 31, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 1, 2, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 1, 3, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 1, 4, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 1, 5, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 1, 6, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 1, 7, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 1, 8, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 1, 9, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 1, 10, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 1, 11, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 1, 12, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 1, 13, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 1, 14, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 1, 15, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 1, 16, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 1, 17, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 1, 18, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 1, 19, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 1, 20, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 1, 21, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 1, 22, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 1, 23, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 1, 24, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 1, 25, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 1, 26, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 1, 27, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 1, 28, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 1, 29, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 1, 30, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 1, 31, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 2, 1, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 2, 2, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 2, 3, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 2, 4, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 2, 5, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 2, 6, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 2, 7, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 2, 8, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 2, 9, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 2, 10, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 2, 11, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 2, 12, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 2, 13, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 2, 14, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 2, 15, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 2, 16, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 2, 17, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 2, 18, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 2, 19, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 2, 20, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 2, 21, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 2, 22, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 2, 23, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 2, 24, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 2, 25, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 2, 26, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 2, 27, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 2, 28, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 3, 1, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 3, 2, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 3, 3, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 3, 4, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 3, 5, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 3, 6, 0, 0), 'AvgTemp': 60.5}
# {'date': datetime.datetime(2021, 3, 7, 0, 0), 'AvgTemp': 64.0}
# {'date': datetime.datetime(2021, 3, 8, 0, 0), 'AvgTemp': 51.5}
# {'date': datetime.datetime(2021, 3, 9, 0, 0), 'AvgTemp': 46.666666666666664}
# {'date': datetime.datetime(2021, 3, 10, 0, 0), 'AvgTemp': 69.375}
# {'date': datetime.datetime(2021, 3, 11, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 3, 12, 0, 0), 'AvgTemp': 88.2}
# {'date': datetime.datetime(2021, 3, 13, 0, 0), 'AvgTemp': 38.5}
# {'date': datetime.datetime(2021, 3, 14, 0, 0), 'AvgTemp': 65.6}
# {'date': datetime.datetime(2021, 3, 15, 0, 0), 'AvgTemp': 46.0}
# {'date': datetime.datetime(2021, 3, 16, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 3, 17, 0, 0), 'AvgTemp': 59.5}
# {'date': datetime.datetime(2021, 3, 18, 0, 0), 'AvgTemp': 79.33333333333333}
# {'date': datetime.datetime(2021, 3, 19, 0, 0), 'AvgTemp': 65.57142857142857}
# {'date': datetime.datetime(2021, 3, 20, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 3, 21, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 3, 22, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 3, 23, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 3, 24, 0, 0), 'AvgTemp': 49.0}
# {'date': datetime.datetime(2021, 3, 25, 0, 0), 'AvgTemp': 66.0}
# {'date': datetime.datetime(2021, 3, 26, 0, 0), 'AvgTemp': 56.88235294117647}
# {'date': datetime.datetime(2021, 3, 27, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 3, 28, 0, 0), 'AvgTemp': 60.925925925925924}
# {'date': datetime.datetime(2021, 3, 29, 0, 0), 'AvgTemp': 51.0}
# {'date': datetime.datetime(2021, 3, 30, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 3, 31, 0, 0), 'AvgTemp': 48.72727272727273}
# {'date': datetime.datetime(2021, 4, 1, 0, 0), 'AvgTemp': 46.714285714285715}
# {'date': datetime.datetime(2021, 4, 2, 0, 0), 'AvgTemp': 45.2}
# {'date': datetime.datetime(2021, 4, 3, 0, 0), 'AvgTemp': 58.44444444444444}
# {'date': datetime.datetime(2021, 4, 4, 0, 0), 'AvgTemp': 62.57303370786517}
# {'date': datetime.datetime(2021, 4, 5, 0, 0), 'AvgTemp': 53.142857142857146}
# {'date': datetime.datetime(2021, 4, 6, 0, 0), 'AvgTemp': 61.71186440677966}
# {'date': datetime.datetime(2021, 4, 7, 0, 0), 'AvgTemp': 50.69230769230769}
# {'date': datetime.datetime(2021, 4, 8, 0, 0), 'AvgTemp': 60.75}
# {'date': datetime.datetime(2021, 4, 9, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 4, 10, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 4, 11, 0, 0), 'AvgTemp': 46.291666666666664}
# {'date': datetime.datetime(2021, 4, 12, 0, 0), 'AvgTemp': 52.69565217391305}
# {'date': datetime.datetime(2021, 4, 13, 0, 0), 'AvgTemp': 58.57983193277311}
# {'date': datetime.datetime(2021, 4, 14, 0, 0), 'AvgTemp': 61.94444444444444}
# {'date': datetime.datetime(2021, 4, 15, 0, 0), 'AvgTemp': 59.57971014492754}
# {'date': datetime.datetime(2021, 4, 16, 0, 0), 'AvgTemp': 48.72222222222222}
# {'date': datetime.datetime(2021, 4, 17, 0, 0), 'AvgTemp': 50.921052631578945}
# {'date': datetime.datetime(2021, 4, 18, 0, 0), 'AvgTemp': 53.36615384615384}
# {'date': datetime.datetime(2021, 4, 19, 0, 0), 'AvgTemp': 54.16}
# {'date': datetime.datetime(2021, 4, 20, 0, 0), 'AvgTemp': 56.58064516129032}
# {'date': datetime.datetime(2021, 4, 21, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 4, 22, 0, 0), 'AvgTemp': 54.5}
# {'date': datetime.datetime(2021, 4, 23, 0, 0), 'AvgTemp': 53.89473684210526}
# {'date': datetime.datetime(2021, 4, 24, 0, 0), 'AvgTemp': 59.375}
# {'date': datetime.datetime(2021, 4, 25, 0, 0), 'AvgTemp': 48.666666666666664}
# {'date': datetime.datetime(2021, 4, 26, 0, 0), 'AvgTemp': 34.0}
# {'date': datetime.datetime(2021, 4, 27, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 4, 28, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 4, 29, 0, 0), 'AvgTemp': 63.0}
# {'date': datetime.datetime(2021, 4, 30, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 5, 1, 0, 0), 'AvgTemp': 68.4}
# {'date': datetime.datetime(2021, 5, 2, 0, 0), 'AvgTemp': 55.6}
# {'date': datetime.datetime(2021, 5, 3, 0, 0), 'AvgTemp': 56.796875}
# {'date': datetime.datetime(2021, 5, 4, 0, 0), 'AvgTemp': 56.80740740740741}
# {'date': datetime.datetime(2021, 5, 5, 0, 0), 'AvgTemp': 51.70967741935484}
# {'date': datetime.datetime(2021, 5, 6, 0, 0), 'AvgTemp': 57.529411764705884}
# {'date': datetime.datetime(2021, 5, 7, 0, 0), 'AvgTemp': 50.333333333333336}
# {'date': datetime.datetime(2021, 5, 8, 0, 0), 'AvgTemp': 56.291666666666664}
# {'date': datetime.datetime(2021, 5, 9, 0, 0), 'AvgTemp': 42.46153846153846}
# {'date': datetime.datetime(2021, 5, 10, 0, 0), 'AvgTemp': 52.86842105263158}
# {'date': datetime.datetime(2021, 5, 11, 0, 0), 'AvgTemp': 59.36842105263158}
# {'date': datetime.datetime(2021, 5, 12, 0, 0), 'AvgTemp': 51.5}
# {'date': datetime.datetime(2021, 5, 13, 0, 0), 'AvgTemp': 58.611111111111114}
# {'date': datetime.datetime(2021, 5, 14, 0, 0), 'AvgTemp': 49.0}
# {'date': datetime.datetime(2021, 5, 15, 0, 0), 'AvgTemp': 53.950980392156865}
# {'date': datetime.datetime(2021, 5, 16, 0, 0), 'AvgTemp': 39.666666666666664}
# {'date': datetime.datetime(2021, 5, 17, 0, 0), 'AvgTemp': 52.0}
# {'date': datetime.datetime(2021, 5, 18, 0, 0), 'AvgTemp': 44.142857142857146}
# {'date': datetime.datetime(2021, 5, 19, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 5, 20, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 5, 21, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 5, 22, 0, 0), 'AvgTemp': 54.484848484848484}
# {'date': datetime.datetime(2021, 5, 23, 0, 0), 'AvgTemp': 51.2}
# {'date': datetime.datetime(2021, 5, 24, 0, 0), 'AvgTemp': 40.333333333333336}
# {'date': datetime.datetime(2021, 5, 25, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 5, 26, 0, 0), 'AvgTemp': 49.5}
# {'date': datetime.datetime(2021, 5, 27, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 5, 28, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 5, 29, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 5, 30, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 5, 31, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 6, 1, 0, 0), 'AvgTemp': 54.0}
# {'date': datetime.datetime(2021, 6, 2, 0, 0), 'AvgTemp': 47.72727272727273}
# {'date': datetime.datetime(2021, 6, 3, 0, 0), 'AvgTemp': 47.0}
# {'date': datetime.datetime(2021, 6, 4, 0, 0), 'AvgTemp': 52.22222222222222}
# {'date': datetime.datetime(2021, 6, 5, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 6, 6, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 6, 7, 0, 0), 'AvgTemp': 51.857142857142854}
# {'date': datetime.datetime(2021, 6, 8, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 6, 9, 0, 0), 'AvgTemp': 49.0}
# {'date': datetime.datetime(2021, 6, 10, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 6, 11, 0, 0), 'AvgTemp': 41.5}
# {'date': datetime.datetime(2021, 6, 12, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 6, 13, 0, 0), 'AvgTemp': 41.0}
# {'date': datetime.datetime(2021, 6, 14, 0, 0), 'AvgTemp': 53.25}
# {'date': datetime.datetime(2021, 6, 15, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 6, 16, 0, 0), 'AvgTemp': 42.5}
# {'date': datetime.datetime(2021, 6, 17, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 6, 18, 0, 0), 'AvgTemp': 42.0}
# {'date': datetime.datetime(2021, 6, 19, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 6, 20, 0, 0), 'AvgTemp': 71.16666666666667}
# {'date': datetime.datetime(2021, 6, 21, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 6, 22, 0, 0), 'AvgTemp': 46.0}
# {'date': datetime.datetime(2021, 6, 23, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 6, 24, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 6, 25, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 6, 26, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 6, 27, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 6, 28, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 6, 29, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 6, 30, 0, 0), 'AvgTemp': 44.333333333333336}
# {'date': datetime.datetime(2021, 7, 1, 0, 0), 'AvgTemp': 30.5}
# {'date': datetime.datetime(2021, 7, 2, 0, 0), 'AvgTemp': 43.5}
# {'date': datetime.datetime(2021, 7, 3, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 7, 4, 0, 0), 'AvgTemp': 40.0}
# {'date': datetime.datetime(2021, 7, 5, 0, 0), 'AvgTemp': 45.0}
# {'date': datetime.datetime(2021, 7, 6, 0, 0), 'AvgTemp': 56.0}
# {'date': datetime.datetime(2021, 7, 7, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 7, 8, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 7, 9, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 7, 10, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 7, 11, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 7, 12, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 7, 13, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 7, 14, 0, 0), 'AvgTemp': 41.5}
# {'date': datetime.datetime(2021, 7, 15, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 7, 16, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 7, 17, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 7, 18, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 7, 19, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 7, 20, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 7, 21, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 7, 22, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 7, 23, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 7, 24, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 7, 25, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 7, 26, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 7, 27, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 7, 28, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 7, 29, 0, 0), 'AvgTemp': 48.0}
# {'date': datetime.datetime(2021, 7, 30, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 7, 31, 0, 0), 'AvgTemp': 47.0}
# {'date': datetime.datetime(2021, 8, 1, 0, 0), 'AvgTemp': 58.0}
# {'date': datetime.datetime(2021, 8, 2, 0, 0), 'AvgTemp': 63.5}
# {'date': datetime.datetime(2021, 8, 3, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 8, 4, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 8, 5, 0, 0), 'AvgTemp': 40.0}
# {'date': datetime.datetime(2021, 8, 6, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 8, 7, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 8, 8, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 8, 9, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 8, 10, 0, 0), 'AvgTemp': 63.0}
# {'date': datetime.datetime(2021, 8, 11, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 8, 12, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 8, 13, 0, 0), 'AvgTemp': 49.0}
# {'date': datetime.datetime(2021, 8, 14, 0, 0), 'AvgTemp': 40.8}
# {'date': datetime.datetime(2021, 8, 15, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 8, 16, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 8, 17, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 8, 18, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 8, 19, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 8, 20, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 8, 21, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 8, 22, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 8, 23, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 8, 24, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 8, 25, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 8, 26, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 8, 27, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 8, 28, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 8, 29, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 8, 30, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 8, 31, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 9, 1, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 9, 2, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 9, 3, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 9, 4, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 9, 5, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 9, 6, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 9, 7, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 9, 8, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 9, 9, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 9, 10, 0, 0), 'AvgTemp': 56.5}
# {'date': datetime.datetime(2021, 9, 11, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 9, 12, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 9, 13, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 9, 14, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 9, 15, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 9, 16, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 9, 17, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 9, 18, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 9, 19, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 9, 20, 0, 0), 'AvgTemp': 63.6}
# {'date': datetime.datetime(2021, 9, 21, 0, 0), 'AvgTemp': 40.5}
# {'date': datetime.datetime(2021, 9, 22, 0, 0), 'AvgTemp': 45.0}
# {'date': datetime.datetime(2021, 9, 23, 0, 0), 'AvgTemp': 52.73913043478261}
# {'date': datetime.datetime(2021, 9, 24, 0, 0), 'AvgTemp': 53.57142857142857}
# {'date': datetime.datetime(2021, 9, 25, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 9, 26, 0, 0), 'AvgTemp': 33.0}
# {'date': datetime.datetime(2021, 9, 27, 0, 0), 'AvgTemp': 49.714285714285715}
# {'date': datetime.datetime(2021, 9, 28, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 9, 29, 0, 0), 'AvgTemp': 43.0}
# {'date': datetime.datetime(2021, 9, 30, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 10, 1, 0, 0), 'AvgTemp': 48.25}
# {'date': datetime.datetime(2021, 10, 2, 0, 0), 'AvgTemp': 43.57142857142857}
# {'date': datetime.datetime(2021, 10, 3, 0, 0), 'AvgTemp': 50.0}
# {'date': datetime.datetime(2021, 10, 4, 0, 0), 'AvgTemp': 49.0}
# {'date': datetime.datetime(2021, 10, 5, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 10, 6, 0, 0), 'AvgTemp': 44.0}
# {'date': datetime.datetime(2021, 10, 7, 0, 0), 'AvgTemp': 42.0}
# {'date': datetime.datetime(2021, 10, 8, 0, 0), 'AvgTemp': 41.0}
# {'date': datetime.datetime(2021, 10, 9, 0, 0), 'AvgTemp': 44.0}
# {'date': datetime.datetime(2021, 10, 10, 0, 0), 'AvgTemp': 53.333333333333336}
# {'date': datetime.datetime(2021, 10, 11, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 10, 12, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 10, 13, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 10, 14, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 10, 15, 0, 0), 'AvgTemp': 72.66666666666667}
# {'date': datetime.datetime(2021, 10, 16, 0, 0), 'AvgTemp': 36.0}
# {'date': datetime.datetime(2021, 10, 17, 0, 0), 'AvgTemp': 51.6}
# {'date': datetime.datetime(2021, 10, 18, 0, 0), 'AvgTemp': 52.166666666666664}
# {'date': datetime.datetime(2021, 10, 19, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 10, 20, 0, 0), 'AvgTemp': 50.0}
# {'date': datetime.datetime(2021, 10, 21, 0, 0), 'AvgTemp': 51.25}
# {'date': datetime.datetime(2021, 10, 22, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 10, 23, 0, 0), 'AvgTemp': 38.0}
# {'date': datetime.datetime(2021, 10, 24, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 10, 25, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 10, 26, 0, 0), 'AvgTemp': 44.6}
# {'date': datetime.datetime(2021, 10, 27, 0, 0), 'AvgTemp': 50.4}
# {'date': datetime.datetime(2021, 10, 28, 0, 0), 'AvgTemp': 56.0}
# {'date': datetime.datetime(2021, 10, 29, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 10, 30, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 10, 31, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 11, 1, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 11, 2, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 11, 3, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 11, 4, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 11, 5, 0, 0), 'AvgTemp': 58.5}
# {'date': datetime.datetime(2021, 11, 6, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 11, 7, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 11, 8, 0, 0), 'AvgTemp': 45.5}
# {'date': datetime.datetime(2021, 11, 9, 0, 0), 'AvgTemp': 61.3}
# {'date': datetime.datetime(2021, 11, 10, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 11, 11, 0, 0), 'AvgTemp': 46.25}
# {'date': datetime.datetime(2021, 11, 12, 0, 0), 'AvgTemp': 53.0}
# {'date': datetime.datetime(2021, 11, 13, 0, 0), 'AvgTemp': 47.0}
# {'date': datetime.datetime(2021, 11, 14, 0, 0), 'AvgTemp': 52.0}
# {'date': datetime.datetime(2021, 11, 15, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 11, 16, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 11, 17, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 11, 18, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 11, 19, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 11, 20, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 11, 21, 0, 0), 'AvgTemp': 59.0}
# {'date': datetime.datetime(2021, 11, 22, 0, 0), 'AvgTemp': 61.5}
# {'date': datetime.datetime(2021, 11, 23, 0, 0), 'AvgTemp': 58.8}
# {'date': datetime.datetime(2021, 11, 24, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 11, 25, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 11, 26, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 11, 27, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 11, 28, 0, 0), 'AvgTemp': 42.0}
# {'date': datetime.datetime(2021, 11, 29, 0, 0), 'AvgTemp': 60.625}
# {'date': datetime.datetime(2021, 11, 30, 0, 0), 'AvgTemp': 52.41935483870968}
# {'date': datetime.datetime(2021, 12, 1, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 12, 2, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 12, 3, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 12, 4, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 12, 5, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 12, 6, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 12, 7, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 12, 8, 0, 0), 'AvgTemp': 50.6}
# {'date': datetime.datetime(2021, 12, 9, 0, 0), 'AvgTemp': 58.25}
# {'date': datetime.datetime(2021, 12, 10, 0, 0), 'AvgTemp': 46.0}
# {'date': datetime.datetime(2021, 12, 11, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 12, 12, 0, 0), 'AvgTemp': 44.0}
# {'date': datetime.datetime(2021, 12, 13, 0, 0), 'AvgTemp': 60.0}
# {'date': datetime.datetime(2021, 12, 14, 0, 0), 'AvgTemp': 70.0}
# {'date': datetime.datetime(2021, 12, 15, 0, 0), 'AvgTemp': 39.0}
# {'date': datetime.datetime(2021, 12, 16, 0, 0), 'AvgTemp': 57.8}
# {'date': datetime.datetime(2021, 12, 17, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 12, 18, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 12, 19, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 12, 20, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 12, 21, 0, 0), 'AvgTemp': 46.0}
# {'date': datetime.datetime(2021, 12, 22, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 12, 23, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 12, 24, 0, 0), 'AvgTemp': 32.0}
# {'date': datetime.datetime(2021, 12, 25, 0, 0), 'AvgTemp': 54.0}
# {'date': datetime.datetime(2021, 12, 26, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 12, 27, 0, 0), 'AvgTemp': 62.75}
# {'date': datetime.datetime(2021, 12, 28, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 12, 29, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 12, 30, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 12, 31, 0, 0), 'AvgTemp': None}
# {'date': datetime.datetime(2021, 1, 1, 0, 0), 'AvgTemp': None}

# %% [markdown]
# ## i. Find the top 10 records with the lowest GHI.

# %%
results = climate_coll.aggregate([{"$sort":{"GHI_w/m2":-1}},{"$limit":10}])
for x in results:
    print(x)
# Out:
# {'_id': ObjectId('628a4076c40eee0972357856'), 'station': 948700, 'date': datetime.datetime(2021, 1, 7, 0, 0), 'air_temperature_celcius': 32, 'relative_humidity': 54.1, 'windspeed_knots': 12.8, 'max_wind_speed': 19.0, 'precipitation ': ' 0.00I', 'GHI_w/m2': 265, 'precipitation_numeric': 0.0}
# {'_id': ObjectId('628a4076c40eee097235798d'), 'station': 948702, 'date': datetime.datetime(2021, 11, 14, 0, 0), 'air_temperature_celcius': 28, 'relative_humidity': 48.3, 'windspeed_knots': 11.9, 'max_wind_speed': 22.0, 'precipitation ': ' 0.00I', 'GHI_w/m2': 243, 'precipitation_numeric': 0.0}
# {'_id': ObjectId('628a4076c40eee09723579aa'), 'station': 948702, 'date': datetime.datetime(2021, 12, 13, 0, 0), 'air_temperature_celcius': 28, 'relative_humidity': 49.9, 'windspeed_knots': 11.0, 'max_wind_speed': 19.0, 'precipitation ': ' 0.00I', 'GHI_w/m2': 240, 'precipitation_numeric': 0.0}
# {'_id': ObjectId('628a4076c40eee0972357876'), 'station': 948700, 'date': datetime.datetime(2021, 2, 8, 0, 0), 'air_temperature_celcius': 31, 'relative_humidity': 61.9, 'windspeed_knots': 14.1, 'max_wind_speed': 23.9, 'precipitation ': ' 0.00I', 'GHI_w/m2': 239, 'precipitation_numeric': 0.0}
# {'_id': ObjectId('628a4076c40eee097235799c'), 'station': 948702, 'date': datetime.datetime(2021, 11, 29, 0, 0), 'air_temperature_celcius': 28, 'relative_humidity': 56.7, 'windspeed_knots': 9.3, 'max_wind_speed': 16.9, 'precipitation ': ' 0.00I', 'GHI_w/m2': 227, 'precipitation_numeric': 0.0}
# {'_id': ObjectId('628a4076c40eee0972357899'), 'station': 948701, 'date': datetime.datetime(2021, 3, 15, 0, 0), 'air_temperature_celcius': 28, 'relative_humidity': 58.4, 'windspeed_knots': 11.9, 'max_wind_speed': 18.1, 'precipitation ': ' 0.04G', 'GHI_w/m2': 223, 'precipitation_numeric': 0.04}
# {'_id': ObjectId('628a4076c40eee09723579b8'), 'station': 948702, 'date': datetime.datetime(2021, 12, 27, 0, 0), 'air_temperature_celcius': 28, 'relative_humidity': 58.3, 'windspeed_knots': 9.3, 'max_wind_speed': 15.9, 'precipitation ': ' 0.00I', 'GHI_w/m2': 223, 'precipitation_numeric': 0.0}
# {'_id': ObjectId('628a4076c40eee0972357972'), 'station': 948702, 'date': datetime.datetime(2021, 10, 18, 0, 0), 'air_temperature_celcius': 26, 'relative_humidity': 52.2, 'windspeed_knots': 13.7, 'max_wind_speed': 16.9, 'precipitation ': ' 0.00I', 'GHI_w/m2': 219, 'precipitation_numeric': 0.0}
# {'_id': ObjectId('628a4076c40eee0972357872'), 'station': 948700, 'date': datetime.datetime(2021, 2, 4, 0, 0), 'air_temperature_celcius': 26, 'relative_humidity': 53.7, 'windspeed_knots': 8.7, 'max_wind_speed': 15.0, 'precipitation ': ' 0.00I', 'GHI_w/m2': 216, 'precipitation_numeric': 0.0}
# {'_id': ObjectId('628a4076c40eee0972357994'), 'station': 948702, 'date': datetime.datetime(2021, 11, 21, 0, 0), 'air_temperature_celcius': 24, 'relative_humidity': 51.8, 'windspeed_knots': 7.9, 'max_wind_speed': 15.0, 'precipitation ': ' 0.00I', 'GHI_w/m2': 203, 'precipitation_numeric': 0.0}

# %% [markdown]
# ## j. Find the records with a 24-hour precipitation recorded between 0.20 to 0.35

# %%
mq = {"precipitation_numeric": {"$gte":0.2,"$lte":0.35 }}
results = climate_coll.find(mq,
                            {"station":1,"date":1,"air_temperature_celcius":1,"relative_humidity":1,"windspeed_knots":1,
                             "max_wind_speed":1,"precipitation ":1, "GHI_w/m2": 1})

for x in results: 
    print(x)
# Out:
# {'_id': ObjectId('628a4076c40eee097235785c'), 'station': 948700, 'date': datetime.datetime(2021, 1, 13, 0, 0), 'air_temperature_celcius': 19, 'relative_humidity': 54.1, 'windspeed_knots': 11.2, 'max_wind_speed': 18.1, 'precipitation ': ' 0.31G', 'GHI_w/m2': 157}
# {'_id': ObjectId('628a4076c40eee09723578a7'), 'station': 948701, 'date': datetime.datetime(2021, 3, 29, 0, 0), 'air_temperature_celcius': 17, 'relative_humidity': 49.9, 'windspeed_knots': 12.2, 'max_wind_speed': 21.0, 'precipitation ': ' 0.24G', 'GHI_w/m2': 146}
# {'_id': ObjectId('628a4076c40eee09723578bd'), 'station': 948701, 'date': datetime.datetime(2021, 4, 20, 0, 0), 'air_temperature_celcius': 20, 'relative_humidity': 53.5, 'windspeed_knots': 7.2, 'max_wind_speed': 15.9, 'precipitation ': ' 0.31G', 'GHI_w/m2': 166}
# {'_id': ObjectId('628a4076c40eee09723578c3'), 'station': 948701, 'date': datetime.datetime(2021, 4, 26, 0, 0), 'air_temperature_celcius': 11, 'relative_humidity': 40.8, 'windspeed_knots': 12.2, 'max_wind_speed': 20.0, 'precipitation ': ' 0.24G', 'GHI_w/m2': 102}
# {'_id': ObjectId('628a4076c40eee09723578e2'), 'station': 948701, 'date': datetime.datetime(2021, 5, 27, 0, 0), 'air_temperature_celcius': 14, 'relative_humidity': 48.1, 'windspeed_knots': 13.7, 'max_wind_speed': 19.0, 'precipitation ': ' 0.35G', 'GHI_w/m2': 122}
# {'_id': ObjectId('628a4076c40eee09723578e5'), 'station': 948701, 'date': datetime.datetime(2021, 5, 30, 0, 0), 'air_temperature_celcius': 8, 'relative_humidity': 41.6, 'windspeed_knots': 8.3, 'max_wind_speed': 15.9, 'precipitation ': ' 0.24G', 'GHI_w/m2': 73}
# {'_id': ObjectId('628a4076c40eee0972357907'), 'station': 948701, 'date': datetime.datetime(2021, 7, 3, 0, 0), 'air_temperature_celcius': 11, 'relative_humidity': 45.1, 'windspeed_knots': 11.5, 'max_wind_speed': 18.1, 'precipitation ': ' 0.20G', 'GHI_w/m2': 98}
# {'_id': ObjectId('628a4076c40eee097235791f'), 'station': 948701, 'date': datetime.datetime(2021, 7, 27, 0, 0), 'air_temperature_celcius': 11, 'relative_humidity': 43.5, 'windspeed_knots': 13.1, 'max_wind_speed': 21.0, 'precipitation ': ' 0.24G', 'GHI_w/m2': 99}
# {'_id': ObjectId('628a4076c40eee0972357929'), 'station': 948702, 'date': datetime.datetime(2021, 8, 6, 0, 0), 'air_temperature_celcius': 9, 'relative_humidity': 41.1, 'windspeed_knots': 12.7, 'max_wind_speed': 19.0, 'precipitation ': ' 0.24G', 'GHI_w/m2': 83}
# {'_id': ObjectId('628a4076c40eee097235793d'), 'station': 948702, 'date': datetime.datetime(2021, 8, 26, 0, 0), 'air_temperature_celcius': 11, 'relative_humidity': 39.7, 'windspeed_knots': 11.8, 'max_wind_speed': 19.0, 'precipitation ': ' 0.28G', 'GHI_w/m2': 102}
# {'_id': ObjectId('628a4076c40eee0972357947'), 'station': 948702, 'date': datetime.datetime(2021, 9, 5, 0, 0), 'air_temperature_celcius': 8, 'relative_humidity': 38.6, 'windspeed_knots': 12.8, 'max_wind_speed': 18.1, 'precipitation ': ' 0.31G', 'GHI_w/m2': 75}
# {'_id': ObjectId('628a4076c40eee0972357949'), 'station': 948702, 'date': datetime.datetime(2021, 9, 7, 0, 0), 'air_temperature_celcius': 10, 'relative_humidity': 43.6, 'windspeed_knots': 9.7, 'max_wind_speed': 14.0, 'precipitation ': ' 0.20G', 'GHI_w/m2': 90}
# {'_id': ObjectId('628a4076c40eee0972357951'), 'station': 948702, 'date': datetime.datetime(2021, 9, 15, 0, 0), 'air_temperature_celcius': 11, 'relative_humidity': 46.2, 'windspeed_knots': 10.5, 'max_wind_speed': 15.0, 'precipitation ': ' 0.28G', 'GHI_w/m2': 97}
# {'_id': ObjectId('628a4076c40eee0972357965'), 'station': 948702, 'date': datetime.datetime(2021, 10, 5, 0, 0), 'air_temperature_celcius': 12, 'relative_humidity': 47.5, 'windspeed_knots': 15.0, 'max_wind_speed': 18.1, 'precipitation ': ' 0.20G', 'GHI_w/m2': 105}
# {'_id': ObjectId('628a4076c40eee097235797d'), 'station': 948702, 'date': datetime.datetime(2021, 10, 29, 0, 0), 'air_temperature_celcius': 17, 'relative_humidity': 44.9, 'windspeed_knots': 16.1, 'max_wind_speed': 27.0, 'precipitation ': ' 0.24G', 'GHI_w/m2': 152}
# {'_id': ObjectId('628a4076c40eee097235797e'), 'station': 948702, 'date': datetime.datetime(2021, 10, 30, 0, 0), 'air_temperature_celcius': 11, 'relative_humidity': 43.2, 'windspeed_knots': 8.1, 'max_wind_speed': 14.0, 'precipitation ': ' 0.20G', 'GHI_w/m2': 100}
# {'_id': ObjectId('628a4076c40eee097235798f'), 'station': 948702, 'date': datetime.datetime(2021, 11, 16, 0, 0), 'air_temperature_celcius': 18, 'relative_humidity': 61.5, 'windspeed_knots': 5.5, 'max_wind_speed': 11.1, 'precipitation ': ' 0.28G', 'GHI_w/m2': 140}
# {'_id': ObjectId('628a4076c40eee0972357990'), 'station': 948702, 'date': datetime.datetime(2021, 11, 17, 0, 0), 'air_temperature_celcius': 19, 'relative_humidity': 58.7, 'windspeed_knots': 5.5, 'max_wind_speed': 12.0, 'precipitation ': ' 0.28G', 'GHI_w/m2': 151}
# {'_id': ObjectId('628a4076c40eee097235799d'), 'station': 948702, 'date': datetime.datetime(2021, 11, 30, 0, 0), 'air_temperature_celcius': 26, 'relative_humidity': 61.0, 'windspeed_knots': 9.3, 'max_wind_speed': 15.0, 'precipitation ': ' 0.20G', 'GHI_w/m2': 202}
